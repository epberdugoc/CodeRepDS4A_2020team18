# %%
# Saber Pro Dictionary
personal_columns = [
    'ESTU_TIPODOCUMENTO',
    'ESTU_NACIONALIDAD',
    'ESTU_GENERO',
    'ESTU_FECHANACIMIENTO',
    'ESTU_EXTERIOR',
    'PERIODO',
    'ESTU_CONSECUTIVO',
    'ESTU_ESTADOCIVIL', 
    'ESTU_ESTUDIANTE',
    'ESTU_PAIS_RESIDE',
    'ESTU_TIENEETNIA', 
    'ESTU_ETNIA', 
    'ESTU_DISC_FISICA', 
    'ESTU_DISC_SISTEM', 
    'ESTU_DISC_AUDITCASTELL', 
    'ESTU_DISC_AUDITLSC', 
    'ESTU_DISC_VISUALCEGUE', 
    'ESTU_DISC_VISUALBAJA', 
    'ESTU_DISC_VOZHABLA', 
    'ESTU_DISC_INTELEC', 
    'ESTU_DISC_SORDOCEGUERA', 
    'ESTU_DISC_ASPERGER', 
    'ESTU_DISC_PSICOSOCIAL', 
    'ESTU_LIMITA_MOTRIZ',
    'ESTU_LIMITA_INVIDENTE',
    'ESTU_LIMITA_CONDICIONESPECIAL',
    'ESTU_LIMITA_SORDO',
    'ESTU_LIMITA_SDOWN',
    'ESTU_LIMITA_AUTISMO',
    'ESTU_LIMITA_SORDOCONINTERPRETE',
    'ESTU_LIMITA_SORDOSININTERPRETE',
    'ESTU_LIMITA_SORDOCEGUERA',
    'ESTU_APO_DESPLAZASITIO',
    'ESTU_APO_ACOMPAÑAMIENTO',
    'ESTU_APO_JEFESALON',
    'ESTU_APO_LECTORAPOYO',
    'ESTU_APO_MANIOBRARMAT',
    'ESTU_APO_INTERPSEÑAS',
    'ESTU_APO_INTERPSORDOCIEGO',
    'ESTU_APO_NOREQUIERE'
]

contact_columns = [
    'ESTU_DEPTO_RESIDE',
    'ESTU_COD_RESIDE_DEPTO',
    'ESTU_MCPIO_RESIDE',
    'ESTU_COD_RESIDE_MCPIO',
    'ESTU_AREARESIDE'
]

academic_columns = [
    'ESTU_GRADUO_BACHILLER',
    'ESTU_FECHAGRADOBACHILLER',
    'ESTU_MES_TERMINOBACHILLER',
    'ESTU_ANO_TERMINOBACHILLER',
    'ESTU_ANO_EGRESO',
    'ESTU_CODICFESCOLE_TERMINO',
    'ESTU_COLE_TERMINO',
    'ESTU_CODDANE_COLE_TERMINO',
    'ESTU_COD_COLE_MCPIO_TERMINO',
    'ESTU_OTROCOLE_TERMINO',
    'ESTU_TITULOOBTENIDOBACHILLER',
    'ESTU_ANO_EXAMENESTADO_SB11',
    'ESTU_SEMESTRE_EXAMENESTADOSB11',
    'ESTU_PORCENTAJECREDITOSAPROB',
    'ESTU_VALORMATRICULAUEXT',
    'ESTU_VALORMATRICULAUNIVERSIDAD',
    'ESTU_PAGOMATRICULAEXT',
    'ESTU_PAGOMATRICULABECA',
    'ESTU_PAGOMATRICULACREDITO',
    'ESTU_PAGOMATRICULAPADRES',
    'ESTU_PAGOMATRICULAPROPIO',
    'ESTU_COMOCAPACITOEXAMENSB11',
    'ESTU_TOMO_CURSOPREPARACION',
    'ESTU_CURSODOCENTESIES',
    'ESTU_CURSOIESAPOYOEXTERNO',
    'ESTU_CURSOIESEXTERNA',
    'ESTU_SIMULACROTIPOICFES',
    'ESTU_ACTIVIDADREFUERZOAREAS',
    'ESTU_ACTIVIDADREFUERZOGENERIC',
    'ESTU_PAISDOCUMENTOSB11',
    'ESTU_TIPODOCUMENTOSB11',
    'ESTU_SEMESTRECURSA',
    'ESTU_ULTIMOGRADOAPROBO',
    'ESTU_ANOTERMINOULTIMOGRADO',
    'ESTU_VECESPRESENTOEXAMENESTADO',
    'ESTU_VECESPRESENTOEXAMEN'
]

socioeconomic_columns = [
    'FAMI_HOGARACTUAL',
    'FAMI_CABEZAFAMILIA',
    'FAMI_NUMPERSONASACARGO',
    'FAMI_EDUCACIONPADRE',
    'FAMI_EDUCACIONMADRE',
    'FAMI_OCUPACIONPADRE',
    'FAMI_OCUPACIONMADRE',
    'FAMI_TRABAJOLABORPADRE',
    'FAMI_TRABAJOLABORMADRE',
    'FAMI_ESTRATOVIVIENDA',
    'FAMI_NIVEL_SISBEN',
    'FAMI_PERSONASHOGAR',
    'FAMI_CUARTOSHOGAR',
    'FAMI_PISOS_HOGAR',
    'FAMI_TIENEINTERNET',
    'FAMI_TIENESERVICIOTV',
    'FAMI_TIENECOMPUTADOR',
    'FAMI_TIENELAVADORA',
    'FAMI_TIENEHORNOMICROOGAS',
    'FAMI_TIENE_MICROONDAS',
    'FAMI_TIENE_HORNO',
    'FAMI_TIENEAUTOMOVIL',
    'FAMI_TIENEMOTOCICLETA',
    'FAMI_TIENE_NEVERA',
    'FAMI_TIENE_CELULAR',
    'FAMI_TIENECONSOLAVIDEOJUEGOS',
    'FAMI_CUANTOSCOMPARTEBAÑO',
    'FAMI_NUMLIBROS',
    'FAMI_TELEFONO',
    'FAMI_INGRESO_FMILIAR_MENSUAL',
    'ESTU_DEDICACIONLECTURADIARIA',
    'ESTU_DEDICACIONINTERNET',
    'ESTU_TRABAJA_ACTUALMENTE',
    'ESTU_HORASSEMANATRABAJA',
    'ESTU_TIPOREMUNERACION'
]

ies_columns = [
    'INST_COD_INSTITUCION',
    'INST_NOMBRE_INSTITUCION',
    'ESTU_PRGM_ACADEMICO',
    'ESTU_SNIES_PRGMACADEMICO',
    'GRUPOREFERENCIA',
    'ESTU_PRGM_CODMUNICIPIO',
    'ESTU_PRGM_MUNICIPIO',
    'ESTU_PRGM_DEPARTAMENTO',
    'ESTU_NIVEL_PRGM_ACADEMICO',
    'ESTU_METODO_PRGM',
    'ESTU_NUCLEO_PREGRADO',
    'ESTU_INST_CODMUNICIPIO',
    'ESTU_INST_MUNICIPIO',
    'ESTU_INST_DEPARTAMENTO',
    'INST_CARACTER_ACADEMICO',
    'INST_ORIGEN'
]

citation_columns = [
    'ESTU_PRIVADO_LIBERTAD',
    'ESTU_COD_MCPIO_PRESENTACION',
    'ESTU_MCPIO_PRESENTACION',
    'ESTU_DEPTO_PRESENTACION',
    'ESTU_COD_DEPTO_PRESENTACION'
]

results_columns = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_RAZONA_CUANTITAT_DESEM',
    'MOD_RAZONA_CUANTITATIVO_PNAL',
    'MOD_RAZONA_CUANTITATIVO_PGREF',
    'MOD_RAZONA_CUANTITATIVO_PNBC',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_LECTURA_CRITICA_DESEM',
    'MOD_LECTURA_CRITICA_PNAL',
    'MOD_LECTURA_CRITICA_PGREF',
    'MOD_LECTURA_CRITICA_PNBC',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_COMPETEN_CIUDADA_DESEM',
    'MOD_COMPETEN_CIUDADA_PNAL',
    'MOD_COMPETEN_CIUDADA_PGREF',
    'MOD_COMPETEN_CIUDADA_PNBC',
    'MOD_INGLES_PUNT',
    'MOD_INGLES_DESEM',
    'MOD_INGLES_PNAL',
    'MOD_INGLES_PGREF',
    'MOD_INGLES_PNBC',
    'MOD_COMUNI_ESCRITA_PUNT',
    'MOD_COMUNI_ESCRITA_DESEM',
    'MOD_COMUNI_ESCRITA_PNAL',
    'MOD_COMUNI_ESCRITA_PGREF',
    'MOD_COMUNI_ESCRITA_PNBC',
    'PUNT_GLOBAL',
    'PERCENTIL_GLOBAL',
    'PERCENTIL_NBC'
]

aditional_columns = [
    'ESTU_INSE_INDIVIDUAL',
    'ESTU_NSE_INDIVIDUAL',
    'ESTU_NSE_IES',
    'ESTU_ESTADOINVESTIGACION'
]

generic_df_columns = {
    'personal': personal_columns,
    'contact': contact_columns,
    'academic': academic_columns,
    'socioeconomic': socioeconomic_columns,
    'ies': ies_columns,
    'citation': citation_columns,
    'results': results_columns,
    'aditional': aditional_columns
}

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import math

# %%
df = pd.read_csv('data-final.csv', index_col=0)
df
# Out:
# /home/developer/miniconda3/envs/project/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (9,11,12,30,33,34,40,45,48,58,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/developer/miniconda3/envs/project/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                     CC        1 COLOMBIA           F
# 1                     CC        1 COLOMBIA           M
# 2                     CC        1 COLOMBIA           F
# 3                     CC        1 COLOMBIA           M
# 4                     CC        1 COLOMBIA           M
# ...                  ...               ...         ...
# ...

# %%
df.shape
# Out:
# (1635915, 63)

# %%
df.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_SIMULACROTIPOICFES',
#        'ESTU_ACTIVIDADREFUERZOAREAS', 'ESTU_ACTIVIDADREFUERZOGENERIC',
#        'ESTU_TIPODOCUMENTOSB11', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_HORASSEMANATRABAJA',
#        'INST_COD_INSTITUCION', 'INST_NOMBRE_INSTITUCION',
#        'ESTU_PRGM_ACADEMICO', 'ESTU_SNIES_PRGMACADEMICO',
#        'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
# ...

# %% [markdown]
# ### See contents by variable

# %%
selected_columns = [
    'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
    'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
    'ESTU_ESTUDIANTE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
    'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
    'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
    'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
    'ESTU_PAGOMATRICULAPROPIO', 'ESTU_SIMULACROTIPOICFES',
    'ESTU_ACTIVIDADREFUERZOAREAS', 'ESTU_ACTIVIDADREFUERZOGENERIC',
    'ESTU_TIPODOCUMENTOSB11', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
    'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
    'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_HORASSEMANATRABAJA'
]

# %%
target_columns = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_RAZONA_CUANTITATIVO_PNAL', 'MOD_LECTURA_CRITICA_PUNT',
    'MOD_LECTURA_CRITICA_PNAL', 'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_COMPETEN_CIUDADA_PNAL', 'MOD_INGLES_PUNT', 'MOD_INGLES_DESEM',
    'MOD_INGLES_PNAL', 'MOD_COMUNI_ESCRITA_PUNT',
    'MOD_COMUNI_ESCRITA_DESEM', 'MOD_COMUNI_ESCRITA_PNAL',
    'ESTU_ESTADOINVESTIGACION', 'PERIODO-X', 'PRUEBA'
]

# %%
for column in (selected_columns + target_columns):
    print(f'Column: {column}')
    print(df[column].astype(str).sort_values().unique())
    print('nan ->', df[column].astype(str).isin(['nan']).sum())
    print('. ->', df[column].astype(str).isin(['.']).sum())
    print('- ->', df[column].astype(str).isin(['-']).sum())
    print()
# Out:
# Column: ESTU_TIPODOCUMENTO
# ['CC' 'CE' 'CR' 'NES' 'PC' 'PE' 'PEP' 'TI' 'V']
# nan -> 0
# . -> 0
# - -> 0
#
# Column: ESTU_NACIONALIDAD
# ['1 COLOMBIA' '110 ITALIA' '112 JAPÓN' '118 COREA DEL NORTE'
#  '119 COREA DEL SUR' '12 ARGENTINA' '14 ARUBA' '144 MÉXICO'
#  '152 MOZAMBIQUE' '157 PAÍSES BAJOS - HOLANDA' '166 NORUEGA' '167 OMÁN'
#  '17 AZERBAIYÁN' '171 PANAMÁ' '174 PERÚ' '183 RUSIA' '209 ESPAÑA'
#  '216 SUIZA' '218 TAIWAN' '235 REINO UNIDO' '236 ESTADOS UNIDOS'
#  '238 URUGUAY' '241 VENEZUELA' '242 VIETNAM' '28 BOLIVIA' '3 ALAND'
#  '33 BRASIL' '41 CANADÁ' '46 CHILE' '47 CHINA' '50 COMORAS'
#  '52 REPÚBLICA DEMOCRÁTICA DEL CONGO' '54 COSTA RICA' '55 COSTA DE MARFIL'
#  '57 CUBA' '60 REPÚBLICA CHECA' '64 REPÚBLICA DOMINICANA' '65 ECUADOR'
#  '67 EL SALVADOR' '76 FRANCIA' '83 ALEMANIA' '86 GRECIA' '91 GUATEMALA'
#  '96 HAITI' '98 CIUDAD DEL VATICANO' '99 HONDURAS' 'AFGANISTÁN' 'ALAND'
#  'ALBANIA' 'ALEMANIA' 'ANGUILA' 'ANTIGUA Y BARBUDA' 'ARGELIA' 'ARGENTINA'
# ...

# %%
def clean_ESTU_NACIONALIDAD(element):
    split_element = element.split()
    
    if split_element[0].isnumeric():
        return ' '.join(split_element[1:]).upper()
    return element.upper()

def clean_ESTU_GENERO(element):
    if element in ['nan', np.nan, '-']:
        return np.nan
    return element.upper()

def clean_ESTU_COD_RESIDE_DEPTO(element):
    if element in ['nan', np.nan, '-'] or math.isnan(float(element)):
        return np.nan
    try:
        return f"{int(float(element)):02d}"
    except:
        print(element in ['nan', np.nan, '-', None])
        print(element)
        print(type(element))
        raise Exception('sth went wrong')
    

def clean_ESTU_COD_RESIDE_MCPIO(element):
    if element in ['nan', np.nan, '-'] or math.isnan(float(element)):
        return np.nan
    return f"{int(float(element)):05d}"

# %%
clean_functions = {
    'ESTU_NACIONALIDAD': clean_ESTU_NACIONALIDAD,
    'ESTU_GENERO': clean_ESTU_GENERO,
    'ESTU_COD_RESIDE_DEPTO': clean_ESTU_COD_RESIDE_DEPTO,
    'ESTU_COD_RESIDE_MCPIO': clean_ESTU_COD_RESIDE_MCPIO
}

for column, function in clean_functions.items():
    df[column] = df[column].apply(function)

# %%
datetime_columns = [
    'ESTU_FECHANACIMIENTO'
]

for column in datetime_columns:
    pd.to_datetime(df[column], errors='coerce')

# %%
df = df.replace(to_replace=['-','.'], value=np.nan)
df
# Out:
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                     CC          COLOMBIA           F
# 1                     CC          COLOMBIA           M
# 2                     CC          COLOMBIA           F
# 3                     CC          COLOMBIA           M
# 4                     CC          COLOMBIA           M
# ...                  ...               ...         ...
# 76349                 CC          COLOMBIA           M
# 76350                 CC          COLOMBIA           M
# 76351                 CC          COLOMBIA           M
# 76352                 CC          COLOMBIA           M
# 76353                 CC          COLOMBIA           M
#
#          ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0                  24/11/1994    20163   EK201630197609      ESTUDIANTE
# 1                  11/06/1991    20163   EK201630241417      ESTUDIANTE
# 2                  22/02/1995    20163   EK201630080363      ESTUDIANTE
# ...

# %%
df[[
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]] = df[[
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]].astype(float)

# %% [markdown]
# **Check columns again**

# %%
for column in (selected_columns + target_columns):
    print(f'Column: {column}')
    print(df[column].astype(str).sort_values().unique())
    print('nan ->', df[column].astype(str).isin(['nan']).sum())
    print('. ->', df[column].astype(str).isin(['.']).sum())
    print('- ->', df[column].astype(str).isin(['-']).sum())
    print()
# Out:
# Column: ESTU_TIPODOCUMENTO
# ['CC' 'CE' 'CR' 'NES' 'PC' 'PE' 'PEP' 'TI' 'V']
# nan -> 0
# . -> 0
# - -> 0
#
# Column: ESTU_NACIONALIDAD
# ['AFGANISTÁN' 'ALAND' 'ALBANIA' 'ALEMANIA' 'ANGUILA' 'ANTIGUA Y BARBUDA'
#  'ARGELIA' 'ARGENTINA' 'ARMENIA' 'ARUBA' 'AUSTRALIA' 'AUSTRIA'
#  'AZERBAIYÁN' 'BIELORRUSIA' 'BOLIVIA' 'BRASIL' 'BULGARIA' 'BUTÁN'
#  'CABO VERDE' 'CAMERÚN' 'CANADÁ' 'CHILE' 'CHINA' 'CHIPRE'
#  'CIUDAD DEL VATICANO' 'COLOMBIA' 'COMORAS' 'COREA DEL NORTE'
#  'COREA DEL SUR' 'COSTA DE MARFIL' 'COSTA RICA' 'CROACIA' 'CUBA' 'CURAZAO'
#  'DINAMARCA' 'DOMINICA' 'ECUADOR' 'EL SALVADOR' 'ESPAÑA'
#  'ESTADOS FEDERADOS DE MICRONESIA' 'ESTADOS UNIDOS' 'FILIPINAS' 'FRANCIA'
#  'GABÓN' 'GRECIA' 'GUATEMALA' 'HAITI' 'HONDURAS' 'INDIA' 'ISRAEL' 'ITALIA'
#  'JAMAICA' 'JAPÓN' 'KENIA' 'LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO'
#  'LITUANIA' 'MACAO' 'MARRUECOS' 'MOZAMBIQUE' 'MÉXICO' 'NAMIBIA'
#  'NICARAGUA' 'NORUEGA' 'OMÁN' 'PANAMÁ' 'PARAGUAY' 'PAÍSES BAJOS - HOLANDA'
# ...

# %% [markdown]
# **Inspect a column**

# %%
with pd.option_context('display.max_rows', 110):
    display(df[['ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO']].sort_values(by='ESTU_DEPTO_RESIDE').drop_duplicates())
# Out:
#        ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO
# 232579          AMAZONAS                    91
# 22957          ANTIOQUIA                    05
# 176262            ARAUCA                    81
# 24788          ATLANTICO                    08
# 21881             BOGOTA                    11
# 103873            BOGOTÁ                    11
# 36424            BOLIVAR                    13
# 73385             BOYACA                    15
# 48180             CALDAS                    17
# 69244            CAQUETA                    18
# 202860          CASANARE                    85
# 205165             CAUCA                    19
# 30084              CESAR                    20
# 190475             CHOCO                    27
# 23520            CORDOBA                    23
# 32108       CUNDINAMARCA                    25
# 12092         EXTRANJERO                 99999
# 33024            GUAINIA                    94
# 47218           GUAVIARE                    95
# ...

# %% [markdown]
# ## Future

# %%
selected_columns
# Out:
# ['ESTU_TIPODOCUMENTO',
#  'ESTU_NACIONALIDAD',
#  'ESTU_GENERO',
#  'ESTU_FECHANACIMIENTO',
#  'PERIODO',
#  'ESTU_CONSECUTIVO',
#  'ESTU_ESTUDIANTE',
#  'ESTU_DEPTO_RESIDE',
#  'ESTU_COD_RESIDE_DEPTO',
#  'ESTU_MCPIO_RESIDE',
#  'ESTU_COD_RESIDE_MCPIO',
#  'ESTU_COLE_TERMINO',
#  'ESTU_VALORMATRICULAUNIVERSIDAD',
#  'ESTU_PAGOMATRICULABECA',
#  'ESTU_PAGOMATRICULACREDITO',
#  'ESTU_PAGOMATRICULAPADRES',
#  'ESTU_PAGOMATRICULAPROPIO',
#  'ESTU_SIMULACROTIPOICFES',
#  'ESTU_ACTIVIDADREFUERZOAREAS',
#  'ESTU_ACTIVIDADREFUERZOGENERIC',
#  'ESTU_TIPODOCUMENTOSB11',
#  'FAMI_EDUCACIONPADRE',
#  'FAMI_EDUCACIONMADRE',
#  'FAMI_ESTRATOVIVIENDA',
#  'FAMI_TIENEINTERNET',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENELAVADORA',
#  'FAMI_TIENEAUTOMOVIL',
#  'ESTU_HORASSEMANATRABAJA']

# %%
target_columns
# Out:
# ['MOD_RAZONA_CUANTITAT_PUNT',
#  'MOD_RAZONA_CUANTITATIVO_PNAL',
#  'MOD_LECTURA_CRITICA_PUNT',
#  'MOD_LECTURA_CRITICA_PNAL',
#  'MOD_COMPETEN_CIUDADA_PUNT',
#  'MOD_COMPETEN_CIUDADA_PNAL',
#  'MOD_INGLES_PUNT',
#  'MOD_INGLES_DESEM',
#  'MOD_INGLES_PNAL',
#  'MOD_COMUNI_ESCRITA_PUNT',
#  'MOD_COMUNI_ESCRITA_DESEM',
#  'MOD_COMUNI_ESCRITA_PNAL',
#  'ESTU_ESTADOINVESTIGACION',
#  'PERIODO-X',
#  'PRUEBA']

# %%
vars_to_inspect = [
    'ESTU_NACIONALIDAD', 'ESTU_GENERO',
    'ESTU_ESTUDIANTE', 'ESTU_VALORMATRICULAUNIVERSIDAD',
    'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO'
]

plt.figure(figsize=(12,4*3));
for i, var in enumerate(vars_to_inspect,1):
    plt.subplot(3,2,i)
    sns.boxplot(x=var, y='MOD_RAZONA_CUANTITAT_PUNT', data=df.sort_values(by=var));
    plt.xticks(rotation=90); 
    plt.title('Puntaje global vs. '+ var)

# %%
vars_to_inspect = [
    'ESTU_NACIONALIDAD', 'ESTU_GENERO',
    'ESTU_ESTUDIANTE', 'ESTU_VALORMATRICULAUNIVERSIDAD',
    'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO'
]

mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_GENERO'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
vars_to_inspect = [
    'ESTU_NACIONALIDAD', 'ESTU_GENERO',
    'ESTU_ESTUDIANTE', 'ESTU_VALORMATRICULAUNIVERSIDAD',
    'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO'
]

mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_VALORMATRICULAUNIVERSIDAD'

df = df.replace(to_replace='Más de 5 millones', value='Mas de 5 millones')
df = df.replace(to_replace='Más de 7 millones', value='Mas de 7 millones')

var_order = [
    'No pago semestre',
    'No pagó matrícula',
    'Menos de 500 mil',
    'Entre 500 mil y menos de 1 millón',
    'Entre 1 millón y menos de 2.5 millones',
    'Entre 2.5 millones y menos de 4 millones',
    'Entre 4 millones y menos de 5.5 millones',
    'Entre 5.5 millones y menos de 7 millones',
    'Menos de 500 mil pesos',
    'Entre 500 mil y un millon de pesos',
    'Entre 1 millón y menos de 3 millones',
    'Entre un millon y 3 millones de pesose',
    'Entre 3 millones y menos de 5 millones',
    'Entre 3 y 5 millones',
    'Entre 5 y 7 millones',
    'Mas de 5 millones',
    'Más de 7 millones'
]

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var), order=var_order);
    plt.xticks(rotation=90); 
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var), order=var_order); 
    plt.xticks(rotation=90);

# %%
unique_u_cost_values_df = df.drop_duplicates(['PERIODO-X', 'ESTU_VALORMATRICULAUNIVERSIDAD'])
                                             
df['ESTU_VALORMATRICULAUNIVERSIDAD'] = pd.Categorical(
    df['ESTU_VALORMATRICULAUNIVERSIDAD'], 
    var_order
)
                                             
unique_u_cost_values_df = unique_u_cost_values_df.sort_values(by=['PERIODO-X', 'ESTU_VALORMATRICULAUNIVERSIDAD'])

with pd.option_context('display.max_rows', 105):
    display(unique_u_cost_values_df[['PRUEBA', 'PERIODO-X', 'ESTU_VALORMATRICULAUNIVERSIDAD']])
# Out:
# /home/developer/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#         PRUEBA  PERIODO-X            ESTU_VALORMATRICULAUNIVERSIDAD
# 11    SaberPro       2016                         No pagó matrícula
# 7     SaberPro       2016                          Menos de 500 mil
# 2     SaberPro       2016         Entre 500 mil y menos de 1 millón
# 0     SaberPro       2016    Entre 1 millón y menos de 2.5 millones
# 16    SaberPro       2016  Entre 2.5 millones y menos de 4 millones
# 6     SaberPro       2016  Entre 4 millones y menos de 5.5 millones
# 4     SaberPro       2016  Entre 5.5 millones y menos de 7 millones
# ...

# %% [markdown]
# 2016-1 and 2019-1 have different values than other periods for Saber TyT.

# %%
df['ESTU_VALORMATRICULAUNIVERSIDAD'] = pd.Categorical(
    df['ESTU_VALORMATRICULAUNIVERSIDAD'], 
    var_order
)

# %%
df['MOD_RAZONA_CUANTITAT_PUNT'].dtype
# Out:
# dtype('float64')

# %%
'CC' in df['MOD_RAZONA_CUANTITAT_PUNT'].unique()
# Out:
# /home/developer/miniconda3/envs/project/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   """Entry point for launching an IPython kernel.
# False

# %%
plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,1,i)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    data = df[df["PRUEBA"]=='SaberPro']
    semester_values = data['ESTU_VALORMATRICULAUNIVERSIDAD'].unique().sort_values()
    for semester_value in semester_values:
        sns.kdeplot(
            data=data[data['ESTU_VALORMATRICULAUNIVERSIDAD']==semester_value][mod],
            label=semester_value,
            shade=True
        )

# %%
plt.figure(figsize=(16,5*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,1,i)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    data = df[df["PRUEBA"]=='SaberTyT']
    semester_values = data['ESTU_VALORMATRICULAUNIVERSIDAD'].unique().sort_values()
    for semester_value in semester_values:
        sns.kdeplot(
            data=data[data['ESTU_VALORMATRICULAUNIVERSIDAD']==semester_value][mod],
            label=semester_value,
            shade=True
        )

# %%
vars_to_inspect = [
    'ESTU_NACIONALIDAD', 'ESTU_GENERO',
    'ESTU_ESTUDIANTE', 'ESTU_VALORMATRICULAUNIVERSIDAD',
    'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO'
]

mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_PAGOMATRICULABECA'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_PAGOMATRICULACREDITO'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_PAGOMATRICULAPADRES'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_PAGOMATRICULAPROPIO'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_SIMULACROTIPOICFES'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_ACTIVIDADREFUERZOAREAS'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_ACTIVIDADREFUERZOGENERIC'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_EDUCACIONPADRE'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    plt.xticks(rotation=90); 
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var)); 
    plt.xticks(rotation=90);

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_EDUCACIONMADRE'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    plt.xticks(rotation=90); 
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var)); 
    plt.xticks(rotation=90);

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_ESTRATOVIVIENDA'
df = df.replace(to_replace='Vive en una zona rural donde no hay estratificación socioeconómica', value='Zona rural')

var2 = ''
f = plt.figure(figsize=(16,5*5));
# f.subplots_adjust(hspace=0.5)

for i, mod in enumerate(mod_list, 1):
    a1 = plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    plt.xticks(rotation=90);
    
    if i != 5:
        a1.get_xaxis().set_visible(False)
    
    a2 = plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));
    plt.xticks(rotation=90);
    
    if i != 5:
        a2.get_xaxis().set_visible(False)

# %%
f.savefig("estrato.png")

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_TIENEINTERNET'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_TIENECOMPUTADOR'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_TIENECOMPUTADOR'
var2 = 'FAMI_TIENEINTERNET'

plt.figure(figsize=(16,4*5));
f.subplots_adjust(hspace=2.5);
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, hue=var2, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, hue=var2, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'FAMI_TIENEAUTOMOVIL'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_HORASSEMANATRABAJA'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    plt.xticks(rotation=90); 
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var)); 
    plt.xticks(rotation=90);

# %%
mod_list = [
    'MOD_RAZONA_CUANTITAT_PUNT',
    'MOD_LECTURA_CRITICA_PUNT',
    'MOD_COMPETEN_CIUDADA_PUNT',
    'MOD_INGLES_PUNT',
    'MOD_COMUNI_ESCRITA_PUNT',
]

var = 'ESTU_FECHANACIMIENTO'

plt.figure(figsize=(16,4*5));
for i, mod in enumerate(mod_list, 1):
    plt.subplot(5,2,i*2 - 1)
    plt.title('SaberPro: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberPro'].sort_values(by=var));
    
    plt.subplot(5,2,i*2)
    plt.title('SaberTyT: '+ mod + ' vs. ' + var);
    sns.boxplot(x=var, y=mod, data=df[df["PRUEBA"]=='SaberTyT'].sort_values(by=var));
