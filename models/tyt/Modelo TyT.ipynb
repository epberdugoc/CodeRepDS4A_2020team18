# %%
### Load relevant packages
import pandas                  as pd
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import statsmodels.formula.api as smf
import statsmodels.api         as sm
import scipy

# !pip install linearmodels

from linearmodels import PanelOLS
from linearmodels import RandomEffects
# Out:
# Requirement already satisfied: linearmodels in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (4.17)
# Requirement already satisfied: numpy>=1.15 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.18.1)
# Requirement already satisfied: patsy in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.5.1)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: scipy>=1 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.4.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.0.3)
# Requirement already satisfied: statsmodels>=0.9 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.11.1)
# Requirement already satisfied: Cython>=0.29.14 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.29.21)
# Requirement already satisfied: property-cached>=1.6.3 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: six in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from patsy->linearmodels) (1.14.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from pandas>=0.23->linearmodels) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from pandas>=0.23->linearmodels) (2.8.1)

# %%
datafinal = pd.read_csv('data-final-depurado.csv', encoding = "UTF-8")
# Out:
# C:\Users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
datafinal.columns
# Out:
# Index(['Unnamed: 0', 'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_SIMULACROTIPOICFES',
#        'ESTU_ACTIVIDADREFUERZOAREAS', 'ESTU_ACTIVIDADREFUERZOGENERIC',
#        'ESTU_TIPODOCUMENTOSB11', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_HORASSEMANATRABAJA',
#        'INST_COD_INSTITUCION', 'INST_NOMBRE_INSTITUCION',
#        'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_PRGM_DEPARTAMENTO', 'ESTU_NIVEL_PRGM_ACADEMICO',
#        'ESTU_METODO_PRGM', 'ESTU_NUCLEO_PREGRADO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_INST_DEPARTAMENTO',
#        'INST_CARACTER_ACADEMICO', 'INST_ORIGEN', 'ESTU_COD_MCPIO_PRESENTACION',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_DEPTO_PRESENTACION', 'MOD_RAZONA_CUANTITAT_PUNT',
#        'MOD_RAZONA_CUANTITATIVO_PNAL', 'MOD_LECTURA_CRITICA_PUNT',
#        'MOD_LECTURA_CRITICA_PNAL', 'MOD_COMPETEN_CIUDADA_PUNT',
#        'MOD_COMPETEN_CIUDADA_PNAL', 'MOD_INGLES_PUNT', 'MOD_INGLES_DESEM',
#        'MOD_INGLES_PNAL', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_COMUNI_ESCRITA_PNAL',
#        'ESTU_ESTADOINVESTIGACION', 'PERIODO-X', 'PRUEBA', 'TIPO_PRUEBA'],
#       dtype='object')

# %%
datafinal.head()
# Out:
#    Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0           0                 CC          COLOMBIA           F
# 1           1                 CC          COLOMBIA           M
# 2           2                 CC          COLOMBIA           F
# 3           3                 CC          COLOMBIA           M
# 4           4                 CC          COLOMBIA           M
#
#   ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0           24/11/1994    20163   EK201630197609      ESTUDIANTE
# 1           11/06/1991    20163   EK201630241417      ESTUDIANTE
# 2           22/02/1995    20163   EK201630080363      ESTUDIANTE
# 3           01/08/1994    20163   EK201630081694      ESTUDIANTE
# 4           18/08/1980    20163   EK201630079620      ESTUDIANTE
#
#   ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_INGLES_PUNT  \
# 0      CUNDINAMARCA                   25.0  ...           155.0
# 1            BOGOTA                   11.0  ...           153.0
# 2   NORTE SANTANDER                   54.0  ...           120.0
# 3            BOGOTA                   11.0  ...           214.0
# 4           BOLIVAR                   13.0  ...           184.0
#
#    MOD_INGLES_DESEM MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT  \
# 0                A2            62.0                   151.0
# 1                A2            59.0                   220.0
# 2               -A1            16.0                   162.0
# 3                B2            98.0                   112.0
# 4                B1            84.0                   158.0
#
#   MOD_COMUNI_ESCRITA_DESEM MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION  \
# 0                        3                    43.0                 PUBLICAR
# 1                        4                   100.0                 PUBLICAR
# 2                        3                    72.0                 PUBLICAR
# 3                        1                     8.0                 PUBLICAR
# 4                        3                    53.0                 PUBLICAR
#
#   PERIODO-X    PRUEBA TIPO_PRUEBA
# 0      2016  SaberPro      Normal
# 1      2016  SaberPro      Normal
# 2      2016  SaberPro      Normal
# 3      2016  SaberPro      Normal
# 4      2016  SaberPro      Normal
#
# [5 rows x 64 columns]

# %%
datafinal.shape
# Out:
# (1502154, 64)

# %%
for column in datafinal.columns:
    print(f'Column: {column}')
    print(datafinal[column].astype(str).sort_values().value_counts())
    print('\n')
# Out:
# Column: Unnamed: 0
# 3261      12
# 49352     12
# 37617     12
# 26918     12
# 35300     12
#           ..
# 252381     1
# 249426     1
# 249892     1
# 256869     1
# 251430     1
# Name: Unnamed: 0, Length: 260241, dtype: int64
#
#
# Column: ESTU_TIPODOCUMENTO
# CC     1474809
# TI       22811
# CR        2293
# CE        1905
# PE         264
# PC          66
# PEP          3
# NES          2
# V            1
# Name: ESTU_TIPODOCUMENTO, dtype: int64
#
#
# Column: ESTU_NACIONALIDAD
# COLOMBIA          1499749
# VENEZUELA             816
# ESTADOS UNIDOS        217
# ECUADOR               167
# FRANCIA               156
#                    ...
# SANTA LUCÍA             1
# INDIA                   1
# JAMAICA                 1
# ARGELIA                 1
# UCRANIA                 1
# Name: ESTU_NACIONALIDAD, Length: 91, dtype: int64
#
#
# Column: ESTU_GENERO
# F      857779
# M      644063
# ND        282
# nan        30
# Name: ESTU_GENERO, dtype: int64
#
#
# Column: ESTU_FECHANACIMIENTO
# 01/01/1900                862
# 10/10/1995                413
# 08/11/1994                410
# 09/08/1995                409
# 09/12/1994                407
#                          ...
# 1965-08-22T00:00:00         1
# 12/05/1962 12:00:00 AM      1
# 03/14/1969 12:00:00 AM      1
# 26/04/1961                  1
# 08/28/1964                  1
# Name: ESTU_FECHANACIMIENTO, Length: 51664, dtype: int64
#
#
# Column: PERIODO
# 20195    321127
# 20173    278802
# 20183    278685
# 20163    232466
# 20192    100920
# 20161    100765
# 20171     80246
# 20181     66702
# 20164     38923
# 20194      1826
# 20182      1079
# 20184       382
# 20196       231
# Name: PERIODO, dtype: int64
#
#
# Column: ESTU_CONSECUTIVO
# EK201830313327    1
# EK201830072114    1
# EK201610053995    1
# EK201630110897    1
# EK201950220940    1
#                  ..
# EK201630120293    1
# EK201730202234    1
# EK201830200237    1
# EK201730190904    1
# EK201610105615    1
# Name: ESTU_CONSECUTIVO, Length: 1502154, dtype: int64
#
#
# Column: ESTU_ESTUDIANTE
# ESTUDIANTE    1502154
# Name: ESTU_ESTUDIANTE, dtype: int64
#
#
# Column: ESTU_DEPTO_RESIDE
# BOGOTA             408728
# ANTIOQUIA          178677
# VALLE              120992
# CUNDINAMARCA        85416
# ATLANTICO           83625
# SANTANDER           77092
# BOLIVAR             53956
# nan                 49559
# TOLIMA              41336
# NORTE SANTANDER     39602
# BOYACA              34754
# CALDAS              30263
# RISARALDA           29628
# CORDOBA             28748
# NARIÑO              28676
# CAUCA               28595
# HUILA               28073
# META                25147
# MAGDALENA           23615
# CESAR               21340
# QUINDIO             19242
# SUCRE               17017
# LA GUAJIRA          13179
# CASANARE             7682
# CAQUETA              6993
# CHOCO                6601
# PUTUMAYO             6191
# ARAUCA               3039
# SAN ANDRES           1408
# GUAVIARE             1280
# VICHADA               458
# GUAINIA               443
# AMAZONAS              414
# VAUPES                228
# EXTRANJERO            157
# Name: ESTU_DEPTO_RESIDE, dtype: int64
#
#
# Column: ESTU_COD_RESIDE_DEPTO
# 11.0       408728
# 5.0        178677
# 76.0       120992
# 25.0        85416
# 8.0         83625
# 68.0        77092
# 13.0        53956
# nan         49559
# 73.0        41336
# 54.0        39602
# 15.0        34754
# 17.0        30263
# 66.0        29628
# 23.0        28748
# 52.0        28676
# 19.0        28595
# 41.0        28073
# 50.0        25147
# 47.0        23615
# 20.0        21340
# 63.0        19242
# 70.0        17017
# 44.0        13179
# 85.0         7682
# 18.0         6993
# 27.0         6601
# 86.0         6191
# 81.0         3039
# 88.0         1408
# 95.0         1280
# 99.0          458
# 94.0          443
# 91.0          414
# 97.0          228
# 99999.0       157
# Name: ESTU_COD_RESIDE_DEPTO, dtype: int64
#
#
# Column: ESTU_MCPIO_RESIDE
# BOGOTA                      408728
# MEDELLIN                     92768
# CALI                         71505
# BARRANQUILLA                 55114
# nan                          49559
#                              ...
# CARURU                           1
# YAVARATE                         1
# ROBERTO PAYAN (SAN JOSE)         1
# MEDIO ATRATO                     1
# ALTO BAUDO (PIE DE PATO)         1
# Name: ESTU_MCPIO_RESIDE, Length: 1091, dtype: int64
#
#
# Column: ESTU_COD_RESIDE_MCPIO
# 11001.0    408728
# 5001.0      92768
# 76001.0     71505
# 8001.0      55114
# nan         49559
#             ...
# 27425.0         1
# 94884.0         1
# 97161.0         1
# 91669.0         1
# 68370.0         1
# Name: ESTU_COD_RESIDE_MCPIO, Length: 1112, dtype: int64
#
#
# Column: ESTU_COLE_TERMINO
# -                                 457733
# nan                                77802
# 0.0                                34127
# ,                                  14447
# INST EDUC VILLA SANTANA            12094
#                                    ...
# CLAROS                                 1
# 3339.0                                 1
# SEDE 02 CAMILO TORRES RESTREPO         1
# CARRIZALITO ORTEGA                     1
# 69332.0                                1
# Name: ESTU_COLE_TERMINO, Length: 31709, dtype: int64
#
#
# Column: ESTU_VALORMATRICULAUNIVERSIDAD
# Entre 1 millón y menos de 2.5 millones      368861
# No pagó matrícula                           208273
# Entre 2.5 millones y menos de 4 millones    196818
# Entre 500 mil y menos de 1 millón           179368
# Menos de 500 mil                            156819
# Entre 4 millones y menos de 5.5 millones     90715
# No pago semestre                             59362
# Más de 7 millones                            58489
# -                                            53289
# Entre 5.5 millones y menos de 7 millones     47083
# Entre un millon y 3 millones de pesose       21654
# Entre 1 millón y menos de 3 millones         20180
# Mas de 7 millones                            17325
# Entre 500 mil y un millon de pesos            8784
# Menos de 500 mil pesos                        5269
# nan                                           4670
# Entre 3 y 5 millones                          2368
# Entre 3 millones y menos de 5 millones        2084
# Más de 5 millones                              503
# Entre 5 y 7 millones                           240
# Name: ESTU_VALORMATRICULAUNIVERSIDAD, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULABECA
# No     1136299
# Si      226177
# -       134811
# nan       4867
# Name: ESTU_PAGOMATRICULABECA, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULACREDITO
# No     988860
# Si     378135
# -      130335
# nan      4824
# Name: ESTU_PAGOMATRICULACREDITO, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULAPADRES
# No     735827
# Si     635421
# -      126127
# nan      4779
# Name: ESTU_PAGOMATRICULAPADRES, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULAPROPIO
# No     790906
# Si     578863
# -      127584
# nan      4801
# Name: ESTU_PAGOMATRICULAPROPIO, dtype: int64
#
#
# Column: ESTU_SIMULACROTIPOICFES
# -      998647
# nan    286215
# Si     113958
# No     103334
# Name: ESTU_SIMULACROTIPOICFES, dtype: int64
#
#
# Column: ESTU_ACTIVIDADREFUERZOAREAS
# -      998653
# nan    286222
# No     111353
# Si     105926
# Name: ESTU_ACTIVIDADREFUERZOAREAS, dtype: int64
#
#
# Column: ESTU_ACTIVIDADREFUERZOGENERIC
# -      998661
# nan    286222
# No     118775
# Si      98496
# Name: ESTU_ACTIVIDADREFUERZOGENERIC, dtype: int64
#
#
# Column: ESTU_TIPODOCUMENTOSB11
# TI     961288
# CC     445722
# nan     70969
# CR      21552
# CE       1819
# PE        690
# PC        114
# Name: ESTU_TIPODOCUMENTOSB11, dtype: int64
#
#
# Column: FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      310942
# Primaria incompleta                     289187
# Secundaria (Bachillerato) incompleta    180376
# Primaria completa                       165067
# Educación profesional completa          144621
# Técnica o tecnológica completa          123070
# Ninguno                                  66476
# Postgrado                                63144
# Técnica o tecnológica incompleta         44630
# nan                                      42198
# Educación profesional incompleta         41216
# No sabe                                  31227
# Name: FAMI_EDUCACIONPADRE, dtype: int64
#
#
# Column: FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      349673
# Primaria incompleta                     240021
# Secundaria (Bachillerato) incompleta    207402
# Primaria completa                       166402
# Técnica o tecnológica completa          164764
# Educación profesional completa          142978
# Postgrado                                64347
# Técnica o tecnológica incompleta         51857
# Educación profesional incompleta         37308
# Ninguno                                  36152
# nan                                      34778
# No sabe                                   6472
# Name: FAMI_EDUCACIONMADRE, dtype: int64
#
#
# Column: FAMI_ESTRATOVIVIENDA
# Estrato 2      552118
# Estrato 3      442073
# Estrato 1      283503
# Estrato 4      115033
# nan             44370
# Estrato 5       38555
# Estrato 6       19503
# Sin Estrato      4680
# Estrato 0        2165
# Zona Rural        154
# Name: FAMI_ESTRATOVIVIENDA, dtype: int64
#
#
# Column: FAMI_TIENEINTERNET
# Si     1179828
# No      289886
# nan      32440
# Name: FAMI_TIENEINTERNET, dtype: int64
#
#
# Column: FAMI_TIENECOMPUTADOR
# Si     1256366
# No      211426
# nan      34362
# Name: FAMI_TIENECOMPUTADOR, dtype: int64
#
#
# Column: FAMI_TIENELAVADORA
# Si     1218477
# No      249455
# nan      34222
# Name: FAMI_TIENELAVADORA, dtype: int64
#
#
# Column: FAMI_TIENEAUTOMOVIL
# No     1041278
# Si      425883
# nan      34993
# Name: FAMI_TIENEAUTOMOVIL, dtype: int64
#
#
# Column: ESTU_HORASSEMANATRABAJA
# Más de 30 horas        566685
# 0                      316181
# Entre 11 y 20 horas    217135
# Menos de 10 horas      167390
# Entre 21 y 30 horas    151743
# nan                     83020
# Name: ESTU_HORASSEMANATRABAJA, dtype: int64
#
#
# Column: INST_COD_INSTITUCION
# 9110     305753
# 2829      70701
# 4813      49054
# 2725      34827
# 2102      26808
#           ...
# 22376         8
# 9605          7
# 24612         6
# 90043         5
# 4705          4
# Name: INST_COD_INSTITUCION, Length: 409, dtype: int64
#
#
# Column: INST_NOMBRE_INSTITUCION
# SERVICIO NACIONAL DE APRENDIZAJE-SENA                                                              253338
# CORPORACION UNIVERSITARIA MINUTO DE DIOS -UNIMINUTO-BOGOTÁ D.C.                                     70701
# SERVICIO NACIONAL DE APRENDIZAJE-SENA-BOGOTÁ D.C.                                                   52415
# CORPORACION UNIFICADA NACIONAL DE EDUCACION SUPERIOR-CUN-BOGOTÁ D.C.                                49054
# POLITECNICO GRANCOLOMBIANO-BOGOTÁ D.C.                                                              34827
#                                                                                                     ...
# I. E. ESCUELA NORMAL SUPERIOR DE JERICO-JERICO                                                          6
# ESCUELA NORMAL SUPERIOR DEL NORDESTE-YOLOMBO                                                            5
# FUNDACION UNIVERSIDAD DE BOGOTA"-"JORGE TADEO LOZANO"-"-CARTAGENA                                       5
# FUNDACION CENTRO DE EDUCACION SUPERIOR,INVESTIGACION Y PROFESIONALIZACION -CEDINPRO-BOGOTÁ D.C.         4
# FUNDACION UNIVERSITARIA "-"MARIA CANO"-"-MEDELLIN                                                       3
# Name: INST_NOMBRE_INSTITUCION, Length: 445, dtype: int64
#
#
# Column: ESTU_PRGM_ACADEMICO
# ADMINISTRACION DE EMPRESAS                          78457
# DERECHO                                             75158
# CONTADURIA PUBLICA                                  63855
# INGENIERIA INDUSTRIAL                               41701
# PSICOLOGIA                                          41574
#                                                     ...
# TECNOLOGÍA EN LOGISTICA DE OPERACIONES                  1
# TECNOLOGO EN COMERCIO EXTERIOR                          1
# TECNICA PROFESIONAL EN PRODUCCION DE CAFE               1
# TECNOLOGÍA EN  GESTIÓN  COMERCIAL  INTERNACIONAL        1
# TECNICO PROFESIONAL EN FABRICACION DE PAPEL             1
# Name: ESTU_PRGM_ACADEMICO, Length: 2465, dtype: int64
#
#
# Column: ESTU_PRGM_CODMUNICIPIO
# 11001    607326
# 5001     142441
# 76001     75623
# 8001      73822
# 68001     54547
#           ...
# 66318         1
# 52227         1
# 25769         1
# 19212         1
# 5667          1
# Name: ESTU_PRGM_CODMUNICIPIO, Length: 348, dtype: int64
#
#
# Column: ESTU_PRGM_MUNICIPIO
# BOGOTÁ D.C.          457388
# BOGOTÁ, D.C.         149938
# MEDELLÍN             106482
# CALI                  75623
# BARRANQUILLA          73822
#                       ...
# PUERTO LIBERTADOR         1
# TRUJILLO                  1
# SUAN                      1
# SANTA ROSALÍA             1
# CANDELARIA                1
# Name: ESTU_PRGM_MUNICIPIO, Length: 399, dtype: int64
#
#
# Column: ESTU_PRGM_DEPARTAMENTO
# BOGOTA             447471
# ANTIOQUIA          188494
# BOGOTÁ             159855
# VALLE              102855
# ATLANTICO           79512
# SANTANDER           71853
# BOLIVAR             50746
# NORTE SANTANDER     39200
# CUNDINAMARCA        39194
# TOLIMA              31893
# CALDAS              29059
# BOYACA              28844
# RISARALDA           25874
# CAUCA               24247
# NARIÑO              22298
# HUILA               20262
# CORDOBA             19836
# QUINDIO             19498
# MAGDALENA           19486
# META                16811
# SUCRE               16148
# CESAR               15324
# LA GUAJIRA          10700
# CHOCO                6096
# CASANARE             4856
# CAQUETA              4704
# PUTUMAYO             3701
# ARAUCA               1345
# GUAVIARE              720
# SAN ANDRES            694
# GUAINIA               264
# VICHADA               190
# AMAZONAS               72
# VAUPES                 52
# Name: ESTU_PRGM_DEPARTAMENTO, dtype: int64
#
#
# Column: ESTU_NIVEL_PRGM_ACADEMICO
# UNIVERSITARIO          936889
# TECNOLOGÍA             482668
# TÉCNICO PROFESIONAL     82597
# Name: ESTU_NIVEL_PRGM_ACADEMICO, dtype: int64
#
#
# Column: ESTU_METODO_PRGM
# PRESENCIAL           1117528
# DISTANCIA             335134
# DISTANCIA VIRTUAL      49400
# SEMI-PRESENCIAL           92
# Name: ESTU_METODO_PRGM, dtype: int64
#
#
# Column: ESTU_NUCLEO_PREGRADO
# ADMINISTRACIÓN                                           392549
# CONTADURÍA PUBLICA                                       134828
# EDUCACIÓN                                                101092
# DERECHO Y AFINES                                          82072
# INGENIERÍA INDUSTRIAL Y AFINES                            74988
# INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES               72857
# PSICOLOGÍA                                                58167
# INGENIERÍA AMBIENTAL, SANITARIA Y AFINES                  51036
# ECONOMÍA                                                  47229
# INGENIERÍA CIVIL Y AFINES                                 44463
# INGENIERÍA MECÁNICA Y AFINES                              42008
# COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES                  28928
# DISEÑO                                                    28656
# MEDICINA                                                  27065
# INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES       26072
# SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES                       21692
# SALUD PÚBLICA                                             20409
# ARQUITECTURA                                              19826
# ENFERMERÍA                                                16674
# AGRONOMÍA                                                 16186
# INGENIERÍA ELÉCTRICA Y AFINES                             13735
# FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL     13122
# TERAPIAS                                                  11971
# BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS      9891
# ODONTOLOGÍA                                                9337
# INGENIERÍA QUÍMICA Y AFINES                                8816
# BIOLOGÍA, MICROBIOLOGÍA Y AFINES                           8203
# QUÍMICA Y AFINES                                           7433
# INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES              6771
# MEDICINA VETERINARIA                                       6498
# ARTES PLÁSTICAS, VISUALES Y AFINES                         6452
# CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES             6400
# OTRAS INGENIERÍAS                                          6217
# DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN                    6114
# ZOOTECNIA                                                  6054
# INGENIERÍA DE MINAS, METALURGIA Y AFINES                   5956
# PUBLICIDAD Y AFINES                                        5665
# GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES            5165
# NORMALES SUPERIORES                                        4973
# INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES                   4180
# INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES                     3942
# INGENIERÍA ADMINISTRATIVA Y AFINES                         3726
# OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES                   3442
# LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES         3286
# OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD        3271
# MÚSICA                                                     3144
# GEOGRAFÍA, HISTORIA                                        3027
# BACTERIOLOGÍA                                              2931
# INGENIERÍA BIOMÉDICA Y AFINES                              2778
# NUTRICIÓN Y DIETÉTICA                                      2487
# INSTRUMENTACIÓN QUIRÚRGICA                                 2433
# FILOSOFÍA, TEOLOGÍA Y AFINES                               2384
# MATEMÁTICAS, ESTADÍSTICA Y AFINES                          1788
# ANTROPOLOGÍA, ARTES LIBERALES                              1616
# ARTES REPRESENTATIVAS                                      1151
# FÍSICA                                                      998
# Name: ESTU_NUCLEO_PREGRADO, dtype: int64
#
#
# Column: ESTU_INST_CODMUNICIPIO
# 11001.0    833567
# 5001.0     124372
# 8001.0      68061
# 76001.0     65473
# 68001.0     55858
#             ...
# 5030.0         11
# 99001.0        10
# 5002.0          9
# 5368.0          6
# 5890.0          5
# Name: ESTU_INST_CODMUNICIPIO, Length: 132, dtype: int64
#
#
# Column: ESTU_INST_MUNICIPIO
# BOGOTÁ D.C.       618423
# BOGOTÁ, D.C.      215144
# MEDELLÍN           92660
# BARRANQUILLA       68061
# CALI               65473
#                    ...
# AMAGÁ                 11
# PUERTO CARREÑO        10
# ABEJORRAL              9
# JERICÓ                 6
# YOLOMBÓ                5
# Name: ESTU_INST_MUNICIPIO, Length: 151, dtype: int64
#
#
# Column: ESTU_INST_DEPARTAMENTO
# BOGOTÁ             833567
# ANTIOQUIA          141275
# VALLE               75809
# ATLANTICO           72285
# SANTANDER           62853
# BOLIVAR             42629
# NORTE SANTANDER     28451
# TOLIMA              26742
# CALDAS              23051
# BOYACA              21441
# CUNDINAMARCA        19859
# RISARALDA           19309
# NARIÑO              16987
# QUINDIO             16840
# CAUCA               16437
# MAGDALENA           16249
# SUCRE               13913
# CORDOBA             13141
# HUILA                9807
# LA GUAJIRA           7301
# CESAR                7089
# CHOCO                5604
# META                 4802
# CAQUETA              3846
# PUTUMAYO             1637
# CASANARE             1108
# SAN ANDRES             90
# ARAUCA                 22
# VICHADA                10
# Name: ESTU_INST_DEPARTAMENTO, dtype: int64
#
#
# Column: INST_CARACTER_ACADEMICO
# UNIVERSIDAD                  641490
# INSTITUCIÓN UNIVERSITARIA    405114
# INSTITUCIÓN TECNOLÓGICA      366853
# TÉCNICA PROFESIONAL           83724
# ESCUELA NORMAL SUPERIOR        4973
# Name: INST_CARACTER_ACADEMICO, dtype: int64
#
#
# Column: INST_ORIGEN
# OFICIAL NACIONAL            499247
# NO OFICIAL - CORPORACIÓN    420380
# NO OFICIAL - FUNDACIÓN      353449
# OFICIAL DEPARTAMENTAL       186867
# OFICIAL MUNICIPAL            30664
# REGIMEN ESPECIAL             11547
# Name: INST_ORIGEN, dtype: int64
#
#
# Column: ESTU_COD_MCPIO_PRESENTACION
# 11001    429901
# 5001     108507
# 76001     81089
# 8001      81068
# 68001     56040
#           ...
# 34            2
# 27075         1
# 13            1
# 15204         1
# 23807         1
# Name: ESTU_COD_MCPIO_PRESENTACION, Length: 163, dtype: int64
#
#
# Column: ESTU_MCPIO_PRESENTACION
# BOGOTÁ                     429901
# MEDELLÍN                   108507
# CALI                        81089
# BARRANQUILLA                81068
# BUCARAMANGA                 56040
#                             ...
# SAN JUAN DE PUERTO RICO         2
# LA HABANA                       1
# TIERRALTA                       1
# BAHÍA SOLANO                    1
# COMBITA                         1
# Name: ESTU_MCPIO_PRESENTACION, Length: 162, dtype: int64
#
#
# Column: ESTU_DEPTO_PRESENTACION
# BOGOTÁ                     429901
# ANTIOQUIA                  184998
# VALLE                      124760
# ATLANTICO                   87200
# CUNDINAMARCA                85985
#                             ...
# TEL AVIV                        4
# AUCKLAND                        4
# MONTEVIDEO                      3
# SAN JUAN DE PUERTO RICO         2
# LA HABANA                       1
# Name: ESTU_DEPTO_PRESENTACION, Length: 74, dtype: int64
#
#
# Column: ESTU_COD_DEPTO_PRESENTACION
# 11    429901
# 5     184998
# 76    124760
# 8      87200
# 25     85985
# 68     79089
# 13     54848
# 54     42075
# 73     39648
# 15     36181
# 17     33263
# 66     30889
# 19     28943
# 41     28763
# 52     28223
# 23     28121
# 50     26396
# 20     23958
# 47     23422
# 63     20499
# 70     17853
# 44      9909
# 85      7440
# 18      7256
# 27      6328
# 86      6226
# 0       2905
# 81      2818
# 95      1358
# 88      1309
# 99       465
# 94       460
# 91       417
# 97       248
# Name: ESTU_COD_DEPTO_PRESENTACION, dtype: int64
#
#
# Column: MOD_RAZONA_CUANTITAT_PUNT
# 147.0    21207
# 141.0    21012
# 144.0    21004
# 150.0    20910
# 138.0    20815
#          ...
# 252.0        1
# 250.5        1
# 253.5        1
# 244.0        1
# 245.0        1
# Name: MOD_RAZONA_CUANTITAT_PUNT, Length: 255, dtype: int64
#
#
# Column: MOD_RAZONA_CUANTITATIVO_PNAL
# 61.0    16046
# 63.0    16040
# 57.0    16014
# 55.0    15998
# 52.0    15984
#         ...
# 25.0    13788
# 22.0    13720
# 19.0    13695
# 13.0    13595
# nan       621
# Name: MOD_RAZONA_CUANTITATIVO_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_LECTURA_CRITICA_PUNT
# 150.0    21699
# 147.0    21630
# 153.0    21598
# 156.0    21352
# 144.0    21293
#          ...
# 253.5        2
# 242.0        1
# 34.5         1
# 255.0        1
# 55.0         1
# Name: MOD_LECTURA_CRITICA_PUNT, Length: 276, dtype: int64
#
#
# Column: MOD_LECTURA_CRITICA_PNAL
# 57.0    16091
# 53.0    16085
# 60.0    16074
# 51.0    16065
# 64.0    16062
#         ...
# 26.0    13875
# 18.0    13787
# 21.0    13785
# 24.0    13771
# nan       621
# Name: MOD_LECTURA_CRITICA_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_COMPETEN_CIUDADA_PUNT
# 153.0    19125
# 144.0    19052
# 150.0    19034
# 141.0    18993
# 156.0    18985
#          ...
# 250.5       12
# 253.5        4
# 56.0         3
# 55.5         3
# 255.0        1
# Name: MOD_COMPETEN_CIUDADA_PUNT, Length: 257, dtype: int64
#
#
# Column: MOD_COMPETEN_CIUDADA_PNAL
# 60.0    16097
# 56.0    16059
# 51.0    16048
# 66.0    16046
# 53.0    16037
#         ...
# 27.0    13847
# 30.0    13842
# 24.0    13779
# 21.0    13771
# nan       621
# Name: MOD_COMPETEN_CIUDADA_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_INGLES_PUNT
# 138.0    23689
# 141.0    23608
# 135.0    23386
# 132.0    22928
# 144.0    22859
#          ...
# 70.5        11
# 264.0        5
# 69.0         4
# 265.5        3
# 262.5        3
# Name: MOD_INGLES_PUNT, Length: 244, dtype: int64
#
#
# Column: MOD_INGLES_DESEM
# A1     483825
# A2     385173
# -A1    299763
# B1     244067
# B2      89326
# Name: MOD_INGLES_DESEM, dtype: int64
#
#
# Column: MOD_INGLES_PNAL
# 51.0    16150
# 55.0    16061
# 41.0    16057
# 39.0    16044
# 47.0    16023
#         ...
# 11.0    13701
# 15.0    13690
# 8.0     13576
# 5.0     13574
# nan       621
# Name: MOD_INGLES_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_PUNT
# 156.0    39351
# 159.0    37822
# 157.5    27426
# 162.0    26419
# 138.0    25273
#          ...
# 260.0        1
# 43.0         1
# 286.5        1
# 43.5         1
# 259.0        1
# Name: MOD_COMUNI_ESCRITA_PUNT, Length: 310, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_DESEM
# 2    567144
# 3    521331
# 4    221858
# 1    191821
# Name: MOD_COMUNI_ESCRITA_DESEM, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_PNAL
# 1.0     18402
# 56.0    17625
# 53.0    16929
# 59.0    16872
# 38.0    16855
#         ...
# 66.0    13633
# 54.0    13606
# 52.0    13591
# 49.0    13483
# nan       621
# Name: MOD_COMUNI_ESCRITA_PNAL, Length: 101, dtype: int64
#
#
# Column: ESTU_ESTADOINVESTIGACION
# PUBLICAR                                  1496326
# VALIDEZ OFICINA JURÍDICA                     3601
# PRESENTE CON LECTURA TARDIA                  1685
# NO SE COMPROBO IDENTIDAD DEL EXAMINADO        542
# Name: ESTU_ESTADOINVESTIGACION, dtype: int64
#
#
# Column: PERIODO-X
# 2019     252022
# 2016     232466
# 2017     226896
# 2018     225505
# 20191    100920
# 20161    100765
# 20171     80246
# 20192     71162
# 20181     66702
# 20182     54641
# 20172     51906
# 20162     38923
# Name: PERIODO-X, dtype: int64
#
#
# Column: PRUEBA
# SaberPro    936889
# SaberTyT    565265
# Name: PRUEBA, dtype: int64
#
#
# Column: TIPO_PRUEBA
# Normal          1397716
# Exterior         103825
# Extemporaneo        613
# Name: TIPO_PRUEBA, dtype: int64

# %%
datafinal['ESTU_NUCLEO_PREGRADO'].unique()
# Out:
# array(['ADMINISTRACIÓN', 'PSICOLOGÍA', 'ENFERMERÍA',
#        'INGENIERÍA QUÍMICA Y AFINES', 'EDUCACIÓN', 'ARQUITECTURA',
#        'INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES',
#        'COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES',
#        'INGENIERÍA ADMINISTRATIVA Y AFINES',
#        'INGENIERÍA BIOMÉDICA Y AFINES', 'INGENIERÍA INDUSTRIAL Y AFINES',
#        'INGENIERÍA AMBIENTAL, SANITARIA Y AFINES', 'DISEÑO',
#        'ARTES PLÁSTICAS, VISUALES Y AFINES', 'QUÍMICA Y AFINES',
#        'INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES',
#        'INGENIERÍA CIVIL Y AFINES', 'CONTADURÍA PUBLICA', 'TERAPIAS',
#        'MEDICINA', 'ECONOMÍA', 'INGENIERÍA MECÁNICA Y AFINES',
#        'GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#        'DERECHO Y AFINES', 'INGENIERÍA ELÉCTRICA Y AFINES',
#        'INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES',
#        'SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES',
#        'FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL',
#        'BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS',
#        'AGRONOMÍA', 'MEDICINA VETERINARIA', 'SALUD PÚBLICA',
#        'ODONTOLOGÍA', 'PUBLICIDAD Y AFINES', 'MÚSICA',
#        'OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD',
#        'CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES',
#        'INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#        'GEOGRAFÍA, HISTORIA', 'BACTERIOLOGÍA',
#        'BIOLOGÍA, MICROBIOLOGÍA Y AFINES',
#        'INGENIERÍA DE MINAS, METALURGIA Y AFINES',
#        'MATEMÁTICAS, ESTADÍSTICA Y AFINES',
#        'INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES',
#        'DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN', 'FÍSICA',
#        'INSTRUMENTACIÓN QUIRÚRGICA', 'ARTES REPRESENTATIVAS',
#        'LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES', 'ZOOTECNIA',
#        'OTRAS INGENIERÍAS', 'FILOSOFÍA, TEOLOGÍA Y AFINES',
#        'OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES',
#        'NUTRICIÓN Y DIETÉTICA', 'ANTROPOLOGÍA, ARTES LIBERALES',
#        'NORMALES SUPERIORES'], dtype=object)

# %%
datafinal['ESTU_PRGM_DEPARTAMENTO']=datafinal['ESTU_PRGM_DEPARTAMENTO'].replace('BOGOTÁ','BOGOTA')

# %%
datafinal['ESTU_PRGM_DEPARTAMENTO'].value_counts()
# Out:
# BOGOTA             607326
# ANTIOQUIA          188494
# VALLE              102855
# ATLANTICO           79512
# SANTANDER           71853
# BOLIVAR             50746
# NORTE SANTANDER     39200
# CUNDINAMARCA        39194
# TOLIMA              31893
# CALDAS              29059
# BOYACA              28844
# RISARALDA           25874
# CAUCA               24247
# NARIÑO              22298
# HUILA               20262
# CORDOBA             19836
# QUINDIO             19498
# MAGDALENA           19486
# META                16811
# SUCRE               16148
# CESAR               15324
# LA GUAJIRA          10700
# CHOCO                6096
# CASANARE             4856
# CAQUETA              4704
# PUTUMAYO             3701
# ARAUCA               1345
# GUAVIARE              720
# SAN ANDRES            694
# GUAINIA               264
# VICHADA               190
# AMAZONAS               72
# VAUPES                 52
# Name: ESTU_PRGM_DEPARTAMENTO, dtype: int64

# %%
datafinal['TIPO_PRUEBA'].unique()
# Out:
# array(['Normal', 'Exterior', 'Extemporaneo'], dtype=object)

# %%
# Let's filter the nan values for the column ESTU_VALORMATRICULAUNIVERSIDAD
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_VALORMATRICULAUNIVERSIDAD']=='nan') | (datafinal['ESTU_VALORMATRICULAUNIVERSIDAD']=='-')].index)
datafinal=datafinal.dropna(subset=['ESTU_VALORMATRICULAUNIVERSIDAD'])
datafinal['ESTU_VALORMATRICULAUNIVERSIDAD'].unique()
# Out:
# array(['Entre 1 millón y menos de 2.5 millones',
#        'Entre 500 mil y menos de 1 millón', 'Más de 7 millones',
#        'Entre 5.5 millones y menos de 7 millones',
#        'Entre 4 millones y menos de 5.5 millones', 'Menos de 500 mil',
#        'No pagó matrícula', 'Entre 2.5 millones y menos de 4 millones',
#        'Mas de 7 millones', 'Entre 1 millón y menos de 3 millones',
#        'Más de 5 millones', 'Entre 3 millones y menos de 5 millones',
#        'Entre un millon y 3 millones de pesose',
#        'Entre 500 mil y un millon de pesos', 'No pago semestre',
#        'Menos de 500 mil pesos', 'Entre 5 y 7 millones',
#        'Entre 3 y 5 millones'], dtype=object)

# %%
datafinal.shape
# Out:
# (1444195, 64)

# %%
datafinal=datafinal.dropna(subset=['ESTU_PAGOMATRICULABECA','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULAPADRES',\
                                    'ESTU_PAGOMATRICULAPROPIO','ESTU_SIMULACROTIPOICFES','ESTU_ACTIVIDADREFUERZOAREAS',\
                                    'ESTU_TIPODOCUMENTOSB11','FAMI_EDUCACIONPADRE','FAMI_EDUCACIONMADRE',\
                                    'FAMI_ESTRATOVIVIENDA','FAMI_TIENEINTERNET','FAMI_TIENECOMPUTADOR',\
                                    'FAMI_TIENELAVADORA','FAMI_TIENEAUTOMOVIL','ESTU_HORASSEMANATRABAJA',\
                                    'MOD_RAZONA_CUANTITATIVO_PNAL'])

# %%
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULABECA']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULACREDITO']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULAPADRES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULAPROPIO']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_SIMULACROTIPOICFES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_SIMULACROTIPOICFES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_ACTIVIDADREFUERZOAREAS']=='-')].index)

# %%
datafinal.shape
# Out:
# (116527, 64)

# %%
datafinal['PRUEBA'].value_counts()
# Out:
# SaberPro    77371
# SaberTyT    39156
# Name: PRUEBA, dtype: int64

# %%
datafinal['PERIODO-X'].value_counts()
# Out:
# 2019     26400
# 2018     17918
# 2017     17457
# 2016     15596
# 20161     7630
# 20191     7218
# 20192     6733
# 20181     5248
# 20182     4526
# 20172     3507
# 20162     2424
# 20171     1870
# Name: PERIODO-X, dtype: int64

# %%
datafinal[datafinal['PRUEBA']=='SaberTyT']['ESTU_NACIONALIDAD'].value_counts()
# Out:
# COLOMBIA                  39119
# VENEZUELA                    15
# ESTADOS UNIDOS                3
# PANAMÁ                        3
# BOLIVIA                       2
# ECUADOR                       2
# COREA DEL NORTE               2
# ESPAÑA                        2
# TERRITORIOS PALESTINOS        2
# CIUDAD DEL VATICANO           1
# REPÚBLICA DOMINICANA          1
# HAITI                         1
# COSTA RICA                    1
# ALAND                         1
# COMORAS                       1
# Name: ESTU_NACIONALIDAD, dtype: int64

# %% [markdown]
# **TYT + TODOS LOS PERIODOS + COLOMBIANOS**

# %%
# Filter by the two conditions
df_sabertyt=datafinal[(datafinal['PRUEBA']=='SaberTyT')&((datafinal['PERIODO-X']==20161)|(datafinal['PERIODO-X']==20162)\
                    |(datafinal['PERIODO-X']==20171)|(datafinal['PERIODO-X']==20172)\
                    |(datafinal['PERIODO-X']==20181)|(datafinal['PERIODO-X']==20182)\
                    |(datafinal['PERIODO-X']==20191)|(datafinal['PERIODO-X']==20192))\
                    &(datafinal['ESTU_NACIONALIDAD']=='COLOMBIA')]
len(df_sabertyt)
# Out:
# 39119

# %%
# Decision Tree Regresison

import pandas as pd
import pydotplus
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from io import StringIO
from IPython.display import Image, SVG
from graphviz import Source
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.patches import Patch
from scipy.stats import chi2_contingency, norm
from sklearn.tree import export_graphviz
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from statsmodels.formula.api import ols
from sympy import var, plot_implicit, Eq

# %% [markdown]
# **MOD_RAZONA_CUANTITAT_PUNT**

# %%
df_sabertyt['group_CUANTITATIVO'] = pd.cut(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-20-3cda9fd83d6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_CUANTITATIVO'] = pd.cut(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],

# %%
df_sabertyt.head()
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA           F
# 937046         165                 CC          COLOMBIA           F
# 937055         176                 CC          COLOMBIA           F
# 937060         181                 CC          COLOMBIA           M
# 937073         198                 CC          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_INGLES_DESEM  \
# 937022             VALLE                   76.0  ...              -A1
# 937046            BOGOTA                   11.0  ...               A2
# 937055              META                   50.0  ...               A2
# 937060         ATLANTICO                    8.0  ...               A2
# 937073         SANTANDER                   68.0  ...               B1
#
#         MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                   156.0                        3
# 937046             85.0                   180.0                        3
# 937055             76.0                   165.0                        3
# 937060             80.0                   205.5                        4
# 937073             87.0                   172.5                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                    53.0                 PUBLICAR     20161  SaberTyT
# 937046                    84.0                 PUBLICAR     20161  SaberTyT
# 937055                    67.0                 PUBLICAR     20161  SaberTyT
# 937060                    99.0                 PUBLICAR     20161  SaberTyT
# 937073                    78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 937022      Normal                 Q2
# 937046      Normal                 Q4
# 937055      Normal                 Q4
# 937060      Normal                 Q3
# 937073      Normal                 Q4
#
# [5 rows x 65 columns]

# %%
df_sabertyt.group_CUANTITATIVO.value_counts()
# Out:
# Q2    10154
# Q1    10011
# Q3     9629
# Q4     9321
# Name: group_CUANTITATIVO, dtype: int64

# %%
df_sabertyt["group_CUANTITATIVO"] = df_sabertyt["group_CUANTITATIVO"].astype('category')
df_sabertyt["ESTU_GENERO"] = df_sabertyt["ESTU_GENERO"].astype('category')
df_sabertyt["INST_ORIGEN"] = df_sabertyt["INST_ORIGEN"].astype('category')
df_sabertyt["FAMI_TIENEAUTOMOVIL"] = df_sabertyt["FAMI_TIENEAUTOMOVIL"].astype('category')
df_sabertyt["FAMI_TIENELAVADORA"] = df_sabertyt["FAMI_TIENELAVADORA"].astype('category')
df_sabertyt["FAMI_TIENECOMPUTADOR"] = df_sabertyt["FAMI_TIENECOMPUTADOR"].astype('category')
df_sabertyt["FAMI_TIENEINTERNET"] = df_sabertyt["FAMI_TIENEINTERNET"].astype('category')
df_sabertyt["FAMI_ESTRATOVIVIENDA"] = df_sabertyt["FAMI_ESTRATOVIVIENDA"].astype('category')
df_sabertyt["FAMI_EDUCACIONMADRE"] = df_sabertyt["FAMI_EDUCACIONMADRE"].astype('category')
df_sabertyt["FAMI_EDUCACIONPADRE"] = df_sabertyt["FAMI_EDUCACIONPADRE"].astype('category')
df_sabertyt["ESTU_METODO_PRGM"] = df_sabertyt["ESTU_METODO_PRGM"].astype('category')
df_sabertyt["INST_CARACTER_ACADEMICO"] = df_sabertyt["INST_CARACTER_ACADEMICO"].astype('category')
df_sabertyt["ESTU_HORASSEMANATRABAJA"] = df_sabertyt["ESTU_HORASSEMANATRABAJA"].astype('category')
df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"].astype('category')
df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"].astype('category')
df_sabertyt["ESTU_SIMULACROTIPOICFES"] = df_sabertyt["ESTU_SIMULACROTIPOICFES"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULAPROPIO"] = df_sabertyt["ESTU_PAGOMATRICULAPROPIO"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULAPADRES"] = df_sabertyt["ESTU_PAGOMATRICULAPADRES"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULACREDITO"] = df_sabertyt["ESTU_PAGOMATRICULACREDITO"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULABECA"] = df_sabertyt["ESTU_PAGOMATRICULABECA"].astype('category')
df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"] = df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"].astype('category')
df_sabertyt["ESTU_NUCLEO_PREGRADO"] = df_sabertyt["ESTU_NUCLEO_PREGRADO"].astype('category')
df_sabertyt["ESTU_PRGM_DEPARTAMENTO"] = df_sabertyt["ESTU_PRGM_DEPARTAMENTO"].astype('category')
df_sabertyt["PERIODO-X"] = df_sabertyt["PERIODO-X"].astype('category')
# Out:
# <ipython-input-25-39cc2f0721c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_CUANTITATIVO"] = df_sabertyt["group_CUANTITATIVO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_GENERO"] = df_sabertyt["ESTU_GENERO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["INST_ORIGEN"] = df_sabertyt["INST_ORIGEN"].astype('category')
# <ipython-input-25-39cc2f0721c2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENEAUTOMOVIL"] = df_sabertyt["FAMI_TIENEAUTOMOVIL"].astype('category')
# <ipython-input-25-39cc2f0721c2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENELAVADORA"] = df_sabertyt["FAMI_TIENELAVADORA"].astype('category')
# <ipython-input-25-39cc2f0721c2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENECOMPUTADOR"] = df_sabertyt["FAMI_TIENECOMPUTADOR"].astype('category')
# <ipython-input-25-39cc2f0721c2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENEINTERNET"] = df_sabertyt["FAMI_TIENEINTERNET"].astype('category')
# <ipython-input-25-39cc2f0721c2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_ESTRATOVIVIENDA"] = df_sabertyt["FAMI_ESTRATOVIVIENDA"].astype('category')
# <ipython-input-25-39cc2f0721c2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_EDUCACIONMADRE"] = df_sabertyt["FAMI_EDUCACIONMADRE"].astype('category')
# <ipython-input-25-39cc2f0721c2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_EDUCACIONPADRE"] = df_sabertyt["FAMI_EDUCACIONPADRE"].astype('category')
# <ipython-input-25-39cc2f0721c2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_METODO_PRGM"] = df_sabertyt["ESTU_METODO_PRGM"].astype('category')
# <ipython-input-25-39cc2f0721c2>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["INST_CARACTER_ACADEMICO"] = df_sabertyt["INST_CARACTER_ACADEMICO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_HORASSEMANATRABAJA"] = df_sabertyt["ESTU_HORASSEMANATRABAJA"].astype('category')
# <ipython-input-25-39cc2f0721c2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"].astype('category')
# <ipython-input-25-39cc2f0721c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"].astype('category')
# <ipython-input-25-39cc2f0721c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_SIMULACROTIPOICFES"] = df_sabertyt["ESTU_SIMULACROTIPOICFES"].astype('category')
# <ipython-input-25-39cc2f0721c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULAPROPIO"] = df_sabertyt["ESTU_PAGOMATRICULAPROPIO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULAPADRES"] = df_sabertyt["ESTU_PAGOMATRICULAPADRES"].astype('category')
# <ipython-input-25-39cc2f0721c2>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULACREDITO"] = df_sabertyt["ESTU_PAGOMATRICULACREDITO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULABECA"] = df_sabertyt["ESTU_PAGOMATRICULABECA"].astype('category')
# <ipython-input-25-39cc2f0721c2>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"] = df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"].astype('category')
# <ipython-input-25-39cc2f0721c2>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_NUCLEO_PREGRADO"] = df_sabertyt["ESTU_NUCLEO_PREGRADO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PRGM_DEPARTAMENTO"] = df_sabertyt["ESTU_PRGM_DEPARTAMENTO"].astype('category')
# <ipython-input-25-39cc2f0721c2>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["PERIODO-X"] = df_sabertyt["PERIODO-X"].astype('category')

# %%
df_sabertyt.head()
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA           F
# 937046         165                 CC          COLOMBIA           F
# 937055         176                 CC          COLOMBIA           F
# 937060         181                 CC          COLOMBIA           M
# 937073         198                 CC          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_INGLES_DESEM  \
# 937022             VALLE                   76.0  ...              -A1
# 937046            BOGOTA                   11.0  ...               A2
# 937055              META                   50.0  ...               A2
# 937060         ATLANTICO                    8.0  ...               A2
# 937073         SANTANDER                   68.0  ...               B1
#
#         MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                   156.0                        3
# 937046             85.0                   180.0                        3
# 937055             76.0                   165.0                        3
# 937060             80.0                   205.5                        4
# 937073             87.0                   172.5                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                    53.0                 PUBLICAR     20161  SaberTyT
# 937046                    84.0                 PUBLICAR     20161  SaberTyT
# 937055                    67.0                 PUBLICAR     20161  SaberTyT
# 937060                    99.0                 PUBLICAR     20161  SaberTyT
# 937073                    78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 937022      Normal                 Q2
# 937046      Normal                 Q4
# 937055      Normal                 Q4
# 937060      Normal                 Q3
# 937073      Normal                 Q4
#
# [5 rows x 65 columns]

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_CUANTITATIVO'])

# %%
df_sabertyt.shape
# Out:
# (39115, 65)

# %%
df_sabertyt.head()
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA           F
# 937046         165                 CC          COLOMBIA           F
# 937055         176                 CC          COLOMBIA           F
# 937060         181                 CC          COLOMBIA           M
# 937073         198                 CC          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_INGLES_DESEM  \
# 937022             VALLE                   76.0  ...              -A1
# 937046            BOGOTA                   11.0  ...               A2
# 937055              META                   50.0  ...               A2
# 937060         ATLANTICO                    8.0  ...               A2
# 937073         SANTANDER                   68.0  ...               B1
#
#         MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                   156.0                        3
# 937046             85.0                   180.0                        3
# 937055             76.0                   165.0                        3
# 937060             80.0                   205.5                        4
# 937073             87.0                   172.5                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                    53.0                 PUBLICAR     20161  SaberTyT
# 937046                    84.0                 PUBLICAR     20161  SaberTyT
# 937055                    67.0                 PUBLICAR     20161  SaberTyT
# 937060                    99.0                 PUBLICAR     20161  SaberTyT
# 937073                    78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 937022      Normal                 Q2
# 937046      Normal                 Q4
# 937055      Normal                 Q4
# 937060      Normal                 Q3
# 937073      Normal                 Q4
#
# [5 rows x 65 columns]

# %%
df_t=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t[var]=df_t[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t.head())
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA            0
# 937046         165                 CC          COLOMBIA            0
# 937055         176                 CC          COLOMBIA            0
# 937060         181                 CC          COLOMBIA            1
# 937073         198                 CC          COLOMBIA            0
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 937022             VALLE                   76.0              CALI
# 937046            BOGOTA                   11.0            BOGOTA
# 937055              META                   50.0     VILLAVICENCIO
# 937060         ATLANTICO                    8.0      BARRANQUILLA
# 937073         SANTANDER                   68.0       BUCARAMANGA
#
#         ESTU_COD_RESIDE_MCPIO  \
# 937022                76001.0
# 937046                11001.0
# 937055                50001.0
# 937060                 8001.0
# 937073                68001.0
#
#                                         ESTU_COLE_TERMINO  \
# 937022  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 937046   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 937055                                COLEGIO CORAZONISTA
# 937060                                           PABLO VI
# 937073                             I.E.R PEDRONEL DURANGO
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 937022                               8                       0
# 937046                               1                       0
# 937055                               1                       0
# 937060                               8                       0
# 937073                               1                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 937022                          0                         0
# 937046                          1                         0
# 937055                          1                         0
# 937060                          1                         0
# 937073                          1                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 937022                         1                        0
# 937046                         1                        0
# 937055                         1                        0
# 937060                         1                        0
# 937073                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 937022                            0                              0
# 937046                            0                              0
# 937055                            0                              0
# 937060                            0                              0
# 937073                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 937022                     CC                    8                    5
# 937046                     TI                    8                    5
# 937055                     TI                    5                    1
# 937060                     TI                    8                    7
# 937073                     TI                    8                    8
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 937022                     3                   0                     1
# 937046                     2                   1                     1
# 937055                     4                   1                     1
# 937060                     2                   0                     1
# 937073                     2                   1                     0
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 937022                   1                    0                        1
# 937046                   1                    0                        1
# 937055                   1                    1                        1
# 937060                   1                    0                        1
# 937073                   1                    0                        1
#
#         INST_COD_INSTITUCION  \
# 937022                  4109
# 937046                  4813
# 937055                  3712
# 937060                  3117
# 937073                  3201
#
#                                   INST_NOMBRE_INSTITUCION  \
# 937022  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 937046  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 937055  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 937060             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 937073     UNIDADES TECNOLOGICAS DE SANTANDER-BUCARAMANGA
#
#                                       ESTU_PRGM_ACADEMICO  \
# 937022           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 937046   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 937055                           TECNOLOGIA EN INDUSTRIAL
# 937060  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 937073              TECNOLOGIA EN CONTABILIDAD FINANCIERA
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 937022                   76001                CALI                      29
# 937046                   11001        BOGOTÁ, D.C.                       3
# 937055                   50001       VILLAVICENCIO                      19
# 937060                    8758             SOLEDAD                       2
# 937073                   68001         BUCARAMANGA                      26
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 937022       TÉCNICO PROFESIONAL                 2                    46
# 937046       TÉCNICO PROFESIONAL                 2                    30
# 937055                TECNOLOGÍA                 2                    32
# 937060                TECNOLOGÍA                 2                    30
# 937073                TECNOLOGÍA                 2                     0
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 937022                 76001.0                CALI                  VALLE
# 937046                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937055                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937060                  8758.0             SOLEDAD              ATLANTICO
# 937073                 68001.0         BUCARAMANGA              SANTANDER
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 937022                        3            4                        76001
# 937046                        3            0                        11001
# 937055                        1            1                        50001
# 937060                        2            4                         8001
# 937073                        1            2                        68001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 937022                    CALI                   VALLE
# 937046                  BOGOTÁ                  BOGOTÁ
# 937055           VILLAVICENCIO                    META
# 937060            BARRANQUILLA               ATLANTICO
# 937073             BUCARAMANGA               SANTANDER
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 937022                           76                      136.5
# 937046                           11                      192.0
# 937055                           50                      166.5
# 937060                            8                      154.5
# 937073                           68                      174.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 937022                          34.0                     145.5
# 937046                          92.0                     187.5
# 937055                          70.0                     132.0
# 937060                          55.0                     205.5
# 937073                          78.0                     178.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 937022                      45.0                      148.5
# 937046                      89.0                      199.5
# 937055                      28.0                      142.5
# 937060                      97.0                      207.0
# 937073                      83.0                      160.5
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 937022                       47.0            120.0              -A1
# 937046                       96.0            181.5               A2
# 937055                       39.0            169.5               A2
# 937060                       98.0            174.0               A2
# 937073                       62.0            186.0               B1
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                    156.0                         3
# 937046             85.0                    180.0                         3
# 937055             76.0                    165.0                         3
# 937060             80.0                    205.5                         4
# 937073             87.0                    172.5                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 937022      Normal                 Q2
# 937046      Normal                 Q4
# 937055      Normal                 Q4
# 937060      Normal                 Q3
# 937073      Normal                 Q4

# %%
# That's just for classification
#clf = DecisionTreeClassifier(criterion = "entropy", splitter = "random", max_depth = 10,  min_samples_split = 100, min_samples_leaf = 5, max_features = 10)
#clf=DecisionTreeClassifier(criterion = "gini", splitter = "random", max_depth = 10)
#clf = RandomForestClassifier(criterion = "entropy",  max_depth = 10,  min_samples_split = 1000,min_samples_leaf = 20, max_features = 10)
#clf_new =RandomForestClassifier(criterion = "entropy", max_depth = 12, max_features = 4)

# %%
# Train Decision Tree Classifer
covariates=['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO','PERIODO-X']

# %%
len(covariates)
# Out:
# 23

# %%
# Metricas

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(df_t[covariates],
                                                    df_t['MOD_RAZONA_CUANTITAT_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train shape: ', X_train.shape)
print('X_test shape: ', X_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (29336, 23)
# X_test shape:  (9779, 23)
# y_train shape:  (29336,)
# y_test shape:  (9779,)

# %%
X_train
# Out:
#          ESTU_GENERO  INST_ORIGEN  FAMI_TIENEAUTOMOVIL  FAMI_TIENELAVADORA  \
# 1032818            0            0                    0                   0
# 1236906            0            1                    0                   1
# 1280185            1            4                    1                   1
# 1040033            0            0                    0                   0
# 1464547            0            1                    0                   1
# ...              ...          ...                  ...                 ...
# 1431476            1            1                    0                   1
# 1231560            0            4                    0                   1
# 1318194            0            4                    1                   1
# 1453064            0            4                    0                   0
# 1367305            1            4                    1                   1
#
#          FAMI_TIENECOMPUTADOR  FAMI_TIENEINTERNET  FAMI_ESTRATOVIVIENDA  \
# 1032818                     0                   0                     1
# 1236906                     1                   1                     4
# 1280185                     1                   1                     3
# 1040033                     1                   0                     1
# 1464547                     1                   1                     1
# ...                       ...                 ...                   ...
# 1431476                     1                   1                     3
# 1231560                     1                   1                     3
# 1318194                     1                   1                     2
# 1453064                     1                   1                     1
# 1367305                     1                   1                     2
#
#          FAMI_EDUCACIONMADRE  FAMI_EDUCACIONPADRE  ESTU_METODO_PRGM  ...  \
# 1032818                    6                    6                 0  ...
# 1236906                    7                    7                 2  ...
# 1280185                    0                    8                 2  ...
# 1040033                    6                    6                 1  ...
# 1464547                   10                    0                 0  ...
# ...                      ...                  ...               ...  ...
# 1431476                    7                    9                 1  ...
# 1231560                    8                    8                 0  ...
# 1318194                    1                    0                 0  ...
# 1453064                    7                    5                 2  ...
# 1367305                    7                    8                 2  ...
#
#          ESTU_ACTIVIDADREFUERZOAREAS  ESTU_SIMULACROTIPOICFES  \
# 1032818                            0                        0
# 1236906                            1                        1
# 1280185                            0                        1
# 1040033                            1                        1
# 1464547                            1                        1
# ...                              ...                      ...
# 1431476                            1                        1
# 1231560                            1                        0
# 1318194                            1                        1
# 1453064                            1                        1
# 1367305                            1                        1
#
#          ESTU_PAGOMATRICULAPROPIO  ESTU_PAGOMATRICULAPADRES  \
# 1032818                         1                         0
# 1236906                         0                         1
# 1280185                         0                         1
# 1040033                         1                         0
# 1464547                         0                         0
# ...                           ...                       ...
# 1431476                         0                         0
# 1231560                         0                         0
# 1318194                         0                         0
# 1453064                         0                         0
# 1367305                         0                         0
#
#          ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULABECA  \
# 1032818                          1                       0
# 1236906                          1                       0
# 1280185                          0                       0
# 1040033                          0                       0
# 1464547                          0                       1
# ...                            ...                     ...
# 1431476                          0                       1
# 1231560                          0                       0
# 1318194                          0                       0
# 1453064                          0                       1
# 1367305                          0                       1
#
#          ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PRGM_DEPARTAMENTO  \
# 1032818                               1                       3
# 1236906                               0                       4
# 1280185                               8                      24
# 1040033                              12                      26
# 1464547                              17                      18
# ...                                 ...                     ...
# 1431476                              17                       6
# 1231560                              17                       3
# 1318194                              17                       3
# 1453064                              17                      29
# 1367305                              16                       3
#
#          ESTU_NUCLEO_PREGRADO  PERIODO-X
# 1032818                    10      20161
# 1236906                     0      20181
# 1280185                    32      20182
# 1040033                    45      20162
# 1464547                     0      20192
# ...                       ...        ...
# 1431476                    29      20192
# 1231560                     0      20181
# 1318194                     0      20182
# 1453064                    25      20192
# 1367305                    33      20191
#
# [29336 rows x 23 columns]

# %%
X_test
# Out:
#          ESTU_GENERO  INST_ORIGEN  FAMI_TIENEAUTOMOVIL  FAMI_TIENELAVADORA  \
# 1491654            1            4                    0                   1
# 1392560            1            4                    0                   1
# 1375137            0            4                    0                   1
# 1026135            1            1                    0                   1
# 1500943            1            2                    0                   1
# ...              ...          ...                  ...                 ...
# 994189             1            1                    0                   1
# 1168121            0            4                    1                   1
# 1277426            1            5                    1                   1
# 1008126            0            4                    1                   1
# 1392761            1            0                    0                   1
#
#          FAMI_TIENECOMPUTADOR  FAMI_TIENEINTERNET  FAMI_ESTRATOVIVIENDA  \
# 1491654                     1                   1                     2
# 1392560                     1                   0                     2
# 1375137                     1                   1                     2
# 1026135                     1                   1                     1
# 1500943                     0                   0                     1
# ...                       ...                 ...                   ...
# 994189                      1                   0                     2
# 1168121                     1                   1                     4
# 1277426                     1                   1                     3
# 1008126                     1                   1                     2
# 1392761                     1                   1                     2
#
#          FAMI_EDUCACIONMADRE  FAMI_EDUCACIONPADRE  ESTU_METODO_PRGM  ...  \
# 1491654                    5                    5                 2  ...
# 1392560                    7                    5                 2  ...
# 1375137                    5                    5                 2  ...
# 1026135                    7                    8                 0  ...
# 1500943                    8                    1                 2  ...
# ...                      ...                  ...               ...  ...
# 994189                     5                    8                 2  ...
# 1168121                    0                    0                 2  ...
# 1277426                   10                   10                 2  ...
# 1008126                    8                    8                 0  ...
# 1392761                    8                    6                 2  ...
#
#          ESTU_ACTIVIDADREFUERZOAREAS  ESTU_SIMULACROTIPOICFES  \
# 1491654                            1                        1
# 1392560                            1                        1
# 1375137                            0                        0
# 1026135                            0                        0
# 1500943                            1                        1
# ...                              ...                      ...
# 994189                             0                        0
# 1168121                            1                        1
# 1277426                            1                        1
# 1008126                            0                        0
# 1392761                            1                        1
#
#          ESTU_PAGOMATRICULAPROPIO  ESTU_PAGOMATRICULAPADRES  \
# 1491654                         0                         1
# 1392560                         0                         0
# 1375137                         0                         0
# 1026135                         0                         0
# 1500943                         0                         1
# ...                           ...                       ...
# 994189                          1                         0
# 1168121                         0                         1
# 1277426                         0                         1
# 1008126                         1                         0
# 1392761                         1                         0
#
#          ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULABECA  \
# 1491654                          0                       0
# 1392560                          0                       0
# 1375137                          0                       0
# 1026135                          1                       0
# 1500943                          0                       0
# ...                            ...                     ...
# 994189                           0                       1
# 1168121                          0                       0
# 1277426                          0                       0
# 1008126                          0                       0
# 1392761                          1                       0
#
#          ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PRGM_DEPARTAMENTO  \
# 1491654                               0                      27
# 1392560                              16                      13
# 1375137                              16                       3
# 1026135                               8                       4
# 1500943                              12                       2
# ...                                 ...                     ...
# 994189                                1                      29
# 1168121                               2                       3
# 1277426                               8                      24
# 1008126                               8                       3
# 1392761                               4                       3
#
#          ESTU_NUCLEO_PREGRADO  PERIODO-X
# 1491654                    17      20192
# 1392560                     2      20191
# 1375137                    22      20191
# 1026135                     0      20161
# 1500943                     2      20192
# ...                       ...        ...
# 994189                     32      20161
# 1168121                     0      20172
# 1277426                     0      20182
# 1008126                     0      20161
# 1392761                    14      20191
#
# [9779 rows x 23 columns]

# %%
# Create the Regression model with Random Forest
RandomforestRegModel= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred=RandomforestRegModel.predict(X_test)

# %%
y_pred
# Out:
# array([119.68278201, 129.97893115, 136.57841196, ..., 128.88231704,
#        157.0281776 , 148.84639547])

# %%
y_test
# Out:
# 1491654    129.0
# 1392560    124.5
# 1375137    181.5
# 1026135    154.5
# 1500943    145.5
#            ...
# 994189     145.5
# 1168121     78.0
# 1277426    181.5
# 1008126    175.5
# 1392761    139.5
# Name: MOD_RAZONA_CUANTITAT_PUNT, Length: 9779, dtype: float64

# %%
#MOD_RAZONA_CUANTITAT_PUNT
comparar=pd.DataFrame(y_pred, y_test)
comparar.head(20)
# Out:
#                                     0
# MOD_RAZONA_CUANTITAT_PUNT
# 129.0                      119.682782
# 124.5                      129.978931
# 181.5                      136.578412
# 154.5                      154.408806
# 145.5                      128.636122
# 202.5                      145.964150
# 148.5                      125.634142
# 115.5                      130.358460
# 144.0                      138.572335
# 105.0                      125.826539
# 139.5                      126.068691
# 88.5                       166.178915
# 94.5                       137.848989
# 190.5                      155.391603
# 70.5                       139.916200
# 172.5                      127.476045
# 180.0                      161.017250
# 123.0                      120.436131
# 144.0                      136.559991
# 151.5                      133.736471

# %%
import statsmodels.api as sm
res = y_pred-y_test # residuals
#print(res)
fig=sm.qqplot(res,fit=True, line='45')

# %%
#Evaluate the Random forest regression model

# %%
def MAE(prediction,true_values):
    return np.mean(                                                      # Mean
                np.abs(                                                   # Absolute
                        prediction-true_values                            # Error
                    )
                )

# %%
def RMSE(prediction,true_values):
    
    return np.sqrt(                                                          # Root
            np.mean(                                                      # Mean
                np.square(                                                # Squared
                         prediction-true_values                           # Error
                )
            )
        )

# %%
def MAPE(prediction,true_value):
    return np.mean(                                           # Mean
        np.abs(                                               # Absolute
               (prediction-true_value)/true_value             # Error
            )*100                                            # Percentage
    )

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model RAZON CUANTI', MAE(y_pred,y_test))
print('RMSE of the model RAZON CUANTI', RMSE(y_pred,y_test))
print('MAPE of the model RAZON CUANTI', MAPE(y_pred,y_test))
print('Accuracy of the model RAZON CUANTI', 100-MAPE(y_pred,y_test))
# Out:
# MAE of the model RAZON CUANTI 23.686978377207975
# RMSE of the model RAZON CUANTI 29.30821850198474
# MAPE of the model RAZON CUANTI 18.681967709889538
# Accuracy of the model RAZON CUANTI 81.31803229011047

# %%
# Important variables

feature_list= list(df_t[covariates].columns)
# Get numerical feature importances
importances = list(RandomforestRegModel.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_RAZONA_CUANTITAT_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# MOD_RAZONA_CUANTITAT_PUNT
#
# Variable: PERIODO-X            Importance: 0.59
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.1
# Variable: ESTU_HORASSEMANATRABAJA Importance: 0.08
# Variable: ESTU_GENERO          Importance: 0.06
# Variable: FAMI_TIENEINTERNET   Importance: 0.03
# Variable: INST_ORIGEN          Importance: 0.02
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.02
# Variable: ESTU_METODO_PRGM     Importance: 0.02
# Variable: FAMI_TIENECOMPUTADOR Importance: 0.01
# Variable: FAMI_EDUCACIONMADRE  Importance: 0.01
# Variable: INST_CARACTER_ACADEMICO Importance: 0.01
# Variable: ESTU_SIMULACROTIPOICFES Importance: 0.01
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.01
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.01
# Variable: FAMI_TIENEAUTOMOVIL  Importance: 0.0
# Variable: FAMI_TIENELAVADORA   Importance: 0.0
# Variable: FAMI_EDUCACIONPADRE  Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOGENERIC Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOAREAS Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPROPIO Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPADRES Importance: 0.0
# Variable: ESTU_PAGOMATRICULACREDITO Importance: 0.0
# Variable: ESTU_PAGOMATRICULABECA Importance: 0.0

# %% [markdown]
# **QUANTILES**

# %%
df_sabertyt
# Out:
#          Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022          140                 CC          COLOMBIA           F
# 937046          165                 CC          COLOMBIA           F
# 937055          176                 CC          COLOMBIA           F
# 937060          181                 CC          COLOMBIA           M
# 937073          198                 CC          COLOMBIA           F
# ...             ...                ...               ...         ...
# 1502148       76347                 CC          COLOMBIA           M
# 1502149       76348                 CC          COLOMBIA           M
# 1502150       76349                 CC          COLOMBIA           M
# 1502151       76350                 CC          COLOMBIA           M
# 1502152       76351                 CC          COLOMBIA           M
#
#            ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022               22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046               01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055               08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060               03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073               04/02/1996    20161   EK201610096299      ESTUDIANTE
# ...                         ...      ...              ...             ...
# 1502148  05/28/1996 12:00:00 AM    20195   EK201950042257      ESTUDIANTE
# 1502149  10/04/1998 12:00:00 AM    20195   EK201950042514      ESTUDIANTE
# 1502150  06/19/1999 12:00:00 AM    20195   EK201950044146      ESTUDIANTE
# 1502151  10/08/1998 12:00:00 AM    20195   EK201950042208      ESTUDIANTE
# 1502152  08/28/1997 12:00:00 AM    20195   EK201950042462      ESTUDIANTE
#
#         ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_INGLES_DESEM  \
# 937022              VALLE                   76.0  ...              -A1
# 937046             BOGOTA                   11.0  ...               A2
# 937055               META                   50.0  ...               A2
# 937060          ATLANTICO                    8.0  ...               A2
# 937073          SANTANDER                   68.0  ...               B1
# ...                   ...                    ...  ...              ...
# 1502148            BOYACA                   15.0  ...               A1
# 1502149            BOYACA                   15.0  ...               A2
# 1502150            BOYACA                   15.0  ...              -A1
# 1502151            BOYACA                   15.0  ...               A2
# 1502152            BOYACA                   15.0  ...               A1
#
#          MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 937022              17.0                   156.0                        3
# 937046              85.0                   180.0                        3
# 937055              76.0                   165.0                        3
# 937060              80.0                   205.5                        4
# 937073              87.0                   172.5                        3
# ...                  ...                     ...                      ...
# 1502148             45.0                   108.0                        1
# 1502149             86.0                   220.5                        4
# 1502150             21.0                   205.5                        4
# 1502151             65.0                   151.5                        2
# 1502152             42.0                   192.0                        4
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
# ...                         ...                      ...       ...       ...
# 1502148                     6.0                 PUBLICAR     20192  SaberTyT
# 1502149                    92.0                 PUBLICAR     20192  SaberTyT
# 1502150                    90.0                 PUBLICAR     20192  SaberTyT
# 1502151                    40.0                 PUBLICAR     20192  SaberTyT
# 1502152                    83.0                 PUBLICAR     20192  SaberTyT
#
#         TIPO_PRUEBA group_CUANTITATIVO
# 937022       Normal                 Q2
# 937046       Normal                 Q4
# 937055       Normal                 Q4
# 937060       Normal                 Q3
# 937073       Normal                 Q4
# ...             ...                ...
# 1502148      Normal                 Q3
# 1502149      Normal                 Q3
# 1502150      Normal                 Q1
# 1502151      Normal                 Q4
# 1502152      Normal                 Q3
#
# [39115 rows x 65 columns]

# %%
df_sabertyt['group_LECTURA'] = pd.cut(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-76-3ab50f97c578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_LECTURA'] = pd.cut(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],

# %%
df_sabertyt['group_COMPETENCIA'] = pd.cut(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-78-580097de9e69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_COMPETENCIA'] = pd.cut(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],

# %%
df_sabertyt['group_INGLES'] = pd.cut(df_sabertyt['MOD_INGLES_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_INGLES_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-80-5b2e87977d2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_INGLES'] = pd.cut(df_sabertyt['MOD_INGLES_PUNT'],

# %%
df_sabertyt['group_ESCRITA'] = pd.cut(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-82-30f65de58e8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_ESCRITA'] = pd.cut(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],

# %%
df_sabertyt
# Out:
#          Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022          140                 CC          COLOMBIA           F
# 937046          165                 CC          COLOMBIA           F
# 937055          176                 CC          COLOMBIA           F
# 937060          181                 CC          COLOMBIA           M
# 937073          198                 CC          COLOMBIA           F
# ...             ...                ...               ...         ...
# 1502148       76347                 CC          COLOMBIA           M
# 1502149       76348                 CC          COLOMBIA           M
# 1502150       76349                 CC          COLOMBIA           M
# 1502151       76350                 CC          COLOMBIA           M
# 1502152       76351                 CC          COLOMBIA           M
#
#            ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022               22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046               01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055               08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060               03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073               04/02/1996    20161   EK201610096299      ESTUDIANTE
# ...                         ...      ...              ...             ...
# 1502148  05/28/1996 12:00:00 AM    20195   EK201950042257      ESTUDIANTE
# 1502149  10/04/1998 12:00:00 AM    20195   EK201950042514      ESTUDIANTE
# 1502150  06/19/1999 12:00:00 AM    20195   EK201950044146      ESTUDIANTE
# 1502151  10/08/1998 12:00:00 AM    20195   EK201950042208      ESTUDIANTE
# 1502152  08/28/1997 12:00:00 AM    20195   EK201950042462      ESTUDIANTE
#
#         ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_COMUNI_ESCRITA_PNAL  \
# 937022              VALLE                   76.0  ...                    53.0
# 937046             BOGOTA                   11.0  ...                    84.0
# 937055               META                   50.0  ...                    67.0
# 937060          ATLANTICO                    8.0  ...                    99.0
# 937073          SANTANDER                   68.0  ...                    78.0
# ...                   ...                    ...  ...                     ...
# 1502148            BOYACA                   15.0  ...                     6.0
# 1502149            BOYACA                   15.0  ...                    92.0
# 1502150            BOYACA                   15.0  ...                    90.0
# 1502151            BOYACA                   15.0  ...                    40.0
# 1502152            BOYACA                   15.0  ...                    83.0
#
#          ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA TIPO_PRUEBA  \
# 937022                   PUBLICAR     20161  SaberTyT      Normal
# 937046                   PUBLICAR     20161  SaberTyT      Normal
# 937055                   PUBLICAR     20161  SaberTyT      Normal
# 937060                   PUBLICAR     20161  SaberTyT      Normal
# 937073                   PUBLICAR     20161  SaberTyT      Normal
# ...                           ...       ...       ...         ...
# 1502148                  PUBLICAR     20192  SaberTyT      Normal
# 1502149                  PUBLICAR     20192  SaberTyT      Normal
# 1502150                  PUBLICAR     20192  SaberTyT      Normal
# 1502151                  PUBLICAR     20192  SaberTyT      Normal
# 1502152                  PUBLICAR     20192  SaberTyT      Normal
#
#         group_CUANTITATIVO group_LECTURA group_COMPETENCIA group_INGLES  \
# 937022                  Q2            Q2                Q3           Q1
# 937046                  Q4            Q4                Q4           Q4
# 937055                  Q4            Q2                Q2           Q3
# 937060                  Q3            Q4                Q4           Q4
# 937073                  Q4            Q4                Q3           Q4
# ...                    ...           ...               ...          ...
# 1502148                 Q3            Q2                Q4           Q2
# 1502149                 Q3            Q2                Q1           Q4
# 1502150                 Q1            Q2                Q3           Q1
# 1502151                 Q4            Q4                Q4           Q3
# 1502152                 Q3            Q2                Q1           Q2
#
#         group_ESCRITA
# 937022             Q3
# 937046             Q4
# 937055             Q3
# 937060             Q4
# 937073             Q4
# ...               ...
# 1502148            Q1
# 1502149            Q4
# 1502150            Q4
# 1502151            Q2
# 1502152            Q4
#
# [39115 rows x 69 columns]

# %%
df_sabertyt["group_LECTURA"] = df_sabertyt["group_LECTURA"].astype('category')
df_sabertyt["group_COMPETENCIA"] = df_sabertyt["group_COMPETENCIA"].astype('category')
df_sabertyt["group_INGLES"] = df_sabertyt["group_INGLES"].astype('category')
df_sabertyt["group_ESCRITA"] = df_sabertyt["group_ESCRITA"].astype('category')
# Out:
# <ipython-input-86-f309d7b3cc30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_LECTURA"] = df_sabertyt["group_LECTURA"].astype('category')
# <ipython-input-86-f309d7b3cc30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_COMPETENCIA"] = df_sabertyt["group_COMPETENCIA"].astype('category')
# <ipython-input-86-f309d7b3cc30>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_INGLES"] = df_sabertyt["group_INGLES"].astype('category')
# <ipython-input-86-f309d7b3cc30>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_ESCRITA"] = df_sabertyt["group_ESCRITA"].astype('category')

# %%
df_sabertyt.dtypes
# Out:
# Unnamed: 0                 int64
# ESTU_TIPODOCUMENTO        object
# ESTU_NACIONALIDAD         object
# ESTU_GENERO             category
# ESTU_FECHANACIMIENTO      object
#                           ...
# group_CUANTITATIVO      category
# group_LECTURA           category
# group_COMPETENCIA       category
# group_INGLES            category
# group_ESCRITA           category
# Length: 69, dtype: object

# %%
df_sabertyt.shape
# Out:
# (39115, 69)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_LECTURA'])

# %%
df_sabertyt.shape
# Out:
# (39113, 69)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_COMPETENCIA'])

# %%
df_sabertyt.shape
# Out:
# (39107, 69)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_INGLES'])

# %%
df_sabertyt.shape
# Out:
# (39067, 69)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_ESCRITA'])

# %%
df_sabertyt.shape
# Out:
# (38781, 69)

# %% [markdown]
# **MOD_LECTURA_CRITICA_PUNT**

# %%
df_sabertyt.head()
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA           F
# 937046         165                 CC          COLOMBIA           F
# 937055         176                 CC          COLOMBIA           F
# 937060         181                 CC          COLOMBIA           M
# 937073         198                 CC          COLOMBIA           F
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO  ... MOD_COMUNI_ESCRITA_PNAL  \
# 937022             VALLE                   76.0  ...                    53.0
# 937046            BOGOTA                   11.0  ...                    84.0
# 937055              META                   50.0  ...                    67.0
# 937060         ATLANTICO                    8.0  ...                    99.0
# 937073         SANTANDER                   68.0  ...                    78.0
#
#         ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA TIPO_PRUEBA  \
# 937022                  PUBLICAR     20161  SaberTyT      Normal
# 937046                  PUBLICAR     20161  SaberTyT      Normal
# 937055                  PUBLICAR     20161  SaberTyT      Normal
# 937060                  PUBLICAR     20161  SaberTyT      Normal
# 937073                  PUBLICAR     20161  SaberTyT      Normal
#
#        group_CUANTITATIVO group_LECTURA group_COMPETENCIA group_INGLES  \
# 937022                 Q2            Q2                Q3           Q1
# 937046                 Q4            Q4                Q4           Q4
# 937055                 Q4            Q2                Q2           Q3
# 937060                 Q3            Q4                Q4           Q4
# 937073                 Q4            Q4                Q3           Q4
#
#        group_ESCRITA
# 937022            Q3
# 937046            Q4
# 937055            Q3
# 937060            Q4
# 937073            Q4
#
# [5 rows x 69 columns]

# %%
df_t_lectura=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_lectura[var]=df_t_lectura[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_lectura.head())
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA            0
# 937046         165                 CC          COLOMBIA            0
# 937055         176                 CC          COLOMBIA            0
# 937060         181                 CC          COLOMBIA            1
# 937073         198                 CC          COLOMBIA            0
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 937022             VALLE                   76.0              CALI
# 937046            BOGOTA                   11.0            BOGOTA
# 937055              META                   50.0     VILLAVICENCIO
# 937060         ATLANTICO                    8.0      BARRANQUILLA
# 937073         SANTANDER                   68.0       BUCARAMANGA
#
#         ESTU_COD_RESIDE_MCPIO  \
# 937022                76001.0
# 937046                11001.0
# 937055                50001.0
# 937060                 8001.0
# 937073                68001.0
#
#                                         ESTU_COLE_TERMINO  \
# 937022  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 937046   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 937055                                COLEGIO CORAZONISTA
# 937060                                           PABLO VI
# 937073                             I.E.R PEDRONEL DURANGO
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 937022                               8                       0
# 937046                               1                       0
# 937055                               1                       0
# 937060                               8                       0
# 937073                               1                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 937022                          0                         0
# 937046                          1                         0
# 937055                          1                         0
# 937060                          1                         0
# 937073                          1                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 937022                         1                        0
# 937046                         1                        0
# 937055                         1                        0
# 937060                         1                        0
# 937073                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 937022                            0                              0
# 937046                            0                              0
# 937055                            0                              0
# 937060                            0                              0
# 937073                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 937022                     CC                    8                    5
# 937046                     TI                    8                    5
# 937055                     TI                    5                    1
# 937060                     TI                    8                    7
# 937073                     TI                    8                    8
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 937022                     3                   0                     1
# 937046                     2                   1                     1
# 937055                     4                   1                     1
# 937060                     2                   0                     1
# 937073                     2                   1                     0
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 937022                   1                    0                        1
# 937046                   1                    0                        1
# 937055                   1                    1                        1
# 937060                   1                    0                        1
# 937073                   1                    0                        1
#
#         INST_COD_INSTITUCION  \
# 937022                  4109
# 937046                  4813
# 937055                  3712
# 937060                  3117
# 937073                  3201
#
#                                   INST_NOMBRE_INSTITUCION  \
# 937022  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 937046  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 937055  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 937060             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 937073     UNIDADES TECNOLOGICAS DE SANTANDER-BUCARAMANGA
#
#                                       ESTU_PRGM_ACADEMICO  \
# 937022           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 937046   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 937055                           TECNOLOGIA EN INDUSTRIAL
# 937060  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 937073              TECNOLOGIA EN CONTABILIDAD FINANCIERA
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 937022                   76001                CALI                      29
# 937046                   11001        BOGOTÁ, D.C.                       3
# 937055                   50001       VILLAVICENCIO                      19
# 937060                    8758             SOLEDAD                       2
# 937073                   68001         BUCARAMANGA                      26
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 937022       TÉCNICO PROFESIONAL                 2                    46
# 937046       TÉCNICO PROFESIONAL                 2                    30
# 937055                TECNOLOGÍA                 2                    32
# 937060                TECNOLOGÍA                 2                    30
# 937073                TECNOLOGÍA                 2                     0
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 937022                 76001.0                CALI                  VALLE
# 937046                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937055                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937060                  8758.0             SOLEDAD              ATLANTICO
# 937073                 68001.0         BUCARAMANGA              SANTANDER
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 937022                        3            4                        76001
# 937046                        3            0                        11001
# 937055                        1            1                        50001
# 937060                        2            4                         8001
# 937073                        1            2                        68001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 937022                    CALI                   VALLE
# 937046                  BOGOTÁ                  BOGOTÁ
# 937055           VILLAVICENCIO                    META
# 937060            BARRANQUILLA               ATLANTICO
# 937073             BUCARAMANGA               SANTANDER
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 937022                           76                      136.5
# 937046                           11                      192.0
# 937055                           50                      166.5
# 937060                            8                      154.5
# 937073                           68                      174.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 937022                          34.0                     145.5
# 937046                          92.0                     187.5
# 937055                          70.0                     132.0
# 937060                          55.0                     205.5
# 937073                          78.0                     178.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 937022                      45.0                      148.5
# 937046                      89.0                      199.5
# 937055                      28.0                      142.5
# 937060                      97.0                      207.0
# 937073                      83.0                      160.5
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 937022                       47.0            120.0              -A1
# 937046                       96.0            181.5               A2
# 937055                       39.0            169.5               A2
# 937060                       98.0            174.0               A2
# 937073                       62.0            186.0               B1
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                    156.0                         3
# 937046             85.0                    180.0                         3
# 937055             76.0                    165.0                         3
# 937060             80.0                    205.5                         4
# 937073             87.0                    172.5                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 937022      Normal                 Q2            Q2                Q3
# 937046      Normal                 Q4            Q4                Q4
# 937055      Normal                 Q4            Q2                Q2
# 937060      Normal                 Q3            Q4                Q4
# 937073      Normal                 Q4            Q4                Q3
#
#        group_INGLES group_ESCRITA
# 937022           Q1            Q3
# 937046           Q4            Q4
# 937055           Q3            Q3
# 937060           Q4            Q4
# 937073           Q4            Q4

# %%
X_train_lect, X_test_lect, y_train_lect, y_test_lect = train_test_split(df_t_lectura[covariates],
                                                    df_t_lectura['MOD_LECTURA_CRITICA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_lect shape: ', X_train_lect.shape)
print('X_test_lect shape: ', X_test_lect.shape)
print('y_train_lect shape: ', y_train_lect.shape)
print('y_test_lect shape: ', y_test_lect.shape)
# Out:
# X_train_lect shape:  (29085, 23)
# X_test_lect shape:  (9696, 23)
# y_train_lect shape:  (29085,)
# y_test_lect shape:  (9696,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_lectura= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_lectura.fit(X_train_lect, y_train_lect)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_lect=RandomforestRegModel_lectura.predict(X_test_lect)

# %%
#MOD_LECTURA_CRITICA_PUNT
comparar_lect=pd.DataFrame(y_pred_lect, y_test_lect)
comparar_lect.head(20)
# Out:
#                                    0
# MOD_LECTURA_CRITICA_PUNT
# 99.0                      148.256917
# 165.0                     150.203293
# 163.5                     125.966813
# 123.0                     150.504385
# 169.5                     149.851648
# 148.5                     144.548199
# 177.0                     144.836848
# 130.5                     138.253333
# 144.0                     134.595391
# 69.0                      134.907886
# 120.0                     140.464214
# 69.0                      145.796557
# 145.5                     141.514908
# 165.0                     155.307771
# 138.0                     144.218362
# 129.0                     139.862365
# 108.0                     148.193554
# 181.5                     161.969974
# 196.5                     161.260051
# 154.5                     148.768663

# %%
res_lect = y_pred_lect-y_test_lect # residuals
#print(res)
fig=sm.qqplot(res_lect,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model LECTURA', MAE(y_pred_lect,y_test_lect))
print('RMSE of the model LECTURA', RMSE(y_pred_lect,y_test_lect))
print('MAPE of the model LECTURA', MAPE(y_pred_lect,y_test_lect))
print('Accuracy of the model LECTURA', 100-MAPE(y_pred_lect,y_test_lect))
# Out:
# MAE of the model LECTURA 24.315253435597217
# RMSE of the model LECTURA 30.316667875816307
# MAPE of the model LECTURA 18.342029437789783
# Accuracy of the model LECTURA 81.65797056221021

# %%
# Important variables

feature_list_lectura= list(df_t_lectura[covariates].columns)
# Get numerical feature importances
importances_lectura = list(RandomforestRegModel_lectura.feature_importances_)
# List of tuples with variable and importance
feature_importances_lectura = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_lectura, importances_lectura)]
# Sort the feature importances by most important first
feature_importances_lectura = sorted(feature_importances_lectura, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_LECTURA_CRITICA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_lectura];
# Out:
# MOD_LECTURA_CRITICA_PUNT
#
# Variable: INST_ORIGEN          Importance: 0.18
# Variable: PERIODO-X            Importance: 0.17
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.16
# Variable: FAMI_TIENEINTERNET   Importance: 0.12
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.08
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.05
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.05
# Variable: INST_CARACTER_ACADEMICO Importance: 0.03
# Variable: ESTU_HORASSEMANATRABAJA Importance: 0.03
# Variable: FAMI_TIENECOMPUTADOR Importance: 0.02
# Variable: FAMI_EDUCACIONMADRE  Importance: 0.02
# Variable: FAMI_EDUCACIONPADRE  Importance: 0.02
# Variable: ESTU_METODO_PRGM     Importance: 0.02
# Variable: ESTU_GENERO          Importance: 0.01
# Variable: ESTU_SIMULACROTIPOICFES Importance: 0.01
# Variable: FAMI_TIENEAUTOMOVIL  Importance: 0.0
# Variable: FAMI_TIENELAVADORA   Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOGENERIC Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOAREAS Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPROPIO Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPADRES Importance: 0.0
# Variable: ESTU_PAGOMATRICULACREDITO Importance: 0.0
# Variable: ESTU_PAGOMATRICULABECA Importance: 0.0

# %% [markdown]
# **MOD_COMPETEN_CIUDADA_PUNT**

# %%
df_t_competencia=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_competencia[var]=df_t_competencia[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_competencia.head())
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA            0
# 937046         165                 CC          COLOMBIA            0
# 937055         176                 CC          COLOMBIA            0
# 937060         181                 CC          COLOMBIA            1
# 937073         198                 CC          COLOMBIA            0
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 937022             VALLE                   76.0              CALI
# 937046            BOGOTA                   11.0            BOGOTA
# 937055              META                   50.0     VILLAVICENCIO
# 937060         ATLANTICO                    8.0      BARRANQUILLA
# 937073         SANTANDER                   68.0       BUCARAMANGA
#
#         ESTU_COD_RESIDE_MCPIO  \
# 937022                76001.0
# 937046                11001.0
# 937055                50001.0
# 937060                 8001.0
# 937073                68001.0
#
#                                         ESTU_COLE_TERMINO  \
# 937022  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 937046   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 937055                                COLEGIO CORAZONISTA
# 937060                                           PABLO VI
# 937073                             I.E.R PEDRONEL DURANGO
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 937022                               8                       0
# 937046                               1                       0
# 937055                               1                       0
# 937060                               8                       0
# 937073                               1                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 937022                          0                         0
# 937046                          1                         0
# 937055                          1                         0
# 937060                          1                         0
# 937073                          1                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 937022                         1                        0
# 937046                         1                        0
# 937055                         1                        0
# 937060                         1                        0
# 937073                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 937022                            0                              0
# 937046                            0                              0
# 937055                            0                              0
# 937060                            0                              0
# 937073                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 937022                     CC                    8                    5
# 937046                     TI                    8                    5
# 937055                     TI                    5                    1
# 937060                     TI                    8                    7
# 937073                     TI                    8                    8
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 937022                     3                   0                     1
# 937046                     2                   1                     1
# 937055                     4                   1                     1
# 937060                     2                   0                     1
# 937073                     2                   1                     0
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 937022                   1                    0                        1
# 937046                   1                    0                        1
# 937055                   1                    1                        1
# 937060                   1                    0                        1
# 937073                   1                    0                        1
#
#         INST_COD_INSTITUCION  \
# 937022                  4109
# 937046                  4813
# 937055                  3712
# 937060                  3117
# 937073                  3201
#
#                                   INST_NOMBRE_INSTITUCION  \
# 937022  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 937046  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 937055  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 937060             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 937073     UNIDADES TECNOLOGICAS DE SANTANDER-BUCARAMANGA
#
#                                       ESTU_PRGM_ACADEMICO  \
# 937022           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 937046   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 937055                           TECNOLOGIA EN INDUSTRIAL
# 937060  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 937073              TECNOLOGIA EN CONTABILIDAD FINANCIERA
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 937022                   76001                CALI                      29
# 937046                   11001        BOGOTÁ, D.C.                       3
# 937055                   50001       VILLAVICENCIO                      19
# 937060                    8758             SOLEDAD                       2
# 937073                   68001         BUCARAMANGA                      26
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 937022       TÉCNICO PROFESIONAL                 2                    46
# 937046       TÉCNICO PROFESIONAL                 2                    30
# 937055                TECNOLOGÍA                 2                    32
# 937060                TECNOLOGÍA                 2                    30
# 937073                TECNOLOGÍA                 2                     0
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 937022                 76001.0                CALI                  VALLE
# 937046                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937055                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937060                  8758.0             SOLEDAD              ATLANTICO
# 937073                 68001.0         BUCARAMANGA              SANTANDER
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 937022                        3            4                        76001
# 937046                        3            0                        11001
# 937055                        1            1                        50001
# 937060                        2            4                         8001
# 937073                        1            2                        68001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 937022                    CALI                   VALLE
# 937046                  BOGOTÁ                  BOGOTÁ
# 937055           VILLAVICENCIO                    META
# 937060            BARRANQUILLA               ATLANTICO
# 937073             BUCARAMANGA               SANTANDER
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 937022                           76                      136.5
# 937046                           11                      192.0
# 937055                           50                      166.5
# 937060                            8                      154.5
# 937073                           68                      174.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 937022                          34.0                     145.5
# 937046                          92.0                     187.5
# 937055                          70.0                     132.0
# 937060                          55.0                     205.5
# 937073                          78.0                     178.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 937022                      45.0                      148.5
# 937046                      89.0                      199.5
# 937055                      28.0                      142.5
# 937060                      97.0                      207.0
# 937073                      83.0                      160.5
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 937022                       47.0            120.0              -A1
# 937046                       96.0            181.5               A2
# 937055                       39.0            169.5               A2
# 937060                       98.0            174.0               A2
# 937073                       62.0            186.0               B1
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                    156.0                         3
# 937046             85.0                    180.0                         3
# 937055             76.0                    165.0                         3
# 937060             80.0                    205.5                         4
# 937073             87.0                    172.5                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 937022      Normal                 Q2            Q2                Q3
# 937046      Normal                 Q4            Q4                Q4
# 937055      Normal                 Q4            Q2                Q2
# 937060      Normal                 Q3            Q4                Q4
# 937073      Normal                 Q4            Q4                Q3
#
#        group_INGLES group_ESCRITA
# 937022           Q1            Q3
# 937046           Q4            Q4
# 937055           Q3            Q3
# 937060           Q4            Q4
# 937073           Q4            Q4

# %%
X_train_compet, X_test_compet, y_train_compet, y_test_compet = train_test_split(df_t_competencia[covariates],
                                                    df_t_competencia['MOD_COMPETEN_CIUDADA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_compet shape: ', X_train_compet.shape)
print('X_test_compet shape: ', X_test_compet.shape)
print('y_train_compet shape: ', y_train_compet.shape)
print('y_test_compet shape: ', y_test_compet.shape)
# Out:
# X_train_compet shape:  (29085, 23)
# X_test_compet shape:  (9696, 23)
# y_train_compet shape:  (29085,)
# y_test_compet shape:  (9696,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_competencia= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_competencia.fit(X_train_compet, y_train_compet)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_compet=RandomforestRegModel_competencia.predict(X_test_compet)

# %%
#MOD_COMPETEN_CIUDADA_PUNT
comparar_compet=pd.DataFrame(y_pred_compet, y_test_compet)
comparar_compet.head(20)
# Out:
#                                     0
# MOD_COMPETEN_CIUDADA_PUNT
# 117.0                      140.094712
# 132.0                      150.394922
# 132.0                      123.786800
# 112.5                      141.693540
# 168.0                      140.296522
# 162.0                      136.962654
# 180.0                      134.612014
# 120.0                      131.531234
# 130.5                      141.708004
# 153.0                      128.196266
# 118.5                      131.902336
# 99.0                       151.025121
# 127.5                      137.815948
# 183.0                      144.663734
# 94.5                       138.603792
# 156.0                      128.485423
# 85.5                       128.540608
# 163.5                      160.370297
# 220.5                      160.136509
# 163.5                      145.379723

# %%
res_compet = y_pred_compet-y_test_compet # residuals
#print(res)
fig=sm.qqplot(res_compet,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model COMPETENCIA', MAE(y_pred_compet,y_test_compet))
print('RMSE of the model COMNPETENCIA', RMSE(y_pred_compet,y_test_compet))
print('MAPE of the model COMPETENCIA', MAPE(y_pred_compet,y_test_compet))
print('Accuracy of the model COMPETENCIA', 100-MAPE(y_pred_compet,y_test_compet))
# Out:
# MAE of the model COMPETENCIA 26.639563838555457
# RMSE of the model COMNPETENCIA 32.47215109800726
# MAPE of the model COMPETENCIA 20.286474386929235
# Accuracy of the model COMPETENCIA 79.71352561307077

# %%
# Important variables COMPETENCIA

feature_list_competencia= list(df_t_competencia[covariates].columns)
# Get numerical feature importances
importances_competencia = list(RandomforestRegModel_competencia.feature_importances_)
# List of tuples with variable and importance
feature_importances_competencia = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_competencia, importances_competencia)]
# Sort the feature importances by most important first
feature_importances_competencia = sorted(feature_importances_competencia, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_COMPETEN_CIUDADA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_competencia];
# Out:
# MOD_COMPETEN_CIUDADA_PUNT
#
# Variable: PERIODO-X            Importance: 0.44
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.14
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.07
# Variable: FAMI_TIENECOMPUTADOR Importance: 0.06
# Variable: ESTU_HORASSEMANATRABAJA Importance: 0.05
# Variable: INST_CARACTER_ACADEMICO Importance: 0.04
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.04
# Variable: INST_ORIGEN          Importance: 0.03
# Variable: FAMI_TIENEINTERNET   Importance: 0.03
# Variable: ESTU_GENERO          Importance: 0.02
# Variable: FAMI_EDUCACIONMADRE  Importance: 0.02
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.02
# Variable: FAMI_EDUCACIONPADRE  Importance: 0.01
# Variable: ESTU_ACTIVIDADREFUERZOAREAS Importance: 0.01
# Variable: ESTU_SIMULACROTIPOICFES Importance: 0.01
# Variable: FAMI_TIENEAUTOMOVIL  Importance: 0.0
# Variable: FAMI_TIENELAVADORA   Importance: 0.0
# Variable: ESTU_METODO_PRGM     Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOGENERIC Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPROPIO Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPADRES Importance: 0.0
# Variable: ESTU_PAGOMATRICULACREDITO Importance: 0.0
# Variable: ESTU_PAGOMATRICULABECA Importance: 0.0

# %% [markdown]
# **MOD_INGLES_PUNT**

# %%
df_t_ingles=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_ingles[var]=df_t_ingles[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_ingles.head())
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA            0
# 937046         165                 CC          COLOMBIA            0
# 937055         176                 CC          COLOMBIA            0
# 937060         181                 CC          COLOMBIA            1
# 937073         198                 CC          COLOMBIA            0
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 937022             VALLE                   76.0              CALI
# 937046            BOGOTA                   11.0            BOGOTA
# 937055              META                   50.0     VILLAVICENCIO
# 937060         ATLANTICO                    8.0      BARRANQUILLA
# 937073         SANTANDER                   68.0       BUCARAMANGA
#
#         ESTU_COD_RESIDE_MCPIO  \
# 937022                76001.0
# 937046                11001.0
# 937055                50001.0
# 937060                 8001.0
# 937073                68001.0
#
#                                         ESTU_COLE_TERMINO  \
# 937022  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 937046   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 937055                                COLEGIO CORAZONISTA
# 937060                                           PABLO VI
# 937073                             I.E.R PEDRONEL DURANGO
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 937022                               8                       0
# 937046                               1                       0
# 937055                               1                       0
# 937060                               8                       0
# 937073                               1                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 937022                          0                         0
# 937046                          1                         0
# 937055                          1                         0
# 937060                          1                         0
# 937073                          1                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 937022                         1                        0
# 937046                         1                        0
# 937055                         1                        0
# 937060                         1                        0
# 937073                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 937022                            0                              0
# 937046                            0                              0
# 937055                            0                              0
# 937060                            0                              0
# 937073                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 937022                     CC                    8                    5
# 937046                     TI                    8                    5
# 937055                     TI                    5                    1
# 937060                     TI                    8                    7
# 937073                     TI                    8                    8
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 937022                     3                   0                     1
# 937046                     2                   1                     1
# 937055                     4                   1                     1
# 937060                     2                   0                     1
# 937073                     2                   1                     0
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 937022                   1                    0                        1
# 937046                   1                    0                        1
# 937055                   1                    1                        1
# 937060                   1                    0                        1
# 937073                   1                    0                        1
#
#         INST_COD_INSTITUCION  \
# 937022                  4109
# 937046                  4813
# 937055                  3712
# 937060                  3117
# 937073                  3201
#
#                                   INST_NOMBRE_INSTITUCION  \
# 937022  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 937046  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 937055  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 937060             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 937073     UNIDADES TECNOLOGICAS DE SANTANDER-BUCARAMANGA
#
#                                       ESTU_PRGM_ACADEMICO  \
# 937022           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 937046   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 937055                           TECNOLOGIA EN INDUSTRIAL
# 937060  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 937073              TECNOLOGIA EN CONTABILIDAD FINANCIERA
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 937022                   76001                CALI                      29
# 937046                   11001        BOGOTÁ, D.C.                       3
# 937055                   50001       VILLAVICENCIO                      19
# 937060                    8758             SOLEDAD                       2
# 937073                   68001         BUCARAMANGA                      26
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 937022       TÉCNICO PROFESIONAL                 2                    46
# 937046       TÉCNICO PROFESIONAL                 2                    30
# 937055                TECNOLOGÍA                 2                    32
# 937060                TECNOLOGÍA                 2                    30
# 937073                TECNOLOGÍA                 2                     0
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 937022                 76001.0                CALI                  VALLE
# 937046                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937055                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937060                  8758.0             SOLEDAD              ATLANTICO
# 937073                 68001.0         BUCARAMANGA              SANTANDER
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 937022                        3            4                        76001
# 937046                        3            0                        11001
# 937055                        1            1                        50001
# 937060                        2            4                         8001
# 937073                        1            2                        68001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 937022                    CALI                   VALLE
# 937046                  BOGOTÁ                  BOGOTÁ
# 937055           VILLAVICENCIO                    META
# 937060            BARRANQUILLA               ATLANTICO
# 937073             BUCARAMANGA               SANTANDER
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 937022                           76                      136.5
# 937046                           11                      192.0
# 937055                           50                      166.5
# 937060                            8                      154.5
# 937073                           68                      174.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 937022                          34.0                     145.5
# 937046                          92.0                     187.5
# 937055                          70.0                     132.0
# 937060                          55.0                     205.5
# 937073                          78.0                     178.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 937022                      45.0                      148.5
# 937046                      89.0                      199.5
# 937055                      28.0                      142.5
# 937060                      97.0                      207.0
# 937073                      83.0                      160.5
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 937022                       47.0            120.0              -A1
# 937046                       96.0            181.5               A2
# 937055                       39.0            169.5               A2
# 937060                       98.0            174.0               A2
# 937073                       62.0            186.0               B1
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                    156.0                         3
# 937046             85.0                    180.0                         3
# 937055             76.0                    165.0                         3
# 937060             80.0                    205.5                         4
# 937073             87.0                    172.5                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 937022      Normal                 Q2            Q2                Q3
# 937046      Normal                 Q4            Q4                Q4
# 937055      Normal                 Q4            Q2                Q2
# 937060      Normal                 Q3            Q4                Q4
# 937073      Normal                 Q4            Q4                Q3
#
#        group_INGLES group_ESCRITA
# 937022           Q1            Q3
# 937046           Q4            Q4
# 937055           Q3            Q3
# 937060           Q4            Q4
# 937073           Q4            Q4

# %%
X_train_ingles, X_test_ingles, y_train_ingles, y_test_ingles = train_test_split(df_t_ingles[covariates],
                                                    df_t_ingles['MOD_INGLES_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_ingles shape: ', X_train_ingles.shape)
print('X_test_ingles shape: ', X_test_ingles.shape)
print('y_train_ingles shape: ', y_train_ingles.shape)
print('y_test_ingles shape: ', y_test_ingles.shape)
# Out:
# X_train_ingles shape:  (29085, 23)
# X_test_ingles shape:  (9696, 23)
# y_train_ingles shape:  (29085,)
# y_test_ingles shape:  (9696,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_ingles= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_ingles.fit(X_train_ingles, y_train_ingles)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_ingles=RandomforestRegModel_ingles.predict(X_test_ingles)

# %%
#MOD_INGLES_PUNT
comparar_ingles=pd.DataFrame(y_pred_ingles, y_test_ingles)
comparar_ingles.head(20)
# Out:
#                           0
# MOD_INGLES_PUNT
# 136.5            151.873371
# 198.0            154.931686
# 130.5            129.709398
# 105.0            158.922201
# 99.0             157.162038
# 133.5            156.758747
# 151.5            152.081092
# 153.0            138.661278
# 160.5            138.003310
# 145.5            134.744531
# 145.5            142.494376
# 129.0            136.177572
# 142.5            144.468282
# 163.5            165.494680
# 112.5            142.841685
# 118.5            140.105329
# 187.5            157.806309
# 175.5            168.224772
# 232.5            159.692428
# 160.5            147.878445

# %%
res_ingles = y_pred_ingles-y_test_ingles # residuals
#print(res)
fig=sm.qqplot(res_ingles,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model INGLES', MAE(y_pred_ingles,y_test_ingles))
print('RMSE of the model INGLES', RMSE(y_pred_ingles,y_test_ingles))
print('MAPE of the model INGLES', MAPE(y_pred_ingles,y_test_ingles))
print('Accuracy of the model INGLES', 100-MAPE(y_pred_ingles,y_test_ingles))
# Out:
# MAE of the model INGLES 23.758370961577103
# RMSE of the model INGLES 29.56986671898576
# MAPE of the model INGLES 16.550319239610577
# Accuracy of the model INGLES 83.44968076038943

# %%
# Important variables INGLES

feature_list_ingles= list(df_t_ingles[covariates].columns)
# Get numerical feature importances
importances_ingles = list(RandomforestRegModel_ingles.feature_importances_)
# List of tuples with variable and importance
feature_importances_ingles = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_ingles, importances_ingles)]
# Sort the feature importances by most important first
feature_importances_ingles = sorted(feature_importances_ingles, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_INGLES_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_ingles];
# Out:
# MOD_INGLES_PUNT
#
# Variable: FAMI_TIENEINTERNET   Importance: 0.24
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.21
# Variable: INST_ORIGEN          Importance: 0.15
# Variable: FAMI_EDUCACIONMADRE  Importance: 0.11
# Variable: ESTU_METODO_PRGM     Importance: 0.08
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.06
# Variable: FAMI_EDUCACIONPADRE  Importance: 0.04
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.03
# Variable: INST_CARACTER_ACADEMICO Importance: 0.02
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.02
# Variable: FAMI_TIENECOMPUTADOR Importance: 0.01
# Variable: ESTU_HORASSEMANATRABAJA Importance: 0.01
# Variable: ESTU_PAGOMATRICULAPADRES Importance: 0.01
# Variable: PERIODO-X            Importance: 0.01
# Variable: ESTU_GENERO          Importance: 0.0
# Variable: FAMI_TIENEAUTOMOVIL  Importance: 0.0
# Variable: FAMI_TIENELAVADORA   Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOGENERIC Importance: 0.0
# Variable: ESTU_ACTIVIDADREFUERZOAREAS Importance: 0.0
# Variable: ESTU_SIMULACROTIPOICFES Importance: 0.0
# Variable: ESTU_PAGOMATRICULAPROPIO Importance: 0.0
# Variable: ESTU_PAGOMATRICULACREDITO Importance: 0.0
# Variable: ESTU_PAGOMATRICULABECA Importance: 0.0

# %% [markdown]
# **MOD_COMUNI_ESCRITA_PUNT**

# %%
df_t_escrita=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_escrita[var]=df_t_escrita[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_escrita.head())
# Out:
#         Unnamed: 0 ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO  \
# 937022         140                 CC          COLOMBIA            0
# 937046         165                 CC          COLOMBIA            0
# 937055         176                 CC          COLOMBIA            0
# 937060         181                 CC          COLOMBIA            1
# 937073         198                 CC          COLOMBIA            0
#
#        ESTU_FECHANACIMIENTO  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 937022           22/06/1991    20161   EK201610110512      ESTUDIANTE
# 937046           01/07/1992    20161   EK201610028250      ESTUDIANTE
# 937055           08/10/1992    20161   EK201610085857      ESTUDIANTE
# 937060           03/05/1994    20161   EK201610021372      ESTUDIANTE
# 937073           04/02/1996    20161   EK201610096299      ESTUDIANTE
#
#        ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  \
# 937022             VALLE                   76.0              CALI
# 937046            BOGOTA                   11.0            BOGOTA
# 937055              META                   50.0     VILLAVICENCIO
# 937060         ATLANTICO                    8.0      BARRANQUILLA
# 937073         SANTANDER                   68.0       BUCARAMANGA
#
#         ESTU_COD_RESIDE_MCPIO  \
# 937022                76001.0
# 937046                11001.0
# 937055                50001.0
# 937060                 8001.0
# 937073                68001.0
#
#                                         ESTU_COLE_TERMINO  \
# 937022  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 937046   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 937055                                COLEGIO CORAZONISTA
# 937060                                           PABLO VI
# 937073                             I.E.R PEDRONEL DURANGO
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 937022                               8                       0
# 937046                               1                       0
# 937055                               1                       0
# 937060                               8                       0
# 937073                               1                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 937022                          0                         0
# 937046                          1                         0
# 937055                          1                         0
# 937060                          1                         0
# 937073                          1                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 937022                         1                        0
# 937046                         1                        0
# 937055                         1                        0
# 937060                         1                        0
# 937073                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 937022                            0                              0
# 937046                            0                              0
# 937055                            0                              0
# 937060                            0                              0
# 937073                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 937022                     CC                    8                    5
# 937046                     TI                    8                    5
# 937055                     TI                    5                    1
# 937060                     TI                    8                    7
# 937073                     TI                    8                    8
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 937022                     3                   0                     1
# 937046                     2                   1                     1
# 937055                     4                   1                     1
# 937060                     2                   0                     1
# 937073                     2                   1                     0
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 937022                   1                    0                        1
# 937046                   1                    0                        1
# 937055                   1                    1                        1
# 937060                   1                    0                        1
# 937073                   1                    0                        1
#
#         INST_COD_INSTITUCION  \
# 937022                  4109
# 937046                  4813
# 937055                  3712
# 937060                  3117
# 937073                  3201
#
#                                   INST_NOMBRE_INSTITUCION  \
# 937022  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 937046  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 937055  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 937060             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 937073     UNIDADES TECNOLOGICAS DE SANTANDER-BUCARAMANGA
#
#                                       ESTU_PRGM_ACADEMICO  \
# 937022           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 937046   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 937055                           TECNOLOGIA EN INDUSTRIAL
# 937060  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 937073              TECNOLOGIA EN CONTABILIDAD FINANCIERA
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 937022                   76001                CALI                      29
# 937046                   11001        BOGOTÁ, D.C.                       3
# 937055                   50001       VILLAVICENCIO                      19
# 937060                    8758             SOLEDAD                       2
# 937073                   68001         BUCARAMANGA                      26
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 937022       TÉCNICO PROFESIONAL                 2                    46
# 937046       TÉCNICO PROFESIONAL                 2                    30
# 937055                TECNOLOGÍA                 2                    32
# 937060                TECNOLOGÍA                 2                    30
# 937073                TECNOLOGÍA                 2                     0
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 937022                 76001.0                CALI                  VALLE
# 937046                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937055                 11001.0        BOGOTÁ, D.C.                 BOGOTÁ
# 937060                  8758.0             SOLEDAD              ATLANTICO
# 937073                 68001.0         BUCARAMANGA              SANTANDER
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 937022                        3            4                        76001
# 937046                        3            0                        11001
# 937055                        1            1                        50001
# 937060                        2            4                         8001
# 937073                        1            2                        68001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 937022                    CALI                   VALLE
# 937046                  BOGOTÁ                  BOGOTÁ
# 937055           VILLAVICENCIO                    META
# 937060            BARRANQUILLA               ATLANTICO
# 937073             BUCARAMANGA               SANTANDER
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 937022                           76                      136.5
# 937046                           11                      192.0
# 937055                           50                      166.5
# 937060                            8                      154.5
# 937073                           68                      174.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 937022                          34.0                     145.5
# 937046                          92.0                     187.5
# 937055                          70.0                     132.0
# 937060                          55.0                     205.5
# 937073                          78.0                     178.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 937022                      45.0                      148.5
# 937046                      89.0                      199.5
# 937055                      28.0                      142.5
# 937060                      97.0                      207.0
# 937073                      83.0                      160.5
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 937022                       47.0            120.0              -A1
# 937046                       96.0            181.5               A2
# 937055                       39.0            169.5               A2
# 937060                       98.0            174.0               A2
# 937073                       62.0            186.0               B1
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 937022             17.0                    156.0                         3
# 937046             85.0                    180.0                         3
# 937055             76.0                    165.0                         3
# 937060             80.0                    205.5                         4
# 937073             87.0                    172.5                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 937022                     53.0                 PUBLICAR     20161  SaberTyT
# 937046                     84.0                 PUBLICAR     20161  SaberTyT
# 937055                     67.0                 PUBLICAR     20161  SaberTyT
# 937060                     99.0                 PUBLICAR     20161  SaberTyT
# 937073                     78.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 937022      Normal                 Q2            Q2                Q3
# 937046      Normal                 Q4            Q4                Q4
# 937055      Normal                 Q4            Q2                Q2
# 937060      Normal                 Q3            Q4                Q4
# 937073      Normal                 Q4            Q4                Q3
#
#        group_INGLES group_ESCRITA
# 937022           Q1            Q3
# 937046           Q4            Q4
# 937055           Q3            Q3
# 937060           Q4            Q4
# 937073           Q4            Q4

# %%
X_train_escrita, X_test_escrita, y_train_escrita, y_test_escrita = train_test_split(df_t_escrita[covariates],
                                                    df_t_escrita['MOD_COMUNI_ESCRITA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_escrita shape: ', X_train_escrita.shape)
print('X_test_escrita shape: ', X_test_escrita.shape)
print('y_train_escrita shape: ', y_train_escrita.shape)
print('y_test_escrita shape: ', y_test_escrita.shape)
# Out:
# X_train_escrita shape:  (29085, 23)
# X_test_escrita shape:  (9696, 23)
# y_train_escrita shape:  (29085,)
# y_test_escrita shape:  (9696,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_escrita= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_escrita.fit(X_train_escrita, y_train_escrita)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_escrita=RandomforestRegModel_escrita.predict(X_test_escrita)

# %%
y_pred_escrita
# Out:
# array([143.95958079, 154.28851105, 153.05239345, ..., 156.14548505,
#        145.52139199, 162.08473744])

# %%
#MOD_COMUNI_ESCRITA_PUNT
comparar_escrita=pd.DataFrame(y_pred_escrita, y_test_escrita)
comparar_escrita.head(20)
# Out:
#                                   0
# MOD_COMUNI_ESCRITA_PUNT
# 153.0                    143.959581
# 159.0                    154.288511
# 150.0                    153.052393
# 151.5                    155.492589
# 157.5                    155.004357
# 133.5                    153.686937
# 160.5                    155.257478
# 154.5                    145.623979
# 108.0                    145.268875
# 169.5                    141.677088
# 147.0                    147.466949
# 127.5                    149.988852
# 108.0                    143.436197
# 156.0                    155.006256
# 84.0                     152.938204
# 156.0                    151.431386
# 106.5                    164.038264
# 162.0                    153.830288
# 220.5                    154.005173
# 115.5                    150.997010

# %%
res_escrita = y_pred_escrita-y_test_escrita # residuals
#print(res)
fig=sm.qqplot(res_escrita,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model escrita', MAE(y_pred_escrita,y_test_escrita))
print('RMSE of the model escrita', RMSE(y_pred_escrita,y_test_escrita))
print('MAPE of the model escrita', MAPE(y_pred_escrita,y_test_escrita))
print('Accuracy of the model escrita', 100-MAPE(y_pred_escrita,y_test_escrita))
# Out:
# MAE of the model escrita 21.505236680214228
# RMSE of the model escrita 29.25996739133666
# MAPE of the model escrita 15.200566194408745
# Accuracy of the model escrita 84.79943380559125

# %%
# Important variables MOD_COMUNI_ESCRITA_PUNT

feature_list_escrita= list(df_t_escrita[covariates].columns)
# Get numerical feature importances
importances_escrita = list(RandomforestRegModel_escrita.feature_importances_)
# List of tuples with variable and importance
feature_importances_escrita = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_escrita, importances_escrita)]
# Sort the feature importances by most important first
feature_importances_escrita = sorted(feature_importances_escrita, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_COMUNI_ESCRITA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_escrita];
# Out:
# MOD_COMUNI_ESCRITA_PUNT
#
# Variable: PERIODO-X            Importance: 0.22
# Variable: ESTU_GENERO          Importance: 0.11
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.1
# Variable: FAMI_TIENECOMPUTADOR Importance: 0.07
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.07
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.07
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.06
# Variable: INST_ORIGEN          Importance: 0.05
# Variable: INST_CARACTER_ACADEMICO Importance: 0.05
# Variable: FAMI_EDUCACIONMADRE  Importance: 0.04
# Variable: FAMI_EDUCACIONPADRE  Importance: 0.04
# Variable: ESTU_HORASSEMANATRABAJA Importance: 0.04
# Variable: FAMI_TIENEINTERNET   Importance: 0.02
# Variable: FAMI_TIENEAUTOMOVIL  Importance: 0.01
# Variable: FAMI_TIENELAVADORA   Importance: 0.01
# Variable: ESTU_METODO_PRGM     Importance: 0.01
# Variable: ESTU_ACTIVIDADREFUERZOGENERIC Importance: 0.01
# Variable: ESTU_ACTIVIDADREFUERZOAREAS Importance: 0.01
# Variable: ESTU_SIMULACROTIPOICFES Importance: 0.01
# Variable: ESTU_PAGOMATRICULAPROPIO Importance: 0.01
# Variable: ESTU_PAGOMATRICULAPADRES Importance: 0.01
# Variable: ESTU_PAGOMATRICULACREDITO Importance: 0.01
# Variable: ESTU_PAGOMATRICULABECA Importance: 0.01
