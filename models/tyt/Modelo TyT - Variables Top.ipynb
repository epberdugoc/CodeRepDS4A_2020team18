# %%
### Load relevant packages
import pandas                  as pd
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import statsmodels.formula.api as smf
import statsmodels.api         as sm
import scipy

# !pip install linearmodels

from linearmodels import PanelOLS
from linearmodels import RandomEffects
# Out:
# Requirement already satisfied: linearmodels in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (4.17)
# Requirement already satisfied: scipy>=1 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.4.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.0.3)
# Requirement already satisfied: patsy in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.5.1)
# Requirement already satisfied: Cython>=0.29.14 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.29.21)
# Requirement already satisfied: property-cached>=1.6.3 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: statsmodels>=0.9 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (0.11.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from linearmodels) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from pandas>=0.23->linearmodels) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from pandas>=0.23->linearmodels) (2.8.1)
# Requirement already satisfied: six in c:\users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages (from patsy->linearmodels) (1.14.0)

# %%
datafinal = pd.read_csv('data-final-depurado-fecha-matricula.csv', encoding = "UTF-8")
# Out:
# C:\Users\margu\anaconda3\envs\case_1.2_var2\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
datafinal.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_COLE_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_SIMULACROTIPOICFES',
#        'ESTU_ACTIVIDADREFUERZOAREAS', 'ESTU_ACTIVIDADREFUERZOGENERIC',
#        'ESTU_TIPODOCUMENTOSB11', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_HORASSEMANATRABAJA',
#        'INST_COD_INSTITUCION', 'INST_NOMBRE_INSTITUCION',
#        'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_CODMUNICIPIO', 'ESTU_PRGM_MUNICIPIO',
#        'ESTU_PRGM_DEPARTAMENTO', 'ESTU_NIVEL_PRGM_ACADEMICO',
#        'ESTU_METODO_PRGM', 'ESTU_NUCLEO_PREGRADO', 'ESTU_INST_CODMUNICIPIO',
#        'ESTU_INST_MUNICIPIO', 'ESTU_INST_DEPARTAMENTO',
#        'INST_CARACTER_ACADEMICO', 'INST_ORIGEN', 'ESTU_COD_MCPIO_PRESENTACION',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_DEPTO_PRESENTACION', 'MOD_RAZONA_CUANTITAT_PUNT',
#        'MOD_RAZONA_CUANTITATIVO_PNAL', 'MOD_LECTURA_CRITICA_PUNT',
#        'MOD_LECTURA_CRITICA_PNAL', 'MOD_COMPETEN_CIUDADA_PUNT',
#        'MOD_COMPETEN_CIUDADA_PNAL', 'MOD_INGLES_PUNT', 'MOD_INGLES_DESEM',
#        'MOD_INGLES_PNAL', 'MOD_COMUNI_ESCRITA_PUNT',
#        'MOD_COMUNI_ESCRITA_DESEM', 'MOD_COMUNI_ESCRITA_PNAL',
#        'ESTU_ESTADOINVESTIGACION', 'PERIODO-X', 'PRUEBA', 'TIPO_PRUEBA'],
#       dtype='object')

# %%
datafinal.head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 CC          COLOMBIA           F           1994-11-24
# 1                 CC          COLOMBIA           M           1991-06-11
# 2                 CC          COLOMBIA           F           1995-02-22
# 3                 CC          COLOMBIA           M           1994-08-01
# 4                 CC          COLOMBIA           M           1980-08-18
#
#    PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 0    20163   EK201630197609      ESTUDIANTE      CUNDINAMARCA
# 1    20163   EK201630241417      ESTUDIANTE            BOGOTA
# 2    20163   EK201630080363      ESTUDIANTE   NORTE SANTANDER
# 3    20163   EK201630081694      ESTUDIANTE            BOGOTA
# 4    20163   EK201630079620      ESTUDIANTE           BOLIVAR
#
#    ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ...  MOD_INGLES_PUNT  \
# 0                   25.0             TABIO  ...            155.0
# 1                   11.0            BOGOTA  ...            153.0
# 2                   54.0            CUCUTA  ...            120.0
# 3                   11.0            BOGOTA  ...            214.0
# 4                   13.0         CARTAGENA  ...            184.0
#
#   MOD_INGLES_DESEM MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT  \
# 0               A2            62.0                   151.0
# 1               A2            59.0                   220.0
# 2              -A1            16.0                   162.0
# 3               B2            98.0                   112.0
# 4               B1            84.0                   158.0
#
#   MOD_COMUNI_ESCRITA_DESEM MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION  \
# 0                        3                    43.0                 PUBLICAR
# 1                        4                   100.0                 PUBLICAR
# 2                        3                    72.0                 PUBLICAR
# 3                        1                     8.0                 PUBLICAR
# 4                        3                    53.0                 PUBLICAR
#
#   PERIODO-X    PRUEBA TIPO_PRUEBA
# 0      2016  SaberPro      Normal
# 1      2016  SaberPro      Normal
# 2      2016  SaberPro      Normal
# 3      2016  SaberPro      Normal
# 4      2016  SaberPro      Normal
#
# [5 rows x 63 columns]

# %%
datafinal.shape
# Out:
# (1580574, 63)

# %%
datafinal.ESTU_NUCLEO_PREGRADO.value_counts()
# Out:
# ADMINISTRACIÓN                                           392549
# CONTADURÍA PUBLICA                                       134828
# EDUCACIÓN                                                101092
# DERECHO Y AFINES                                          82072
# INGENIERÍA INDUSTRIAL Y AFINES                            74988
# INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES               72857
# PSICOLOGÍA                                                58167
# INGENIERÍA AMBIENTAL, SANITARIA Y AFINES                  51036
# ECONOMÍA                                                  47229
# SIN CLASIFICAR                                            45333
# INGENIERÍA CIVIL Y AFINES                                 44463
# INGENIERÍA MECÁNICA Y AFINES                              42008
# COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES                  28928
# DISEÑO                                                    28656
# MEDICINA                                                  27065
# INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES       26072
# SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES                       21692
# SALUD PÚBLICA                                             20409
# ARQUITECTURA                                              19826
# ENFERMERÍA                                                16674
# AGRONOMÍA                                                 16186
# SIN ESPECIFICAR                                           14335
# INGENIERÍA ELÉCTRICA Y AFINES                             13735
# FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL     13122
# TERAPIAS                                                  11971
# BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS      9891
# ODONTOLOGÍA                                                9337
# INGENIERÍA QUÍMICA Y AFINES                                8816
# BIOLOGÍA, MICROBIOLOGÍA Y AFINES                           8203
# QUÍMICA Y AFINES                                           7433
# INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES              6771
# MEDICINA VETERINARIA                                       6498
# ARTES PLÁSTICAS, VISUALES Y AFINES                         6452
# CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES             6400
#                                                            6357
# OTRAS INGENIERÍAS                                          6217
# DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN                    6114
# ZOOTECNIA                                                  6054
# INGENIERÍA DE MINAS, METALURGIA Y AFINES                   5956
# PUBLICIDAD Y AFINES                                        5665
# GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES            5165
# NORMALES SUPERIORES                                        4973
# INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES                   4180
# INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES                     3942
# INGENIERÍA ADMINISTRATIVA Y AFINES                         3726
# OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES                   3442
# LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES         3286
# OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD        3271
# MÚSICA                                                     3144
# GEOGRAFÍA, HISTORIA                                        3027
# BACTERIOLOGÍA                                              2931
# INGENIERÍA BIOMÉDICA Y AFINES                              2778
# NUTRICIÓN Y DIETÉTICA                                      2487
# INSTRUMENTACIÓN QUIRÚRGICA                                 2433
# FILOSOFÍA, TEOLOGÍA Y AFINES                               2384
# MATEMÁTICAS, ESTADÍSTICA Y AFINES                          1788
# ANTROPOLOGÍA, ARTES LIBERALES                              1616
# ARTES REPRESENTATIVAS                                      1151
# FÍSICA                                                      998
# Name: ESTU_NUCLEO_PREGRADO, dtype: int64

# %%
datafinal.ESTU_NUCLEO_PREGRADO.unique()
# Out:
# array(['ADMINISTRACIÓN', 'PSICOLOGÍA', 'ENFERMERÍA',
#        'INGENIERÍA QUÍMICA Y AFINES', 'EDUCACIÓN', 'ARQUITECTURA',
#        'INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES',
#        'COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES',
#        'INGENIERÍA ADMINISTRATIVA Y AFINES',
#        'INGENIERÍA BIOMÉDICA Y AFINES', 'INGENIERÍA INDUSTRIAL Y AFINES',
#        'INGENIERÍA AMBIENTAL, SANITARIA Y AFINES', 'DISEÑO',
#        'ARTES PLÁSTICAS, VISUALES Y AFINES', 'QUÍMICA Y AFINES',
#        'INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES', ' ',
#        'INGENIERÍA CIVIL Y AFINES', 'CONTADURÍA PUBLICA', 'TERAPIAS',
#        'MEDICINA', 'ECONOMÍA', 'INGENIERÍA MECÁNICA Y AFINES',
#        'SIN ESPECIFICAR',
#        'GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#        'DERECHO Y AFINES', 'INGENIERÍA ELÉCTRICA Y AFINES',
#        'INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES',
#        'SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES',
#        'FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL',
#        'BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS',
#        'AGRONOMÍA', 'MEDICINA VETERINARIA', 'SALUD PÚBLICA',
#        'ODONTOLOGÍA', 'PUBLICIDAD Y AFINES', 'MÚSICA',
#        'OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD',
#        'CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES',
#        'INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#        'GEOGRAFÍA, HISTORIA', 'BACTERIOLOGÍA',
#        'BIOLOGÍA, MICROBIOLOGÍA Y AFINES',
#        'INGENIERÍA DE MINAS, METALURGIA Y AFINES',
#        'MATEMÁTICAS, ESTADÍSTICA Y AFINES',
#        'INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES',
#        'DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN', 'FÍSICA',
#        'INSTRUMENTACIÓN QUIRÚRGICA', 'ARTES REPRESENTATIVAS',
#        'LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES', 'ZOOTECNIA',
#        'OTRAS INGENIERÍAS', 'FILOSOFÍA, TEOLOGÍA Y AFINES',
#        'OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES',
#        'NUTRICIÓN Y DIETÉTICA', 'ANTROPOLOGÍA, ARTES LIBERALES', nan,
#        'SIN CLASIFICAR', 'NORMALES SUPERIORES'], dtype=object)

# %%
datafinal[datafinal['PRUEBA']=='SaberTyT']['ESTU_VALORMATRICULAUNIVERSIDAD'].value_counts()
# Out:
# No pagó matrícula                           289796
# Entre 1 millón y menos de 2.5 millones      137030
# Entre 500 mil y menos de 1 millón            77763
# Menos de 500 mil                             36331
# Entre 2.5 millones y menos de 4 millones     23157
# Entre 4 millones y menos de 5.5 millones      1512
# Entre 5.5 millones y menos de 7 millones      1216
# Más de 7 millones                              496
# Name: ESTU_VALORMATRICULAUNIVERSIDAD, dtype: int64

# %%
for column in datafinal.columns:
    print(f'Column: {column}')
    print(datafinal[column].astype(str).sort_values().value_counts())
    print('\n')
# Out:
# Column: ESTU_TIPODOCUMENTO
# CC     1549899
# TI       25716
# CR        2659
# CE        1961
# PE         267
# PC          66
# PEP          3
# NES          2
# V            1
# Name: ESTU_TIPODOCUMENTO, dtype: int64
#
#
# Column: ESTU_NACIONALIDAD
# COLOMBIA                                    1578117
# VENEZUELA                                       827
# ESTADOS UNIDOS                                  219
# ECUADOR                                         170
# FRANCIA                                         156
#                                              ...
# LAOS - REPÚBLICA DEMOCRÁTICA POPULAR LAO          1
# SUECIA                                            1
# NAMIBIA                                           1
# REPÚBLICA CHECA                                   1
# REPÚBLICA CENTROAFRICANA                          1
# Name: ESTU_NACIONALIDAD, Length: 92, dtype: int64
#
#
# Column: ESTU_GENERO
# F      897579
# M      682608
# nan       387
# Name: ESTU_GENERO, dtype: int64
#
#
# Column: ESTU_FECHANACIMIENTO
# nan                    197752
# 1900-01-01                763
# 1995-10-10                476
# 1994-11-08                467
# 1995-08-09                466
#                         ...
# 1954-07-21 12:00:00         1
# 1960-12-18                  1
# 2002-05-30 12:00:00         1
# 2006-12-04                  1
# 1960-11-17                  1
# Name: ESTU_FECHANACIMIENTO, Length: 31542, dtype: int64
#
#
# Column: PERIODO
# 20195    321294
# 20173    302428
# 20183    286384
# 20163    239830
# 20161    111589
# 20192    100999
# 20171     91837
# 20181     70367
# 20164     52253
# 20194      1826
# 20182      1141
# 20184       395
# 20196       231
# Name: PERIODO, dtype: int64
#
#
# Column: ESTU_CONSECUTIVO
# EK201730060938    1
# EK201630002063    1
# EK201950018051    1
# EK201710062400    1
# EK201830051964    1
#                  ..
# EK201950343320    1
# EK201830187008    1
# EK201730095909    1
# EK201950327882    1
# EK201830007192    1
# Name: ESTU_CONSECUTIVO, Length: 1580574, dtype: int64
#
#
# Column: ESTU_ESTUDIANTE
# ESTUDIANTE    1580574
# Name: ESTU_ESTUDIANTE, dtype: int64
#
#
# Column: ESTU_DEPTO_RESIDE
# BOGOTA             424341
# ANTIOQUIA          188730
# VALLE              127206
# CUNDINAMARCA        90303
# ATLANTICO           88246
# SANTANDER           80682
# nan                 57681
# BOLIVAR             56648
# TOLIMA              43165
# NORTE SANTANDER     40998
# BOYACA              37192
# CALDAS              33200
# RISARALDA           31135
# NARIÑO              30156
# CAUCA               29714
# CORDOBA             29640
# HUILA               29464
# META                26718
# MAGDALENA           24914
# CESAR               21947
# QUINDIO             20114
# SUCRE               17890
# LA GUAJIRA          13878
# CASANARE             8153
# CAQUETA              7184
# CHOCO                6989
# PUTUMAYO             6471
# ARAUCA               3170
# SAN ANDRES           1455
# GUAVIARE             1312
# VICHADA               517
# AMAZONAS              474
# GUAINIA               469
# VAUPES                259
# EXTRANJERO            159
# Name: ESTU_DEPTO_RESIDE, dtype: int64
#
#
# Column: ESTU_COD_RESIDE_DEPTO
# 11.0       424341
# 5.0        188730
# 76.0       127206
# 25.0        90303
# 8.0         88246
# 68.0        80682
# nan         57681
# 13.0        56648
# 73.0        43165
# 54.0        40998
# 15.0        37192
# 17.0        33200
# 66.0        31135
# 52.0        30156
# 19.0        29714
# 23.0        29640
# 41.0        29464
# 50.0        26718
# 47.0        24914
# 20.0        21947
# 63.0        20114
# 70.0        17890
# 44.0        13878
# 85.0         8153
# 18.0         7184
# 27.0         6989
# 86.0         6471
# 81.0         3170
# 88.0         1455
# 95.0         1312
# 99.0          517
# 91.0          474
# 94.0          469
# 97.0          259
# 99999.0       159
# Name: ESTU_COD_RESIDE_DEPTO, dtype: int64
#
#
# Column: ESTU_MCPIO_RESIDE
# BOGOTA                      424341
# MEDELLIN                     97221
# CALI                         74660
# nan                          57681
# BARRANQUILLA                 57673
#                              ...
# MEDIO ATRATO                     1
# CARURU                           1
# JORDAN                           1
# YAVARATE                         1
# ROBERTO PAYAN (SAN JOSE)         1
# Name: ESTU_MCPIO_RESIDE, Length: 1091, dtype: int64
#
#
# Column: ESTU_COD_RESIDE_MCPIO
# 11001.0    424341
# 5001.0      97221
# 76001.0     74660
# nan         57681
# 8001.0      57673
#             ...
# 97889.0         1
# 94884.0         1
# 97161.0         1
# 68370.0         1
# 27425.0         1
# Name: ESTU_COD_RESIDE_MCPIO, Length: 1112, dtype: int64
#
#
# Column: ESTU_COLE_TERMINO
# nan                                                            565863
# 0.0                                                             34155
# ,                                                               19127
# INST EDUC VILLA SANTANA                                         13494
# INST EDUC CEFA                                                   2660
#                                                                 ...
# I.E. FRANCISCO JOSE DE CALDAS (CENTENARIO) - SEDE PRINCIPAL         1
# 3654.0                                                              1
# I. E. R. NEL UPEGUI                                                 1
# 19055.0                                                             1
# 11164.0                                                             1
# Name: ESTU_COLE_TERMINO, Length: 31885, dtype: int64
#
#
# Column: ESTU_VALORMATRICULAUNIVERSIDAD
# Entre 1 millón y menos de 2.5 millones      425721
# No pagó matrícula                           298126
# Entre 2.5 millones y menos de 4 millones    208492
# Entre 500 mil y menos de 1 millón           198350
# Menos de 500 mil                            169864
# Entre 4 millones y menos de 5.5 millones     91455
# Más de 7 millones                            76105
# nan                                          64442
# Entre 5.5 millones y menos de 7 millones     48019
# Name: ESTU_VALORMATRICULAUNIVERSIDAD, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULABECA
# No     1185098
# Si      237400
# nan     158076
# Name: ESTU_PAGOMATRICULABECA, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULACREDITO
# No     1038544
# Si      388612
# nan     153418
# Name: ESTU_PAGOMATRICULACREDITO, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULAPADRES
# No     772026
# Si     659634
# nan    148914
# Name: ESTU_PAGOMATRICULAPADRES, dtype: int64
#
#
# Column: ESTU_PAGOMATRICULAPROPIO
# No     828053
# Si     602092
# nan    150429
# Name: ESTU_PAGOMATRICULAPROPIO, dtype: int64
#
#
# Column: ESTU_SIMULACROTIPOICFES
# nan    1341565
# Si      125590
# No      113419
# Name: ESTU_SIMULACROTIPOICFES, dtype: int64
#
#
# Column: ESTU_ACTIVIDADREFUERZOAREAS
# nan    1341579
# No      122029
# Si      116966
# Name: ESTU_ACTIVIDADREFUERZOAREAS, dtype: int64
#
#
# Column: ESTU_ACTIVIDADREFUERZOGENERIC
# nan    1341587
# No      130165
# Si      108822
# Name: ESTU_ACTIVIDADREFUERZOGENERIC, dtype: int64
#
#
# Column: ESTU_TIPODOCUMENTOSB11
# TI     1004149
# CC      471016
# nan      80206
# CR       22477
# CE        1898
# PE         711
# PC         117
# Name: ESTU_TIPODOCUMENTOSB11, dtype: int64
#
#
# Column: FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      329340
# Primaria incompleta                     306842
# Secundaria (Bachillerato) incompleta    191123
# Primaria completa                       177594
# Educación profesional completa          148356
# Técnica o tecnológica completa          128188
# Ninguno                                  70857
# Postgrado                                64032
# Técnica o tecnológica incompleta         46234
# nan                                      42827
# Educación profesional incompleta         42277
# No sabe                                  32904
# Name: FAMI_EDUCACIONPADRE, dtype: int64
#
#
# Column: FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      370455
# Primaria incompleta                     255133
# Secundaria (Bachillerato) incompleta    219997
# Primaria completa                       179121
# Técnica o tecnológica completa          171518
# Educación profesional completa          146575
# Postgrado                                65314
# Técnica o tecnológica incompleta         53749
# Educación profesional incompleta         38368
# Ninguno                                  38111
# nan                                      35365
# No sabe                                   6868
# Name: FAMI_EDUCACIONMADRE, dtype: int64
#
#
# Column: FAMI_ESTRATOVIVIENDA
# Estrato 2      585551
# Estrato 3      461090
# Estrato 1      305130
# Estrato 4      117457
# nan             45013
# Estrato 5       39070
# Estrato 6       19676
# Sin Estrato      4810
# Estrato 0        2604
# Zona Rural        173
# Name: FAMI_ESTRATOVIVIENDA, dtype: int64
#
#
# Column: FAMI_TIENEINTERNET
# Si     1234239
# No      313373
# nan      32962
# Name: FAMI_TIENEINTERNET, dtype: int64
#
#
# Column: FAMI_TIENECOMPUTADOR
# Si     1317926
# No      227771
# nan      34877
# Name: FAMI_TIENECOMPUTADOR, dtype: int64
#
#
# Column: FAMI_TIENELAVADORA
# Si     1278371
# No      267454
# nan      34749
# Name: FAMI_TIENELAVADORA, dtype: int64
#
#
# Column: FAMI_TIENEAUTOMOVIL
# No     1105436
# Si      439630
# nan      35508
# Name: FAMI_TIENEAUTOMOVIL, dtype: int64
#
#
# Column: ESTU_HORASSEMANATRABAJA
# Más de 30 horas        593901
# 0                      338294
# Entre 11 y 20 horas    227701
# Menos de 10 horas      175706
# Entre 21 y 30 horas    156566
# nan                     88406
# Name: ESTU_HORASSEMANATRABAJA, dtype: int64
#
#
# Column: INST_COD_INSTITUCION
# 9110     338617
# 2829      70701
# 4813      49505
# 2725      36017
# 2102      27067
#           ...
# 9125         10
# 10041        10
# 3116          9
# 4705          4
# 19109         3
# Name: INST_COD_INSTITUCION, Length: 430, dtype: int64
#
#
# Column: INST_NOMBRE_INSTITUCION
# SERVICIO NACIONAL DE APRENDIZAJE-SENA                                                              271650
# CORPORACION UNIVERSITARIA MINUTO DE DIOS -UNIMINUTO-BOGOTÁ D.C.                                     70701
# SERVICIO NACIONAL DE APRENDIZAJE-SENA-BOGOTÁ D.C.                                                   66967
# CORPORACION UNIFICADA NACIONAL DE EDUCACION SUPERIOR-CUN-BOGOTÁ D.C.                                49505
# POLITECNICO GRANCOLOMBIANO-BOGOTÁ D.C.                                                              36017
#                                                                                                     ...
# ESCUELA DE SUBOFICIALES DE LA FUERZA AEREA COLOMBIANA"-"ANDRES M.DIAZ"-"-MADRID                         7
# FUNDACION UNIVERSIDAD DE BOGOTA"-"JORGE TADEO LOZANO"-"-CARTAGENA                                       5
# FUNDACION CENTRO DE EDUCACION SUPERIOR,INVESTIGACION Y PROFESIONALIZACION -CEDINPRO-BOGOTÁ D.C.         4
# I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARDO CANYES SANTACANA - SEDE PRINCIPAL-LETICIA               3
# FUNDACION UNIVERSITARIA "-"MARIA CANO"-"-MEDELLIN                                                       3
# Name: INST_NOMBRE_INSTITUCION, Length: 468, dtype: int64
#
#
# Column: ESTU_PRGM_ACADEMICO
# ADMINISTRACION DE EMPRESAS                                                                     78597
# DERECHO                                                                                        75158
# CONTADURIA PUBLICA                                                                             64018
# PSICOLOGIA                                                                                     41929
# INGENIERIA INDUSTRIAL                                                                          41714
#                                                                                                ...
# INGENIERÍA DE MINAS                                                                                1
# LICENCIATURA EN  EDUCACION BASICA CON  ENFASIS  EN CIENCIAS NATURALES Y EDUCACION AMBIENTAL        1
# LICENCIATURA EN EDUCACION BASICA CON ENFASIS EN ARTE Y FOLKLORE                                    1
# TECNICO PROFESIONAL EN OPERACIONES LOGISTICAS                                                      1
# LICENCIATURA EN EDUCACION ENFASIS EN HUMANIDADES                                                   1
# Name: ESTU_PRGM_ACADEMICO, Length: 2670, dtype: int64
#
#
# Column: ESTU_PRGM_CODMUNICIPIO
# 11001    635425
# 5001     148765
# 76001     78954
# 8001      78101
# 68001     55957
#           ...
# 25772         1
# 25815         1
# 5107          1
# 8558          1
# 63594         1
# Name: ESTU_PRGM_CODMUNICIPIO, Length: 386, dtype: int64
#
#
# Column: ESTU_PRGM_MUNICIPIO
# BOGOTA               635425
# MEDELLÍN             109958
# CALI                  78954
# BARRANQUILLA          78101
# BUCARAMANGA           55957
#                       ...
# PUERTO LIBERTADOR         1
# MONIQUIRA                 1
# HERRAN                    1
# CUMBAL                    1
# TAURAMENA                 1
# Name: ESTU_PRGM_MUNICIPIO, Length: 456, dtype: int64
#
#
# Column: ESTU_PRGM_DEPARTAMENTO
# BOGOTA             635425
# ANTIOQUIA          198452
# VALLE              108169
# ATLANTICO           84050
# SANTANDER           75586
# BOLIVAR             53551
# CUNDINAMARCA        42088
# NORTE SANTANDER     40053
# TOLIMA              33752
# CALDAS              32254
# BOYACA              31549
# RISARALDA           26951
# CAUCA               25393
# NARIÑO              23597
# HUILA               21358
# MAGDALENA           20461
# CORDOBA             20365
# QUINDIO             20361
# META                18345
# SUCRE               17461
# CESAR               15730
# LA GUAJIRA          11517
# CHOCO                6471
# CASANARE             5243
# CAQUETA              4846
# PUTUMAYO             3939
# ARAUCA               1452
# GUAVIARE              752
# SAN ANDRES            711
# GUAINIA               264
# VICHADA               246
# AMAZONAS              129
# VAUPES                 53
# Name: ESTU_PRGM_DEPARTAMENTO, dtype: int64
#
#
# Column: ESTU_NIVEL_PRGM_ACADEMICO
# UNIVERSITARIO              951833
# TECNOLOGÍA                 527379
# TÉCNICO PROFESIONAL         97980
# ESCUELA NORMAL SUPERIOR      3382
# Name: ESTU_NIVEL_PRGM_ACADEMICO, dtype: int64
#
#
# Column: ESTU_METODO_PRGM
# PRESENCIAL           1165704
# DISTANCIA             358952
# DISTANCIA VIRTUAL      55731
# SEMI-PRESENCIAL          187
# Name: ESTU_METODO_PRGM, dtype: int64
#
#
# Column: ESTU_NUCLEO_PREGRADO
# ADMINISTRACIÓN                                           392549
# CONTADURÍA PUBLICA                                       134828
# EDUCACIÓN                                                101092
# DERECHO Y AFINES                                          82072
# INGENIERÍA INDUSTRIAL Y AFINES                            74988
# INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES               72857
# PSICOLOGÍA                                                58167
# INGENIERÍA AMBIENTAL, SANITARIA Y AFINES                  51036
# ECONOMÍA                                                  47229
# SIN CLASIFICAR                                            45333
# INGENIERÍA CIVIL Y AFINES                                 44463
# INGENIERÍA MECÁNICA Y AFINES                              42008
# COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES                  28928
# DISEÑO                                                    28656
# MEDICINA                                                  27065
# INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES       26072
# SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES                       21692
# SALUD PÚBLICA                                             20409
# ARQUITECTURA                                              19826
# ENFERMERÍA                                                16674
# AGRONOMÍA                                                 16186
# SIN ESPECIFICAR                                           14335
# INGENIERÍA ELÉCTRICA Y AFINES                             13735
# FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL     13122
# nan                                                       12395
# TERAPIAS                                                  11971
# BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS      9891
# ODONTOLOGÍA                                                9337
# INGENIERÍA QUÍMICA Y AFINES                                8816
# BIOLOGÍA, MICROBIOLOGÍA Y AFINES                           8203
# QUÍMICA Y AFINES                                           7433
# INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES              6771
# MEDICINA VETERINARIA                                       6498
# ARTES PLÁSTICAS, VISUALES Y AFINES                         6452
# CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES             6400
#                                                            6357
# OTRAS INGENIERÍAS                                          6217
# DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN                    6114
# ZOOTECNIA                                                  6054
# INGENIERÍA DE MINAS, METALURGIA Y AFINES                   5956
# PUBLICIDAD Y AFINES                                        5665
# GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES            5165
# NORMALES SUPERIORES                                        4973
# INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES                   4180
# INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES                     3942
# INGENIERÍA ADMINISTRATIVA Y AFINES                         3726
# OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES                   3442
# LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES         3286
# OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD        3271
# MÚSICA                                                     3144
# GEOGRAFÍA, HISTORIA                                        3027
# BACTERIOLOGÍA                                              2931
# INGENIERÍA BIOMÉDICA Y AFINES                              2778
# NUTRICIÓN Y DIETÉTICA                                      2487
# INSTRUMENTACIÓN QUIRÚRGICA                                 2433
# FILOSOFÍA, TEOLOGÍA Y AFINES                               2384
# MATEMÁTICAS, ESTADÍSTICA Y AFINES                          1788
# ANTROPOLOGÍA, ARTES LIBERALES                              1616
# ARTES REPRESENTATIVAS                                      1151
# FÍSICA                                                      998
# Name: ESTU_NUCLEO_PREGRADO, dtype: int64
#
#
# Column: ESTU_INST_CODMUNICIPIO
# 11001.0    885005
# 5001.0     127343
# 8001.0      70467
# 76001.0     67798
# 68001.0     57281
#             ...
# 8436.0         17
# 5002.0         17
# 5670.0         13
# 41306.0        10
# 91001.0         3
# Name: ESTU_INST_CODMUNICIPIO, Length: 146, dtype: int64
#
#
# Column: ESTU_INST_MUNICIPIO
# BOGOTA          885005
# MEDELLÍN         94540
# BARRANQUILLA     70467
# CALI             67798
# BUCARAMANGA      57281
#                  ...
# JERICO               8
# JUNÍN                7
# SABOYA               6
# MALAGA               5
# LETICIA              3
# Name: ESTU_INST_MUNICIPIO, Length: 188, dtype: int64
#
#
# Column: ESTU_INST_DEPARTAMENTO
# BOGOTA             885005
# ANTIOQUIA          145160
# VALLE               78981
# ATLANTICO           74935
# SANTANDER           64799
# BOLIVAR             44732
# NORTE SANTANDER     28962
# TOLIMA              27389
# CALDAS              25414
# BOYACA              23372
# CUNDINAMARCA        20450
# RISARALDA           20003
# NARIÑO              18648
# QUINDIO             17318
# CAUCA               16774
# MAGDALENA           16767
# SUCRE               14804
# CORDOBA             13336
# HUILA               10642
# LA GUAJIRA           7896
# CESAR                7156
# CHOCO                5737
# META                 5001
# CAQUETA              3953
# PUTUMAYO             1800
# CASANARE             1360
# SAN ANDRES             90
# VICHADA                44
# ARAUCA                 43
# AMAZONAS                3
# Name: ESTU_INST_DEPARTAMENTO, dtype: int64
#
#
# Column: INST_CARACTER_ACADEMICO
# UNIVERSIDAD                  651350
# INSTITUCIÓN UNIVERSITARIA    426991
# INSTITUCIÓN TECNOLÓGICA      403116
# TÉCNICA PROFESIONAL           88029
# ESCUELA NORMAL SUPERIOR       11088
# Name: INST_CARACTER_ACADEMICO, dtype: int64
#
#
# Column: INST_ORIGEN
# OFICIAL NACIONAL            544687
# NO OFICIAL - CORPORACIÓN    427132
# NO OFICIAL - FUNDACIÓN      369828
# OFICIAL DEPARTAMENTAL       189464
# OFICIAL MUNICIPAL            31651
# REGIMEN ESPECIAL             17812
# Name: INST_ORIGEN, dtype: int64
#
#
# Column: ESTU_COD_MCPIO_PRESENTACION
# 11001    448817
# 5001     114235
# 8001      85965
# 76001     84926
# 68001     58000
#           ...
# 42            4
# 34            2
# 15204         1
# 13            1
# 23807         1
# Name: ESTU_COD_MCPIO_PRESENTACION, Length: 163, dtype: int64
#
#
# Column: ESTU_MCPIO_PRESENTACION
# BOGOTÁ                     448817
# MEDELLÍN                   114235
# BARRANQUILLA                85965
# CALI                        84926
# BUCARAMANGA                 58000
#                             ...
# AUCKLAND                        4
# SAN JUAN DE PUERTO RICO         2
# TIERRALTA                       1
# LA HABANA                       1
# COMBITA                         1
# Name: ESTU_MCPIO_PRESENTACION, Length: 162, dtype: int64
#
#
# Column: ESTU_DEPTO_PRESENTACION
# BOGOTA                     448817
# ANTIOQUIA                  196282
# VALLE                      131338
# ATLANTICO                   92300
# CUNDINAMARCA                90655
#                             ...
# TEL AVIV                        4
# AUCKLAND                        4
# MONTEVIDEO                      4
# SAN JUAN DE PUERTO RICO         2
# LA HABANA                       1
# Name: ESTU_DEPTO_PRESENTACION, Length: 74, dtype: int64
#
#
# Column: ESTU_COD_DEPTO_PRESENTACION
# 11    448817
# 5     196282
# 76    131338
# 8      92300
# 25     90655
# 68     83345
# 13     57847
# 54     43341
# 73     41631
# 15     38865
# 17     36585
# 66     32519
# 19     30380
# 41     30168
# 52     29761
# 23     28829
# 50     28162
# 47     24856
# 20     24828
# 63     21480
# 70     19188
# 44     10359
# 85      7958
# 18      7417
# 27      6722
# 86      6508
# 0       2967
# 81      2951
# 95      1388
# 88      1351
# 99       525
# 91       487
# 94       485
# 97       279
# Name: ESTU_COD_DEPTO_PRESENTACION, dtype: int64
#
#
# Column: MOD_RAZONA_CUANTITAT_PUNT
# 147.0    22461
# 144.0    22244
# 141.0    22238
# 138.0    22084
# 150.0    22069
#          ...
# 244.0        1
# 252.0        1
# 253.5        1
# 245.0        1
# 250.5        1
# Name: MOD_RAZONA_CUANTITAT_PUNT, Length: 255, dtype: int64
#
#
# Column: MOD_RAZONA_CUANTITATIVO_PNAL
# 61.0    16912
# 57.0    16893
# 52.0    16874
# 63.0    16854
# 55.0    16844
#         ...
# 25.0    14577
# 22.0    14530
# 19.0    14526
# 13.0    14429
# nan       622
# Name: MOD_RAZONA_CUANTITATIVO_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_LECTURA_CRITICA_PUNT
# 150.0    23153
# 147.0    22957
# 153.0    22875
# 156.0    22698
# 144.0    22637
#          ...
# 36.0         2
# 34.5         1
# 55.0         1
# 242.0        1
# 255.0        1
# Name: MOD_LECTURA_CRITICA_PUNT, Length: 276, dtype: int64
#
#
# Column: MOD_LECTURA_CRITICA_PNAL
# 51.0    16971
# 57.0    16971
# 53.0    16960
# 49.0    16939
# 58.0    16918
#         ...
# 26.0    14598
# 18.0    14567
# 21.0    14566
# 24.0    14551
# nan       622
# Name: MOD_LECTURA_CRITICA_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_COMPETEN_CIUDADA_PUNT
# 153.0    20269
# 144.0    20233
# 141.0    20214
# 150.0    20172
# 156.0    20129
#          ...
# 252.0       12
# 253.5        4
# 56.0         3
# 55.5         3
# 255.0        1
# Name: MOD_COMPETEN_CIUDADA_PUNT, Length: 257, dtype: int64
#
#
# Column: MOD_COMPETEN_CIUDADA_PNAL
# 60.0    16964
# 53.0    16945
# 51.0    16930
# 55.0    16919
# 64.0    16908
#         ...
# 35.0    14607
# 30.0    14584
# 24.0    14550
# 21.0    14517
# nan       622
# Name: MOD_COMPETEN_CIUDADA_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_INGLES_PUNT
# 138.0    25159
# 141.0    25090
# 135.0    24844
# 132.0    24393
# 144.0    24321
#          ...
# 70.5        11
# 264.0        7
# 69.0         4
# 262.5        3
# 265.5        3
# Name: MOD_INGLES_PUNT, Length: 244, dtype: int64
#
#
# Column: MOD_INGLES_DESEM
# A1     512822
# A2     403834
# -A1    319961
# B1     252687
# B2      91270
# Name: MOD_INGLES_DESEM, dtype: int64
#
#
# Column: MOD_INGLES_PNAL
# 51.0    17039
# 41.0    16996
# 39.0    16994
# 55.0    16993
# 43.0    16950
#         ...
# 15.0    14485
# 11.0    14481
# 8.0     14382
# 5.0     14352
# nan       622
# Name: MOD_INGLES_PNAL, Length: 101, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_PUNT
# 156.0    41288
# 159.0    39603
# 157.5    28987
# 162.0    27881
# 138.0    26453
#          ...
# 260.0        1
# 43.0         1
# 259.0        1
# 43.5         1
# 286.5        1
# Name: MOD_COMUNI_ESCRITA_PUNT, Length: 310, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_DESEM
# 2    595403
# 3    544948
# 4    233555
# 1    206668
# Name: MOD_COMUNI_ESCRITA_DESEM, dtype: int64
#
#
# Column: MOD_COMUNI_ESCRITA_PNAL
# 1.0     19349
# 56.0    18622
# 53.0    17926
# 38.0    17875
# 59.0    17811
#         ...
# 54.0    14282
# 66.0    14260
# 52.0    14218
# 49.0    14160
# nan       622
# Name: MOD_COMUNI_ESCRITA_PNAL, Length: 101, dtype: int64
#
#
# Column: ESTU_ESTADOINVESTIGACION
# PUBLICAR                                  1574273
# VALIDEZ OFICINA JURÍDICA                     3801
# PRESENTE CON LECTURA TARDIA                  1910
# NO SE COMPROBO IDENTIDAD DEL EXAMINADO        590
# Name: ESTU_ESTADOINVESTIGACION, dtype: int64
#
#
# Column: PERIODO-X
# 2019     252023
# 2016     239830
# 2017     233791
# 2018     229571
# 20161    111589
# 20191    100999
# 20171     91837
# 20192     71328
# 20181     70367
# 20172     68637
# 20182     58349
# 20162     52253
# Name: PERIODO-X, dtype: int64
#
#
# Column: PRUEBA
# SaberPro    955215
# SaberTyT    625359
# Name: PRUEBA, dtype: int64
#
#
# Column: TIPO_PRUEBA
# Normal          1475982
# Exterior         103966
# Extemporaneo        626
# Name: TIPO_PRUEBA, dtype: int64

# %%
datafinal['ESTU_NUCLEO_PREGRADO'].unique()
# Out:
# array(['ADMINISTRACIÓN', 'PSICOLOGÍA', 'ENFERMERÍA',
#        'INGENIERÍA QUÍMICA Y AFINES', 'EDUCACIÓN', 'ARQUITECTURA',
#        'INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES',
#        'COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES',
#        'INGENIERÍA ADMINISTRATIVA Y AFINES',
#        'INGENIERÍA BIOMÉDICA Y AFINES', 'INGENIERÍA INDUSTRIAL Y AFINES',
#        'INGENIERÍA AMBIENTAL, SANITARIA Y AFINES', 'DISEÑO',
#        'ARTES PLÁSTICAS, VISUALES Y AFINES', 'QUÍMICA Y AFINES',
#        'INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES', ' ',
#        'INGENIERÍA CIVIL Y AFINES', 'CONTADURÍA PUBLICA', 'TERAPIAS',
#        'MEDICINA', 'ECONOMÍA', 'INGENIERÍA MECÁNICA Y AFINES',
#        'SIN ESPECIFICAR',
#        'GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#        'DERECHO Y AFINES', 'INGENIERÍA ELÉCTRICA Y AFINES',
#        'INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES',
#        'SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES',
#        'FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL',
#        'BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS',
#        'AGRONOMÍA', 'MEDICINA VETERINARIA', 'SALUD PÚBLICA',
#        'ODONTOLOGÍA', 'PUBLICIDAD Y AFINES', 'MÚSICA',
#        'OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD',
#        'CIENCIAS POLÍTICAS, RELACIONES INTERNACIONALES',
#        'INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#        'GEOGRAFÍA, HISTORIA', 'BACTERIOLOGÍA',
#        'BIOLOGÍA, MICROBIOLOGÍA Y AFINES',
#        'INGENIERÍA DE MINAS, METALURGIA Y AFINES',
#        'MATEMÁTICAS, ESTADÍSTICA Y AFINES',
#        'INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES',
#        'DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN', 'FÍSICA',
#        'INSTRUMENTACIÓN QUIRÚRGICA', 'ARTES REPRESENTATIVAS',
#        'LENGUAS MODERNAS, LITERATURA, LINGÜÍSTICA Y AFINES', 'ZOOTECNIA',
#        'OTRAS INGENIERÍAS', 'FILOSOFÍA, TEOLOGÍA Y AFINES',
#        'OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES',
#        'NUTRICIÓN Y DIETÉTICA', 'ANTROPOLOGÍA, ARTES LIBERALES', nan,
#        'SIN CLASIFICAR', 'NORMALES SUPERIORES'], dtype=object)

# %%
datafinal['ESTU_PRGM_DEPARTAMENTO']=datafinal['ESTU_PRGM_DEPARTAMENTO'].replace('BOGOTÁ','BOGOTA')

# %%
datafinal['ESTU_PRGM_DEPARTAMENTO'].value_counts()
# Out:
# BOGOTA             635425
# ANTIOQUIA          198452
# VALLE              108169
# ATLANTICO           84050
# SANTANDER           75586
# BOLIVAR             53551
# CUNDINAMARCA        42088
# NORTE SANTANDER     40053
# TOLIMA              33752
# CALDAS              32254
# BOYACA              31549
# RISARALDA           26951
# CAUCA               25393
# NARIÑO              23597
# HUILA               21358
# MAGDALENA           20461
# CORDOBA             20365
# QUINDIO             20361
# META                18345
# SUCRE               17461
# CESAR               15730
# LA GUAJIRA          11517
# CHOCO                6471
# CASANARE             5243
# CAQUETA              4846
# PUTUMAYO             3939
# ARAUCA               1452
# GUAVIARE              752
# SAN ANDRES            711
# GUAINIA               264
# VICHADA               246
# AMAZONAS              129
# VAUPES                 53
# Name: ESTU_PRGM_DEPARTAMENTO, dtype: int64

# %%
datafinal['TIPO_PRUEBA'].unique()
# Out:
# array(['Normal', 'Exterior', 'Extemporaneo'], dtype=object)

# %%
# Let's filter the nan values for the column ESTU_VALORMATRICULAUNIVERSIDAD
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_VALORMATRICULAUNIVERSIDAD']=='nan') | (datafinal['ESTU_VALORMATRICULAUNIVERSIDAD']=='-')].index)
datafinal=datafinal.dropna(subset=['ESTU_VALORMATRICULAUNIVERSIDAD'])
datafinal['ESTU_VALORMATRICULAUNIVERSIDAD'].unique()
# Out:
# array(['Entre 1 millón y menos de 2.5 millones',
#        'Entre 500 mil y menos de 1 millón', 'Más de 7 millones',
#        'Entre 5.5 millones y menos de 7 millones',
#        'Entre 4 millones y menos de 5.5 millones', 'Menos de 500 mil',
#        'No pagó matrícula', 'Entre 2.5 millones y menos de 4 millones'],
#       dtype=object)

# %%
datafinal.shape
# Out:
# (1516132, 63)

# %%
datafinal=datafinal.dropna(subset=['ESTU_PAGOMATRICULABECA','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULAPADRES',\
                                    'ESTU_PAGOMATRICULAPROPIO','ESTU_SIMULACROTIPOICFES','ESTU_ACTIVIDADREFUERZOAREAS',\
                                    'ESTU_TIPODOCUMENTOSB11','FAMI_EDUCACIONPADRE','FAMI_EDUCACIONMADRE',\
                                    'FAMI_ESTRATOVIVIENDA','FAMI_TIENEINTERNET','FAMI_TIENECOMPUTADOR',\
                                    'FAMI_TIENELAVADORA','FAMI_TIENEAUTOMOVIL','ESTU_HORASSEMANATRABAJA',\
                                    'MOD_RAZONA_CUANTITATIVO_PNAL'])

# %%
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULABECA']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULACREDITO']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULAPADRES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_PAGOMATRICULAPROPIO']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_SIMULACROTIPOICFES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_SIMULACROTIPOICFES']=='-')].index)
datafinal = datafinal.drop(datafinal[(datafinal['ESTU_ACTIVIDADREFUERZOAREAS']=='-')].index)

# %%
datafinal.shape
# Out:
# (127139, 63)

# %%
datafinal['PRUEBA'].value_counts()
# Out:
# SaberPro    78638
# SaberTyT    48501
# Name: PRUEBA, dtype: int64

# %%
datafinal['PERIODO-X'].value_counts()
# Out:
# 2019     26400
# 2018     18231
# 2017     17868
# 2016     16139
# 20161     7783
# 20172     7181
# 20191     7158
# 20162     7100
# 20192     6738
# 20181     5587
# 20182     4776
# 20171     2178
# Name: PERIODO-X, dtype: int64

# %%
datafinal[datafinal['PRUEBA']=='SaberTyT']['ESTU_NACIONALIDAD'].value_counts()
# Out:
# COLOMBIA                  48460
# VENEZUELA                    15
# PANAMÁ                        3
# ESTADOS UNIDOS                3
# COREA DEL NORTE               2
# TERRITORIOS PALESTINOS        2
# ECUADOR                       2
# COMORAS                       2
# BOLIVIA                       2
# ESPAÑA                        2
# COSTA RICA                    1
# COSTA DE MARFIL               1
# REPÚBLICA DOMINICANA          1
# ALAND                         1
# CANADÁ                        1
# HAITI                         1
# CIUDAD DEL VATICANO           1
# PORTUGAL                      1
# Name: ESTU_NACIONALIDAD, dtype: int64

# %% [markdown]
# **TYT + TODOS LOS PERIODOS + COLOMBIANOS**

# %%
# Filter by the two conditions
df_sabertyt=datafinal[(datafinal['PRUEBA']=='SaberTyT')&((datafinal['PERIODO-X']==20161)|(datafinal['PERIODO-X']==20162)\
                    |(datafinal['PERIODO-X']==20171)|(datafinal['PERIODO-X']==20172)\
                    |(datafinal['PERIODO-X']==20181)|(datafinal['PERIODO-X']==20182)\
                    |(datafinal['PERIODO-X']==20191)|(datafinal['PERIODO-X']==20192))\
                    &(datafinal['ESTU_NACIONALIDAD']=='COLOMBIA')]
len(df_sabertyt)
# Out:
# 48460

# %%
# Decision Tree Regresison

import pandas as pd
import pydotplus
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from io import StringIO
from IPython.display import Image, SVG
from graphviz import Source
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.patches import Patch
from scipy.stats import chi2_contingency, norm
from sklearn.tree import export_graphviz
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from statsmodels.formula.api import ols
from sympy import var, plot_implicit, Eq

# %% [markdown]
# **MOD_RAZONA_CUANTITAT_PUNT**

# %%
df_sabertyt['group_CUANTITATIVO'] = pd.cut(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])
# Out:
# <ipython-input-24-3cda9fd83d6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt['group_CUANTITATIVO'] = pd.cut(df_sabertyt['MOD_RAZONA_CUANTITAT_PUNT'],

# %%
df_sabertyt.head()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA           F           1992-07-01
# 955390                 CC          COLOMBIA           F           1992-10-08
# 955395                 CC          COLOMBIA           M           1994-05-03
# 955398                 CC          COLOMBIA           F           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ...  MOD_INGLES_DESEM  \
# 955354                   76.0              CALI  ...               -A1
# 955379                   11.0            BOGOTA  ...                A2
# 955390                   50.0     VILLAVICENCIO  ...                A2
# 955395                    8.0      BARRANQUILLA  ...                A2
# 955398                   15.0             TUNJA  ...                A2
#
#        MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 955354            17.0                   156.0                        3
# 955379            85.0                   180.0                        3
# 955390            76.0                   165.0                        3
# 955395            80.0                   205.5                        4
# 955398            66.0                   159.0                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                    53.0                 PUBLICAR     20161  SaberTyT
# 955379                    84.0                 PUBLICAR     20161  SaberTyT
# 955390                    67.0                 PUBLICAR     20161  SaberTyT
# 955395                    99.0                 PUBLICAR     20161  SaberTyT
# 955398                    59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 955354      Normal                 Q3
# 955379      Normal                 Q4
# 955390      Normal                 Q4
# 955395      Normal                 Q3
# 955398      Normal                 Q3
#
# [5 rows x 64 columns]

# %%
df_sabertyt.group_CUANTITATIVO.value_counts()
# Out:
# Q1    12801
# Q3    11939
# Q2    11918
# Q4    11798
# Name: group_CUANTITATIVO, dtype: int64

# %%
df_sabertyt["group_CUANTITATIVO"] = df_sabertyt["group_CUANTITATIVO"].astype('category')
df_sabertyt["ESTU_GENERO"] = df_sabertyt["ESTU_GENERO"].astype('category')
df_sabertyt["INST_ORIGEN"] = df_sabertyt["INST_ORIGEN"].astype('category')
df_sabertyt["FAMI_TIENEAUTOMOVIL"] = df_sabertyt["FAMI_TIENEAUTOMOVIL"].astype('category')
df_sabertyt["FAMI_TIENELAVADORA"] = df_sabertyt["FAMI_TIENELAVADORA"].astype('category')
df_sabertyt["FAMI_TIENECOMPUTADOR"] = df_sabertyt["FAMI_TIENECOMPUTADOR"].astype('category')
df_sabertyt["FAMI_TIENEINTERNET"] = df_sabertyt["FAMI_TIENEINTERNET"].astype('category')
df_sabertyt["FAMI_ESTRATOVIVIENDA"] = df_sabertyt["FAMI_ESTRATOVIVIENDA"].astype('category')
df_sabertyt["FAMI_EDUCACIONMADRE"] = df_sabertyt["FAMI_EDUCACIONMADRE"].astype('category')
df_sabertyt["FAMI_EDUCACIONPADRE"] = df_sabertyt["FAMI_EDUCACIONPADRE"].astype('category')
df_sabertyt["ESTU_METODO_PRGM"] = df_sabertyt["ESTU_METODO_PRGM"].astype('category')
df_sabertyt["INST_CARACTER_ACADEMICO"] = df_sabertyt["INST_CARACTER_ACADEMICO"].astype('category')
df_sabertyt["ESTU_HORASSEMANATRABAJA"] = df_sabertyt["ESTU_HORASSEMANATRABAJA"].astype('category')
df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"].astype('category')
df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"].astype('category')
df_sabertyt["ESTU_SIMULACROTIPOICFES"] = df_sabertyt["ESTU_SIMULACROTIPOICFES"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULAPROPIO"] = df_sabertyt["ESTU_PAGOMATRICULAPROPIO"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULAPADRES"] = df_sabertyt["ESTU_PAGOMATRICULAPADRES"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULACREDITO"] = df_sabertyt["ESTU_PAGOMATRICULACREDITO"].astype('category')
df_sabertyt["ESTU_PAGOMATRICULABECA"] = df_sabertyt["ESTU_PAGOMATRICULABECA"].astype('category')
df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"] = df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"].astype('category')
df_sabertyt["ESTU_NUCLEO_PREGRADO"] = df_sabertyt["ESTU_NUCLEO_PREGRADO"].astype('category')
df_sabertyt["ESTU_PRGM_DEPARTAMENTO"] = df_sabertyt["ESTU_PRGM_DEPARTAMENTO"].astype('category')
df_sabertyt["PERIODO-X"] = df_sabertyt["PERIODO-X"].astype('category')
# Out:
# <ipython-input-27-39cc2f0721c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["group_CUANTITATIVO"] = df_sabertyt["group_CUANTITATIVO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_GENERO"] = df_sabertyt["ESTU_GENERO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["INST_ORIGEN"] = df_sabertyt["INST_ORIGEN"].astype('category')
# <ipython-input-27-39cc2f0721c2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENEAUTOMOVIL"] = df_sabertyt["FAMI_TIENEAUTOMOVIL"].astype('category')
# <ipython-input-27-39cc2f0721c2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENELAVADORA"] = df_sabertyt["FAMI_TIENELAVADORA"].astype('category')
# <ipython-input-27-39cc2f0721c2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENECOMPUTADOR"] = df_sabertyt["FAMI_TIENECOMPUTADOR"].astype('category')
# <ipython-input-27-39cc2f0721c2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_TIENEINTERNET"] = df_sabertyt["FAMI_TIENEINTERNET"].astype('category')
# <ipython-input-27-39cc2f0721c2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_ESTRATOVIVIENDA"] = df_sabertyt["FAMI_ESTRATOVIVIENDA"].astype('category')
# <ipython-input-27-39cc2f0721c2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_EDUCACIONMADRE"] = df_sabertyt["FAMI_EDUCACIONMADRE"].astype('category')
# <ipython-input-27-39cc2f0721c2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["FAMI_EDUCACIONPADRE"] = df_sabertyt["FAMI_EDUCACIONPADRE"].astype('category')
# <ipython-input-27-39cc2f0721c2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_METODO_PRGM"] = df_sabertyt["ESTU_METODO_PRGM"].astype('category')
# <ipython-input-27-39cc2f0721c2>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["INST_CARACTER_ACADEMICO"] = df_sabertyt["INST_CARACTER_ACADEMICO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_HORASSEMANATRABAJA"] = df_sabertyt["ESTU_HORASSEMANATRABAJA"].astype('category')
# <ipython-input-27-39cc2f0721c2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOGENERIC"].astype('category')
# <ipython-input-27-39cc2f0721c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"] = df_sabertyt["ESTU_ACTIVIDADREFUERZOAREAS"].astype('category')
# <ipython-input-27-39cc2f0721c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_SIMULACROTIPOICFES"] = df_sabertyt["ESTU_SIMULACROTIPOICFES"].astype('category')
# <ipython-input-27-39cc2f0721c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULAPROPIO"] = df_sabertyt["ESTU_PAGOMATRICULAPROPIO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULAPADRES"] = df_sabertyt["ESTU_PAGOMATRICULAPADRES"].astype('category')
# <ipython-input-27-39cc2f0721c2>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULACREDITO"] = df_sabertyt["ESTU_PAGOMATRICULACREDITO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PAGOMATRICULABECA"] = df_sabertyt["ESTU_PAGOMATRICULABECA"].astype('category')
# <ipython-input-27-39cc2f0721c2>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"] = df_sabertyt["ESTU_VALORMATRICULAUNIVERSIDAD"].astype('category')
# <ipython-input-27-39cc2f0721c2>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_NUCLEO_PREGRADO"] = df_sabertyt["ESTU_NUCLEO_PREGRADO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["ESTU_PRGM_DEPARTAMENTO"] = df_sabertyt["ESTU_PRGM_DEPARTAMENTO"].astype('category')
# <ipython-input-27-39cc2f0721c2>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sabertyt["PERIODO-X"] = df_sabertyt["PERIODO-X"].astype('category')

# %%
df_sabertyt.head()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA           F           1992-07-01
# 955390                 CC          COLOMBIA           F           1992-10-08
# 955395                 CC          COLOMBIA           M           1994-05-03
# 955398                 CC          COLOMBIA           F           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ...  MOD_INGLES_DESEM  \
# 955354                   76.0              CALI  ...               -A1
# 955379                   11.0            BOGOTA  ...                A2
# 955390                   50.0     VILLAVICENCIO  ...                A2
# 955395                    8.0      BARRANQUILLA  ...                A2
# 955398                   15.0             TUNJA  ...                A2
#
#        MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 955354            17.0                   156.0                        3
# 955379            85.0                   180.0                        3
# 955390            76.0                   165.0                        3
# 955395            80.0                   205.5                        4
# 955398            66.0                   159.0                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                    53.0                 PUBLICAR     20161  SaberTyT
# 955379                    84.0                 PUBLICAR     20161  SaberTyT
# 955390                    67.0                 PUBLICAR     20161  SaberTyT
# 955395                    99.0                 PUBLICAR     20161  SaberTyT
# 955398                    59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 955354      Normal                 Q3
# 955379      Normal                 Q4
# 955390      Normal                 Q4
# 955395      Normal                 Q3
# 955398      Normal                 Q3
#
# [5 rows x 64 columns]

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_CUANTITATIVO'])

# %%
df_sabertyt.shape
# Out:
# (48456, 64)

# %%
df_sabertyt.head()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA           F           1992-07-01
# 955390                 CC          COLOMBIA           F           1992-10-08
# 955395                 CC          COLOMBIA           M           1994-05-03
# 955398                 CC          COLOMBIA           F           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ...  MOD_INGLES_DESEM  \
# 955354                   76.0              CALI  ...               -A1
# 955379                   11.0            BOGOTA  ...                A2
# 955390                   50.0     VILLAVICENCIO  ...                A2
# 955395                    8.0      BARRANQUILLA  ...                A2
# 955398                   15.0             TUNJA  ...                A2
#
#        MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 955354            17.0                   156.0                        3
# 955379            85.0                   180.0                        3
# 955390            76.0                   165.0                        3
# 955395            80.0                   205.5                        4
# 955398            66.0                   159.0                        3
#
#        MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                    53.0                 PUBLICAR     20161  SaberTyT
# 955379                    84.0                 PUBLICAR     20161  SaberTyT
# 955390                    67.0                 PUBLICAR     20161  SaberTyT
# 955395                    99.0                 PUBLICAR     20161  SaberTyT
# 955398                    59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 955354      Normal                 Q3
# 955379      Normal                 Q4
# 955390      Normal                 Q4
# 955395      Normal                 Q3
# 955398      Normal                 Q3
#
# [5 rows x 64 columns]

# %%
df_t=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t[var]=df_t[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t.head())
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA            0  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA            0           1992-07-01
# 955390                 CC          COLOMBIA            0           1992-10-08
# 955395                 CC          COLOMBIA            1           1994-05-03
# 955398                 CC          COLOMBIA            0           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 955354                   76.0              CALI                76001.0
# 955379                   11.0            BOGOTA                11001.0
# 955390                   50.0     VILLAVICENCIO                50001.0
# 955395                    8.0      BARRANQUILLA                 8001.0
# 955398                   15.0             TUNJA                15001.0
#
#                                         ESTU_COLE_TERMINO  \
# 955354  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 955379   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 955390                                COLEGIO CORAZONISTA
# 955395                                           PABLO VI
# 955398                              COLEGIO REAL DE MARES
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 955354                               4                       0
# 955379                               0                       0
# 955390                               0                       0
# 955395                               4                       0
# 955398                               0                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 955354                          0                         0
# 955379                          1                         0
# 955390                          1                         0
# 955395                          1                         0
# 955398                          0                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 955354                         1                        0
# 955379                         1                        0
# 955390                         1                        0
# 955395                         1                        0
# 955398                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 955354                            0                              0
# 955379                            0                              0
# 955390                            0                              0
# 955395                            0                              0
# 955398                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 955354                     CC                    8                    5
# 955379                     TI                    8                    5
# 955390                     TI                    5                    1
# 955395                     TI                    8                    7
# 955398                     CC                    7                    9
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 955354                     3                   0                     1
# 955379                     2                   1                     1
# 955390                     4                   1                     1
# 955395                     2                   0                     1
# 955398                     3                   1                     1
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 955354                   1                    0                        1
# 955379                   1                    0                        1
# 955390                   1                    1                        1
# 955395                   1                    0                        1
# 955398                   1                    1                        1
#
#         INST_COD_INSTITUCION  \
# 955354                  4109
# 955379                  4813
# 955390                  3712
# 955395                  3117
# 955398                  1106
#
#                                   INST_NOMBRE_INSTITUCION  \
# 955354  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 955379  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 955390  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 955395             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 955398  UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMB...
#
#                                       ESTU_PRGM_ACADEMICO  \
# 955354           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 955379   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 955390                           TECNOLOGIA EN INDUSTRIAL
# 955395  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 955398  TÉCNICA PROFESIONAL EN PROCESOS COMERCIALES Y ...
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 955354                   76001                CALI                      29
# 955379                   11001              BOGOTA                       3
# 955390                   50001       VILLAVICENCIO                      19
# 955395                    8758             SOLEDAD                       2
# 955398                   15001               TUNJA                       5
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 955354       TÉCNICO PROFESIONAL                 2                    46
# 955379       TÉCNICO PROFESIONAL                 2                    31
# 955390                TECNOLOGÍA                 2                    33
# 955395                TECNOLOGÍA                 2                    31
# 955398       TÉCNICO PROFESIONAL                 1                    47
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 955354                 76001.0                CALI                  VALLE
# 955379                 11001.0              BOGOTA                 BOGOTA
# 955390                 11001.0              BOGOTA                 BOGOTA
# 955395                  8758.0             SOLEDAD              ATLANTICO
# 955398                 15001.0               TUNJA                 BOYACA
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 955354                        3            4                        76001
# 955379                        3            0                        11001
# 955390                        1            1                        50001
# 955395                        2            4                         8001
# 955398                        4            4                        15001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 955354                    CALI                   VALLE
# 955379                  BOGOTÁ                  BOGOTA
# 955390           VILLAVICENCIO                    META
# 955395            BARRANQUILLA               ATLANTICO
# 955398                   TUNJA                  BOYACA
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 955354                           76                      136.5
# 955379                           11                      192.0
# 955390                           50                      166.5
# 955395                            8                      154.5
# 955398                           15                      153.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 955354                          34.0                     145.5
# 955379                          92.0                     187.5
# 955390                          70.0                     132.0
# 955395                          55.0                     205.5
# 955398                          54.0                     193.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 955354                      45.0                      148.5
# 955379                      89.0                      199.5
# 955390                      28.0                      142.5
# 955395                      97.0                      207.0
# 955398                      92.0                      180.0
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 955354                       47.0            120.0              -A1
# 955379                       96.0            181.5               A2
# 955390                       39.0            169.5               A2
# 955395                       98.0            174.0               A2
# 955398                       84.0            159.0               A2
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                    156.0                         3
# 955379             85.0                    180.0                         3
# 955390             76.0                    165.0                         3
# 955395             80.0                    205.5                         4
# 955398             66.0                    159.0                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO
# 955354      Normal                 Q3
# 955379      Normal                 Q4
# 955390      Normal                 Q4
# 955395      Normal                 Q3
# 955398      Normal                 Q3

# %%
# That's just for classification
#clf = DecisionTreeClassifier(criterion = "entropy", splitter = "random", max_depth = 10,  min_samples_split = 100, min_samples_leaf = 5, max_features = 10)
#clf=DecisionTreeClassifier(criterion = "gini", splitter = "random", max_depth = 10)
#clf = RandomForestClassifier(criterion = "entropy",  max_depth = 10,  min_samples_split = 1000,min_samples_leaf = 20, max_features = 10)
#clf_new =RandomForestClassifier(criterion = "entropy", max_depth = 12, max_features = 4)

# %%
# Train Decision Tree Classifer
covariates=['ESTU_GENERO','INST_ORIGEN','FAMI_ESTRATOVIVIENDA',\
            'ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO',\
            'ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']

# %%
len(covariates)
# Out:
# 8

# %%
# Metricas

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(df_t[covariates],
                                                    df_t['MOD_RAZONA_CUANTITAT_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train shape: ', X_train.shape)
print('X_test shape: ', X_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (36342, 8)
# X_test shape:  (12114, 8)
# y_train shape:  (36342,)
# y_test shape:  (12114,)

# %%
X_train
# Out:
#          ESTU_GENERO  INST_ORIGEN  FAMI_ESTRATOVIVIENDA  ESTU_METODO_PRGM  \
# 1263721            1            4                     1                 0
# 1497680            1            4                     1                 2
# 1529555            0            4                     3                 2
# 1283353            0            4                     3                 0
# 1570253            1            4                     2                 2
# ...              ...          ...                   ...               ...
# 1387511            1            4                     1                 2
# 1210568            1            4                     2                 2
# 1276771            1            4                     2                 2
# 1403325            0            4                     2                 2
# 1321064            0            4                     2                 2
#
#          INST_CARACTER_ACADEMICO  ESTU_VALORMATRICULAUNIVERSIDAD  \
# 1263721                        1                               7
# 1497680                        1                               7
# 1529555                        1                               7
# 1283353                        1                               7
# 1570253                        1                               7
# ...                          ...                             ...
# 1387511                        1                               7
# 1210568                        2                               4
# 1276771                        2                               4
# 1403325                        1                               7
# 1321064                        1                               7
#
#          ESTU_PRGM_DEPARTAMENTO  ESTU_NUCLEO_PREGRADO
# 1263721                       3                     1
# 1497680                      28                    34
# 1529555                       0                     1
# 1283353                       3                     1
# 1570253                      28                     1
# ...                         ...                   ...
# 1387511                       3                    47
# 1210568                       3                     7
# 1276771                      26                    -1
# 1403325                      13                     1
# 1321064                       3                    30
#
# [36342 rows x 8 columns]

# %%
X_test
# Out:
#          ESTU_GENERO  INST_ORIGEN  FAMI_ESTRATOVIVIENDA  ESTU_METODO_PRGM  \
# 1217427            1            4                     2                 2
# 1057916            1            1                     2                 2
# 1133623            0            1                     1                 0
# 1079821            0            4                     2                 2
# 1356879            0            2                     1                 2
# ...              ...          ...                   ...               ...
# 1445262            1            4                     2                 2
# 1576944            1            4                     1                 2
# 1319548            1            1                     3                 2
# 1556137            1            4                     2                 2
# 1536880            0            4                     1                 2
#
#          INST_CARACTER_ACADEMICO  ESTU_VALORMATRICULAUNIVERSIDAD  \
# 1217427                        1                               4
# 1057916                        1                               0
# 1133623                        1                               0
# 1079821                        1                               7
# 1356879                        4                               4
# ...                          ...                             ...
# 1445262                        1                               7
# 1576944                        2                               0
# 1319548                        3                               5
# 1556137                        2                               0
# 1536880                        1                               7
#
#          ESTU_PRGM_DEPARTAMENTO  ESTU_NUCLEO_PREGRADO
# 1217427                       4                     1
# 1057916                       3                    33
# 1133623                       2                    -1
# 1079821                      16                    48
# 1356879                      18                     1
# ...                         ...                   ...
# 1445262                       3                    34
# 1576944                      13                    18
# 1319548                       3                     1
# 1556137                       2                    18
# 1536880                       9                    46
#
# [12114 rows x 8 columns]

# %%
# Create the Regression model with Random Forest
RandomforestRegModel= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred=RandomforestRegModel.predict(X_test)

# %%
y_pred
# Out:
# array([137.46338277, 163.28958002, 134.1054143 , ..., 146.46424079,
#        125.8778173 , 122.64153237])

# %%
y_test
# Out:
# 1217427     97.5
# 1057916    157.5
# 1133623    172.5
# 1079821    169.5
# 1356879    160.5
#            ...
# 1445262    189.0
# 1576944     75.0
# 1319548    109.5
# 1556137     91.5
# 1536880     76.5
# Name: MOD_RAZONA_CUANTITAT_PUNT, Length: 12114, dtype: float64

# %%
#MOD_RAZONA_CUANTITAT_PUNT
comparar=pd.DataFrame(y_pred, y_test)
comparar.head(20)
# Out:
#                                     0
# MOD_RAZONA_CUANTITAT_PUNT
# 97.5                       137.463383
# 157.5                      163.289580
# 172.5                      134.105414
# 169.5                      130.829344
# 160.5                      133.482033
# 123.0                      139.195932
# 126.0                      136.647781
# 150.0                      141.552252
# 114.0                      129.551782
# 81.0                       124.903066
# 193.5                      141.552252
# 150.0                      138.614253
# 97.5                       109.898844
# 168.0                      156.694050
# 141.0                      133.347617
# 114.0                      122.778590
# 117.0                      129.444595
# 145.5                      139.599229
# 160.5                      127.646386
# 162.0                      129.551782

# %%
import statsmodels.api as sm
res = y_pred-y_test # residuals
#print(res)
fig=sm.qqplot(res,fit=True, line='45')

# %%
#Evaluate the Random forest regression model

# %%
def MAE(prediction,true_values):
    return np.mean(                                                      # Mean
                np.abs(                                                   # Absolute
                        prediction-true_values                            # Error
                    )
                )

# %%
def RMSE(prediction,true_values):
    
    return np.sqrt(                                                          # Root
            np.mean(                                                      # Mean
                np.square(                                                # Squared
                         prediction-true_values                           # Error
                )
            )
        )

# %%
def MAPE(prediction,true_value):
    return np.mean(                                           # Mean
        np.abs(                                               # Absolute
               (prediction-true_value)/true_value             # Error
            )*100                                            # Percentage
    )

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model RAZON CUANTI', MAE(y_pred,y_test))
print('RMSE of the model RAZON CUANTI', RMSE(y_pred,y_test))
print('MAPE of the model RAZON CUANTI', MAPE(y_pred,y_test))
print('Accuracy of the model RAZON CUANTI', 100-MAPE(y_pred,y_test))
# Out:
# MAE of the model RAZON CUANTI 24.311850960100386
# RMSE of the model RAZON CUANTI 29.997653822694087
# MAPE of the model RAZON CUANTI 19.65934459757357
# Accuracy of the model RAZON CUANTI 80.34065540242644

# %%
# Important variables

feature_list= list(df_t[covariates].columns)
# Get numerical feature importances
importances = list(RandomforestRegModel.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_RAZONA_CUANTITAT_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# MOD_RAZONA_CUANTITAT_PUNT
#
# Variable: INST_ORIGEN          Importance: 0.42
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.21
# Variable: ESTU_GENERO          Importance: 0.12
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.08
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.07
# Variable: INST_CARACTER_ACADEMICO Importance: 0.05
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.04
# Variable: ESTU_METODO_PRGM     Importance: 0.0

# %% [markdown]
# **QUANTILES**

# %%
df_sabertyt
# Out:
#         ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                  CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                  CC          COLOMBIA           F           1992-07-01
# 955390                  CC          COLOMBIA           F           1992-10-08
# 955395                  CC          COLOMBIA           M           1994-05-03
# 955398                  CC          COLOMBIA           F           1987-07-31
# ...                    ...               ...         ...                  ...
# 1580568                 CC          COLOMBIA           M  1996-05-28 12:00:00
# 1580569                 CC          COLOMBIA           M  1998-10-04 12:00:00
# 1580570                 CC          COLOMBIA           M  1999-06-19 12:00:00
# 1580571                 CC          COLOMBIA           M  1998-10-08 12:00:00
# 1580572                 CC          COLOMBIA           M  1997-08-28 12:00:00
#
#          PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354     20161   EK201610110512      ESTUDIANTE             VALLE
# 955379     20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390     20161   EK201610085857      ESTUDIANTE              META
# 955395     20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398     20161   EK201610063234      ESTUDIANTE            BOYACA
# ...          ...              ...             ...               ...
# 1580568    20195   EK201950042257      ESTUDIANTE            BOYACA
# 1580569    20195   EK201950042514      ESTUDIANTE            BOYACA
# 1580570    20195   EK201950044146      ESTUDIANTE            BOYACA
# 1580571    20195   EK201950042208      ESTUDIANTE            BOYACA
# 1580572    20195   EK201950042462      ESTUDIANTE            BOYACA
#
#          ESTU_COD_RESIDE_DEPTO      ESTU_MCPIO_RESIDE  ...  MOD_INGLES_DESEM  \
# 955354                    76.0                   CALI  ...               -A1
# 955379                    11.0                 BOGOTA  ...                A2
# 955390                    50.0          VILLAVICENCIO  ...                A2
# 955395                     8.0           BARRANQUILLA  ...                A2
# 955398                    15.0                  TUNJA  ...                A2
# ...                        ...                    ...  ...               ...
# 1580568                   15.0  SANTA ROSA DE VITERBO  ...                A1
# 1580569                   15.0  SANTA ROSA DE VITERBO  ...                A2
# 1580570                   15.0  SANTA ROSA DE VITERBO  ...               -A1
# 1580571                   15.0            SANTA MARIA  ...                A2
# 1580572                   15.0  SANTA ROSA DE VITERBO  ...                A1
#
#         MOD_INGLES_PNAL MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                   156.0                        3
# 955379             85.0                   180.0                        3
# 955390             76.0                   165.0                        3
# 955395             80.0                   205.5                        4
# 955398             66.0                   159.0                        3
# ...                 ...                     ...                      ...
# 1580568            45.0                   108.0                        1
# 1580569            86.0                   220.5                        4
# 1580570            21.0                   205.5                        4
# 1580571            65.0                   151.5                        2
# 1580572            42.0                   192.0                        4
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
# ...                         ...                      ...       ...       ...
# 1580568                     6.0                 PUBLICAR     20192  SaberTyT
# 1580569                    92.0                 PUBLICAR     20192  SaberTyT
# 1580570                    90.0                 PUBLICAR     20192  SaberTyT
# 1580571                    40.0                 PUBLICAR     20192  SaberTyT
# 1580572                    83.0                 PUBLICAR     20192  SaberTyT
#
#         TIPO_PRUEBA group_CUANTITATIVO
# 955354       Normal                 Q3
# 955379       Normal                 Q4
# 955390       Normal                 Q4
# 955395       Normal                 Q3
# 955398       Normal                 Q3
# ...             ...                ...
# 1580568      Normal                 Q3
# 1580569      Normal                 Q3
# 1580570      Normal                 Q1
# 1580571      Normal                 Q4
# 1580572      Normal                 Q4
#
# [48456 rows x 64 columns]

# %%
df_sabertyt['group_LECTURA'] = pd.cut(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_LECTURA_CRITICA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])

# %%
df_sabertyt['group_COMPETENCIA'] = pd.cut(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_COMPETEN_CIUDADA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])

# %%
df_sabertyt['group_INGLES'] = pd.cut(df_sabertyt['MOD_INGLES_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_INGLES_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_INGLES_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])

# %%
df_sabertyt['group_ESCRITA'] = pd.cut(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],
                     bins=[0, np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.25 ), np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.5 ),\
                           np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],0.75 ), np.quantile(df_sabertyt['MOD_COMUNI_ESCRITA_PUNT'],1 )],
                     labels=["Q1", "Q2", "Q3", "Q4"])

# %%
df_sabertyt
# Out:
#         ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                  CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                  CC          COLOMBIA           F           1992-07-01
# 955390                  CC          COLOMBIA           F           1992-10-08
# 955395                  CC          COLOMBIA           M           1994-05-03
# 955398                  CC          COLOMBIA           F           1987-07-31
# ...                    ...               ...         ...                  ...
# 1580568                 CC          COLOMBIA           M  1996-05-28 12:00:00
# 1580569                 CC          COLOMBIA           M  1998-10-04 12:00:00
# 1580570                 CC          COLOMBIA           M  1999-06-19 12:00:00
# 1580571                 CC          COLOMBIA           M  1998-10-08 12:00:00
# 1580572                 CC          COLOMBIA           M  1997-08-28 12:00:00
#
#          PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354     20161   EK201610110512      ESTUDIANTE             VALLE
# 955379     20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390     20161   EK201610085857      ESTUDIANTE              META
# 955395     20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398     20161   EK201610063234      ESTUDIANTE            BOYACA
# ...          ...              ...             ...               ...
# 1580568    20195   EK201950042257      ESTUDIANTE            BOYACA
# 1580569    20195   EK201950042514      ESTUDIANTE            BOYACA
# 1580570    20195   EK201950044146      ESTUDIANTE            BOYACA
# 1580571    20195   EK201950042208      ESTUDIANTE            BOYACA
# 1580572    20195   EK201950042462      ESTUDIANTE            BOYACA
#
#          ESTU_COD_RESIDE_DEPTO      ESTU_MCPIO_RESIDE  ...  \
# 955354                    76.0                   CALI  ...
# 955379                    11.0                 BOGOTA  ...
# 955390                    50.0          VILLAVICENCIO  ...
# 955395                     8.0           BARRANQUILLA  ...
# 955398                    15.0                  TUNJA  ...
# ...                        ...                    ...  ...
# 1580568                   15.0  SANTA ROSA DE VITERBO  ...
# 1580569                   15.0  SANTA ROSA DE VITERBO  ...
# 1580570                   15.0  SANTA ROSA DE VITERBO  ...
# 1580571                   15.0            SANTA MARIA  ...
# 1580572                   15.0  SANTA ROSA DE VITERBO  ...
#
#          MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                      53.0                 PUBLICAR     20161  SaberTyT
# 955379                      84.0                 PUBLICAR     20161  SaberTyT
# 955390                      67.0                 PUBLICAR     20161  SaberTyT
# 955395                      99.0                 PUBLICAR     20161  SaberTyT
# 955398                      59.0                 PUBLICAR     20161  SaberTyT
# ...                          ...                      ...       ...       ...
# 1580568                      6.0                 PUBLICAR     20192  SaberTyT
# 1580569                     92.0                 PUBLICAR     20192  SaberTyT
# 1580570                     90.0                 PUBLICAR     20192  SaberTyT
# 1580571                     40.0                 PUBLICAR     20192  SaberTyT
# 1580572                     83.0                 PUBLICAR     20192  SaberTyT
#
#         TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 955354       Normal                 Q3            Q3                Q3
# 955379       Normal                 Q4            Q4                Q4
# 955390       Normal                 Q4            Q2                Q3
# 955395       Normal                 Q3            Q4                Q4
# 955398       Normal                 Q3            Q4                Q4
# ...             ...                ...           ...               ...
# 1580568      Normal                 Q3            Q2                Q4
# 1580569      Normal                 Q3            Q2                Q1
# 1580570      Normal                 Q1            Q2                Q3
# 1580571      Normal                 Q4            Q4                Q4
# 1580572      Normal                 Q4            Q2                Q1
#
#         group_INGLES group_ESCRITA
# 955354            Q1            Q3
# 955379            Q4            Q4
# 955390            Q4            Q3
# 955395            Q4            Q4
# 955398            Q3            Q3
# ...              ...           ...
# 1580568           Q2            Q1
# 1580569           Q4            Q4
# 1580570           Q1            Q4
# 1580571           Q3            Q2
# 1580572           Q2            Q4
#
# [48456 rows x 68 columns]

# %%
df_sabertyt["group_LECTURA"] = df_sabertyt["group_LECTURA"].astype('category')
df_sabertyt["group_COMPETENCIA"] = df_sabertyt["group_COMPETENCIA"].astype('category')
df_sabertyt["group_INGLES"] = df_sabertyt["group_INGLES"].astype('category')
df_sabertyt["group_ESCRITA"] = df_sabertyt["group_ESCRITA"].astype('category')

# %%
df_sabertyt.dtypes
# Out:
# ESTU_TIPODOCUMENTO        object
# ESTU_NACIONALIDAD         object
# ESTU_GENERO             category
# ESTU_FECHANACIMIENTO      object
# PERIODO                    int64
#                           ...
# group_CUANTITATIVO      category
# group_LECTURA           category
# group_COMPETENCIA       category
# group_INGLES            category
# group_ESCRITA           category
# Length: 68, dtype: object

# %%
df_sabertyt.shape
# Out:
# (48456, 68)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_LECTURA'])

# %%
df_sabertyt.shape
# Out:
# (48453, 68)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_COMPETENCIA'])

# %%
df_sabertyt.shape
# Out:
# (48445, 68)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_INGLES'])

# %%
df_sabertyt.shape
# Out:
# (48396, 68)

# %%
df_sabertyt=df_sabertyt.dropna(subset=['group_ESCRITA'])

# %%
df_sabertyt.shape
# Out:
# (48111, 68)

# %% [markdown]
# **MOD_LECTURA_CRITICA_PUNT**

# %%
df_sabertyt.head()
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA           F  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA           F           1992-07-01
# 955390                 CC          COLOMBIA           F           1992-10-08
# 955395                 CC          COLOMBIA           M           1994-05-03
# 955398                 CC          COLOMBIA           F           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ...  MOD_COMUNI_ESCRITA_PNAL  \
# 955354                   76.0              CALI  ...                     53.0
# 955379                   11.0            BOGOTA  ...                     84.0
# 955390                   50.0     VILLAVICENCIO  ...                     67.0
# 955395                    8.0      BARRANQUILLA  ...                     99.0
# 955398                   15.0             TUNJA  ...                     59.0
#
#        ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA TIPO_PRUEBA  \
# 955354                 PUBLICAR     20161  SaberTyT      Normal
# 955379                 PUBLICAR     20161  SaberTyT      Normal
# 955390                 PUBLICAR     20161  SaberTyT      Normal
# 955395                 PUBLICAR     20161  SaberTyT      Normal
# 955398                 PUBLICAR     20161  SaberTyT      Normal
#
#        group_CUANTITATIVO group_LECTURA group_COMPETENCIA group_INGLES  \
# 955354                 Q3            Q3                Q3           Q1
# 955379                 Q4            Q4                Q4           Q4
# 955390                 Q4            Q2                Q3           Q4
# 955395                 Q3            Q4                Q4           Q4
# 955398                 Q3            Q4                Q4           Q3
#
#        group_ESCRITA
# 955354            Q3
# 955379            Q4
# 955390            Q3
# 955395            Q4
# 955398            Q3
#
# [5 rows x 68 columns]

# %%
df_t_lectura=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_lectura[var]=df_t_lectura[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_lectura.head())
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA            0  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA            0           1992-07-01
# 955390                 CC          COLOMBIA            0           1992-10-08
# 955395                 CC          COLOMBIA            1           1994-05-03
# 955398                 CC          COLOMBIA            0           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 955354                   76.0              CALI                76001.0
# 955379                   11.0            BOGOTA                11001.0
# 955390                   50.0     VILLAVICENCIO                50001.0
# 955395                    8.0      BARRANQUILLA                 8001.0
# 955398                   15.0             TUNJA                15001.0
#
#                                         ESTU_COLE_TERMINO  \
# 955354  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 955379   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 955390                                COLEGIO CORAZONISTA
# 955395                                           PABLO VI
# 955398                              COLEGIO REAL DE MARES
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 955354                               4                       0
# 955379                               0                       0
# 955390                               0                       0
# 955395                               4                       0
# 955398                               0                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 955354                          0                         0
# 955379                          1                         0
# 955390                          1                         0
# 955395                          1                         0
# 955398                          0                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 955354                         1                        0
# 955379                         1                        0
# 955390                         1                        0
# 955395                         1                        0
# 955398                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 955354                            0                              0
# 955379                            0                              0
# 955390                            0                              0
# 955395                            0                              0
# 955398                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 955354                     CC                    8                    5
# 955379                     TI                    8                    5
# 955390                     TI                    5                    1
# 955395                     TI                    8                    7
# 955398                     CC                    7                    9
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 955354                     3                   0                     1
# 955379                     2                   1                     1
# 955390                     4                   1                     1
# 955395                     2                   0                     1
# 955398                     3                   1                     1
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 955354                   1                    0                        1
# 955379                   1                    0                        1
# 955390                   1                    1                        1
# 955395                   1                    0                        1
# 955398                   1                    1                        1
#
#         INST_COD_INSTITUCION  \
# 955354                  4109
# 955379                  4813
# 955390                  3712
# 955395                  3117
# 955398                  1106
#
#                                   INST_NOMBRE_INSTITUCION  \
# 955354  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 955379  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 955390  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 955395             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 955398  UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMB...
#
#                                       ESTU_PRGM_ACADEMICO  \
# 955354           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 955379   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 955390                           TECNOLOGIA EN INDUSTRIAL
# 955395  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 955398  TÉCNICA PROFESIONAL EN PROCESOS COMERCIALES Y ...
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 955354                   76001                CALI                      29
# 955379                   11001              BOGOTA                       3
# 955390                   50001       VILLAVICENCIO                      19
# 955395                    8758             SOLEDAD                       2
# 955398                   15001               TUNJA                       5
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 955354       TÉCNICO PROFESIONAL                 2                    46
# 955379       TÉCNICO PROFESIONAL                 2                    31
# 955390                TECNOLOGÍA                 2                    33
# 955395                TECNOLOGÍA                 2                    31
# 955398       TÉCNICO PROFESIONAL                 1                    47
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 955354                 76001.0                CALI                  VALLE
# 955379                 11001.0              BOGOTA                 BOGOTA
# 955390                 11001.0              BOGOTA                 BOGOTA
# 955395                  8758.0             SOLEDAD              ATLANTICO
# 955398                 15001.0               TUNJA                 BOYACA
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 955354                        3            4                        76001
# 955379                        3            0                        11001
# 955390                        1            1                        50001
# 955395                        2            4                         8001
# 955398                        4            4                        15001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 955354                    CALI                   VALLE
# 955379                  BOGOTÁ                  BOGOTA
# 955390           VILLAVICENCIO                    META
# 955395            BARRANQUILLA               ATLANTICO
# 955398                   TUNJA                  BOYACA
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 955354                           76                      136.5
# 955379                           11                      192.0
# 955390                           50                      166.5
# 955395                            8                      154.5
# 955398                           15                      153.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 955354                          34.0                     145.5
# 955379                          92.0                     187.5
# 955390                          70.0                     132.0
# 955395                          55.0                     205.5
# 955398                          54.0                     193.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 955354                      45.0                      148.5
# 955379                      89.0                      199.5
# 955390                      28.0                      142.5
# 955395                      97.0                      207.0
# 955398                      92.0                      180.0
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 955354                       47.0            120.0              -A1
# 955379                       96.0            181.5               A2
# 955390                       39.0            169.5               A2
# 955395                       98.0            174.0               A2
# 955398                       84.0            159.0               A2
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                    156.0                         3
# 955379             85.0                    180.0                         3
# 955390             76.0                    165.0                         3
# 955395             80.0                    205.5                         4
# 955398             66.0                    159.0                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 955354      Normal                 Q3            Q3                Q3
# 955379      Normal                 Q4            Q4                Q4
# 955390      Normal                 Q4            Q2                Q3
# 955395      Normal                 Q3            Q4                Q4
# 955398      Normal                 Q3            Q4                Q4
#
#        group_INGLES group_ESCRITA
# 955354           Q1            Q3
# 955379           Q4            Q4
# 955390           Q4            Q3
# 955395           Q4            Q4
# 955398           Q3            Q3

# %%
X_train_lect, X_test_lect, y_train_lect, y_test_lect = train_test_split(df_t_lectura[covariates],
                                                    df_t_lectura['MOD_LECTURA_CRITICA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_lect shape: ', X_train_lect.shape)
print('X_test_lect shape: ', X_test_lect.shape)
print('y_train_lect shape: ', y_train_lect.shape)
print('y_test_lect shape: ', y_test_lect.shape)
# Out:
# X_train_lect shape:  (36083, 8)
# X_test_lect shape:  (12028, 8)
# y_train_lect shape:  (36083,)
# y_test_lect shape:  (12028,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_lectura= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_lectura.fit(X_train_lect, y_train_lect)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_lect=RandomforestRegModel_lectura.predict(X_test_lect)

# %%
#MOD_LECTURA_CRITICA_PUNT
comparar_lect=pd.DataFrame(y_pred_lect, y_test_lect)
comparar_lect.head(20)
# Out:
#                                    0
# MOD_LECTURA_CRITICA_PUNT
# 108.0                     139.173979
# 186.0                     157.927488
# 190.5                     144.150033
# 147.0                     156.306473
# 103.5                     141.637969
# 97.5                      137.973862
# 96.0                      136.253230
# 160.5                     147.188262
# 61.5                      136.480656
# 160.5                     147.270013
# 144.0                     136.649075
# 120.0                     146.651457
# 138.0                     143.885643
# 126.0                     129.066493
# 132.0                     130.842975
# 130.5                     139.058235
# 135.0                     147.186885
# 142.5                     137.610157
# 91.5                      155.678121
# 111.0                     139.173979

# %%
res_lect = y_pred_lect-y_test_lect # residuals
#print(res)
fig=sm.qqplot(res_lect,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model LECTURA', MAE(y_pred_lect,y_test_lect))
print('RMSE of the model LECTURA', RMSE(y_pred_lect,y_test_lect))
print('MAPE of the model LECTURA', MAPE(y_pred_lect,y_test_lect))
print('Accuracy of the model LECTURA', 100-MAPE(y_pred_lect,y_test_lect))
# Out:
# MAE of the model LECTURA 24.58435100359897
# RMSE of the model LECTURA 30.597175573605895
# MAPE of the model LECTURA 18.870851086219442
# Accuracy of the model LECTURA 81.12914891378055

# %%
# Important variables

feature_list_lectura= list(df_t_lectura[covariates].columns)
# Get numerical feature importances
importances_lectura = list(RandomforestRegModel_lectura.feature_importances_)
# List of tuples with variable and importance
feature_importances_lectura = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_lectura, importances_lectura)]
# Sort the feature importances by most important first
feature_importances_lectura = sorted(feature_importances_lectura, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_LECTURA_CRITICA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_lectura];
# Out:
# MOD_LECTURA_CRITICA_PUNT
#
# Variable: INST_ORIGEN          Importance: 0.36
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.2
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.16
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.11
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.08
# Variable: INST_CARACTER_ACADEMICO Importance: 0.07
# Variable: ESTU_GENERO          Importance: 0.01
# Variable: ESTU_METODO_PRGM     Importance: 0.01

# %% [markdown]
# **MOD_COMPETEN_CIUDADA_PUNT**

# %%
df_t_competencia=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_competencia[var]=df_t_competencia[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_competencia.head())
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA            0  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA            0           1992-07-01
# 955390                 CC          COLOMBIA            0           1992-10-08
# 955395                 CC          COLOMBIA            1           1994-05-03
# 955398                 CC          COLOMBIA            0           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 955354                   76.0              CALI                76001.0
# 955379                   11.0            BOGOTA                11001.0
# 955390                   50.0     VILLAVICENCIO                50001.0
# 955395                    8.0      BARRANQUILLA                 8001.0
# 955398                   15.0             TUNJA                15001.0
#
#                                         ESTU_COLE_TERMINO  \
# 955354  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 955379   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 955390                                COLEGIO CORAZONISTA
# 955395                                           PABLO VI
# 955398                              COLEGIO REAL DE MARES
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 955354                               4                       0
# 955379                               0                       0
# 955390                               0                       0
# 955395                               4                       0
# 955398                               0                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 955354                          0                         0
# 955379                          1                         0
# 955390                          1                         0
# 955395                          1                         0
# 955398                          0                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 955354                         1                        0
# 955379                         1                        0
# 955390                         1                        0
# 955395                         1                        0
# 955398                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 955354                            0                              0
# 955379                            0                              0
# 955390                            0                              0
# 955395                            0                              0
# 955398                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 955354                     CC                    8                    5
# 955379                     TI                    8                    5
# 955390                     TI                    5                    1
# 955395                     TI                    8                    7
# 955398                     CC                    7                    9
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 955354                     3                   0                     1
# 955379                     2                   1                     1
# 955390                     4                   1                     1
# 955395                     2                   0                     1
# 955398                     3                   1                     1
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 955354                   1                    0                        1
# 955379                   1                    0                        1
# 955390                   1                    1                        1
# 955395                   1                    0                        1
# 955398                   1                    1                        1
#
#         INST_COD_INSTITUCION  \
# 955354                  4109
# 955379                  4813
# 955390                  3712
# 955395                  3117
# 955398                  1106
#
#                                   INST_NOMBRE_INSTITUCION  \
# 955354  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 955379  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 955390  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 955395             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 955398  UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMB...
#
#                                       ESTU_PRGM_ACADEMICO  \
# 955354           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 955379   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 955390                           TECNOLOGIA EN INDUSTRIAL
# 955395  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 955398  TÉCNICA PROFESIONAL EN PROCESOS COMERCIALES Y ...
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 955354                   76001                CALI                      29
# 955379                   11001              BOGOTA                       3
# 955390                   50001       VILLAVICENCIO                      19
# 955395                    8758             SOLEDAD                       2
# 955398                   15001               TUNJA                       5
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 955354       TÉCNICO PROFESIONAL                 2                    46
# 955379       TÉCNICO PROFESIONAL                 2                    31
# 955390                TECNOLOGÍA                 2                    33
# 955395                TECNOLOGÍA                 2                    31
# 955398       TÉCNICO PROFESIONAL                 1                    47
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 955354                 76001.0                CALI                  VALLE
# 955379                 11001.0              BOGOTA                 BOGOTA
# 955390                 11001.0              BOGOTA                 BOGOTA
# 955395                  8758.0             SOLEDAD              ATLANTICO
# 955398                 15001.0               TUNJA                 BOYACA
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 955354                        3            4                        76001
# 955379                        3            0                        11001
# 955390                        1            1                        50001
# 955395                        2            4                         8001
# 955398                        4            4                        15001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 955354                    CALI                   VALLE
# 955379                  BOGOTÁ                  BOGOTA
# 955390           VILLAVICENCIO                    META
# 955395            BARRANQUILLA               ATLANTICO
# 955398                   TUNJA                  BOYACA
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 955354                           76                      136.5
# 955379                           11                      192.0
# 955390                           50                      166.5
# 955395                            8                      154.5
# 955398                           15                      153.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 955354                          34.0                     145.5
# 955379                          92.0                     187.5
# 955390                          70.0                     132.0
# 955395                          55.0                     205.5
# 955398                          54.0                     193.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 955354                      45.0                      148.5
# 955379                      89.0                      199.5
# 955390                      28.0                      142.5
# 955395                      97.0                      207.0
# 955398                      92.0                      180.0
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 955354                       47.0            120.0              -A1
# 955379                       96.0            181.5               A2
# 955390                       39.0            169.5               A2
# 955395                       98.0            174.0               A2
# 955398                       84.0            159.0               A2
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                    156.0                         3
# 955379             85.0                    180.0                         3
# 955390             76.0                    165.0                         3
# 955395             80.0                    205.5                         4
# 955398             66.0                    159.0                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 955354      Normal                 Q3            Q3                Q3
# 955379      Normal                 Q4            Q4                Q4
# 955390      Normal                 Q4            Q2                Q3
# 955395      Normal                 Q3            Q4                Q4
# 955398      Normal                 Q3            Q4                Q4
#
#        group_INGLES group_ESCRITA
# 955354           Q1            Q3
# 955379           Q4            Q4
# 955390           Q4            Q3
# 955395           Q4            Q4
# 955398           Q3            Q3

# %%
X_train_compet, X_test_compet, y_train_compet, y_test_compet = train_test_split(df_t_competencia[covariates],
                                                    df_t_competencia['MOD_COMPETEN_CIUDADA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_compet shape: ', X_train_compet.shape)
print('X_test_compet shape: ', X_test_compet.shape)
print('y_train_compet shape: ', y_train_compet.shape)
print('y_test_compet shape: ', y_test_compet.shape)
# Out:
# X_train_compet shape:  (36083, 8)
# X_test_compet shape:  (12028, 8)
# y_train_compet shape:  (36083,)
# y_test_compet shape:  (12028,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_competencia= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_competencia.fit(X_train_compet, y_train_compet)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_compet=RandomforestRegModel_competencia.predict(X_test_compet)

# %%
#MOD_COMPETEN_CIUDADA_PUNT
comparar_compet=pd.DataFrame(y_pred_compet, y_test_compet)
comparar_compet.head(20)
# Out:
#                                     0
# MOD_COMPETEN_CIUDADA_PUNT
# 91.5                       134.517013
# 163.5                      158.241495
# 184.5                      141.882861
# 166.5                      153.862598
# 91.5                       141.640918
# 96.0                       130.608851
# 82.5                       130.566656
# 175.5                      144.438577
# 76.5                       136.046156
# 175.5                      146.764374
# 130.5                      133.460331
# 111.0                      141.603552
# 157.5                      141.442481
# 153.0                      137.344660
# 97.5                       134.939185
# 124.5                      141.578507
# 160.5                      144.678532
# 108.0                      130.780057
# 108.0                      147.700707
# 99.0                       134.517013

# %%
res_compet = y_pred_compet-y_test_compet # residuals
#print(res)
fig=sm.qqplot(res_compet,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model COMPETENCIA', MAE(y_pred_compet,y_test_compet))
print('RMSE of the model COMNPETENCIA', RMSE(y_pred_compet,y_test_compet))
print('MAPE of the model COMPETENCIA', MAPE(y_pred_compet,y_test_compet))
print('Accuracy of the model COMPETENCIA', 100-MAPE(y_pred_compet,y_test_compet))
# Out:
# MAE of the model COMPETENCIA 26.75125639193686
# RMSE of the model COMNPETENCIA 32.72598979033066
# MAPE of the model COMPETENCIA 20.472462710244464
# Accuracy of the model COMPETENCIA 79.52753728975554

# %%
# Important variables COMPETENCIA

feature_list_competencia= list(df_t_competencia[covariates].columns)
# Get numerical feature importances
importances_competencia = list(RandomforestRegModel_competencia.feature_importances_)
# List of tuples with variable and importance
feature_importances_competencia = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_competencia, importances_competencia)]
# Sort the feature importances by most important first
feature_importances_competencia = sorted(feature_importances_competencia, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_COMPETEN_CIUDADA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_competencia];
# Out:
# MOD_COMPETEN_CIUDADA_PUNT
#
# Variable: INST_ORIGEN          Importance: 0.36
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.22
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.18
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.08
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.07
# Variable: INST_CARACTER_ACADEMICO Importance: 0.05
# Variable: ESTU_GENERO          Importance: 0.03
# Variable: ESTU_METODO_PRGM     Importance: 0.01

# %% [markdown]
# **MOD_INGLES_PUNT**

# %%
df_t_ingles=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_ingles[var]=df_t_ingles[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_ingles.head())
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA            0  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA            0           1992-07-01
# 955390                 CC          COLOMBIA            0           1992-10-08
# 955395                 CC          COLOMBIA            1           1994-05-03
# 955398                 CC          COLOMBIA            0           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 955354                   76.0              CALI                76001.0
# 955379                   11.0            BOGOTA                11001.0
# 955390                   50.0     VILLAVICENCIO                50001.0
# 955395                    8.0      BARRANQUILLA                 8001.0
# 955398                   15.0             TUNJA                15001.0
#
#                                         ESTU_COLE_TERMINO  \
# 955354  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 955379   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 955390                                COLEGIO CORAZONISTA
# 955395                                           PABLO VI
# 955398                              COLEGIO REAL DE MARES
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 955354                               4                       0
# 955379                               0                       0
# 955390                               0                       0
# 955395                               4                       0
# 955398                               0                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 955354                          0                         0
# 955379                          1                         0
# 955390                          1                         0
# 955395                          1                         0
# 955398                          0                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 955354                         1                        0
# 955379                         1                        0
# 955390                         1                        0
# 955395                         1                        0
# 955398                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 955354                            0                              0
# 955379                            0                              0
# 955390                            0                              0
# 955395                            0                              0
# 955398                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 955354                     CC                    8                    5
# 955379                     TI                    8                    5
# 955390                     TI                    5                    1
# 955395                     TI                    8                    7
# 955398                     CC                    7                    9
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 955354                     3                   0                     1
# 955379                     2                   1                     1
# 955390                     4                   1                     1
# 955395                     2                   0                     1
# 955398                     3                   1                     1
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 955354                   1                    0                        1
# 955379                   1                    0                        1
# 955390                   1                    1                        1
# 955395                   1                    0                        1
# 955398                   1                    1                        1
#
#         INST_COD_INSTITUCION  \
# 955354                  4109
# 955379                  4813
# 955390                  3712
# 955395                  3117
# 955398                  1106
#
#                                   INST_NOMBRE_INSTITUCION  \
# 955354  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 955379  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 955390  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 955395             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 955398  UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMB...
#
#                                       ESTU_PRGM_ACADEMICO  \
# 955354           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 955379   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 955390                           TECNOLOGIA EN INDUSTRIAL
# 955395  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 955398  TÉCNICA PROFESIONAL EN PROCESOS COMERCIALES Y ...
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 955354                   76001                CALI                      29
# 955379                   11001              BOGOTA                       3
# 955390                   50001       VILLAVICENCIO                      19
# 955395                    8758             SOLEDAD                       2
# 955398                   15001               TUNJA                       5
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 955354       TÉCNICO PROFESIONAL                 2                    46
# 955379       TÉCNICO PROFESIONAL                 2                    31
# 955390                TECNOLOGÍA                 2                    33
# 955395                TECNOLOGÍA                 2                    31
# 955398       TÉCNICO PROFESIONAL                 1                    47
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 955354                 76001.0                CALI                  VALLE
# 955379                 11001.0              BOGOTA                 BOGOTA
# 955390                 11001.0              BOGOTA                 BOGOTA
# 955395                  8758.0             SOLEDAD              ATLANTICO
# 955398                 15001.0               TUNJA                 BOYACA
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 955354                        3            4                        76001
# 955379                        3            0                        11001
# 955390                        1            1                        50001
# 955395                        2            4                         8001
# 955398                        4            4                        15001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 955354                    CALI                   VALLE
# 955379                  BOGOTÁ                  BOGOTA
# 955390           VILLAVICENCIO                    META
# 955395            BARRANQUILLA               ATLANTICO
# 955398                   TUNJA                  BOYACA
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 955354                           76                      136.5
# 955379                           11                      192.0
# 955390                           50                      166.5
# 955395                            8                      154.5
# 955398                           15                      153.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 955354                          34.0                     145.5
# 955379                          92.0                     187.5
# 955390                          70.0                     132.0
# 955395                          55.0                     205.5
# 955398                          54.0                     193.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 955354                      45.0                      148.5
# 955379                      89.0                      199.5
# 955390                      28.0                      142.5
# 955395                      97.0                      207.0
# 955398                      92.0                      180.0
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 955354                       47.0            120.0              -A1
# 955379                       96.0            181.5               A2
# 955390                       39.0            169.5               A2
# 955395                       98.0            174.0               A2
# 955398                       84.0            159.0               A2
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                    156.0                         3
# 955379             85.0                    180.0                         3
# 955390             76.0                    165.0                         3
# 955395             80.0                    205.5                         4
# 955398             66.0                    159.0                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 955354      Normal                 Q3            Q3                Q3
# 955379      Normal                 Q4            Q4                Q4
# 955390      Normal                 Q4            Q2                Q3
# 955395      Normal                 Q3            Q4                Q4
# 955398      Normal                 Q3            Q4                Q4
#
#        group_INGLES group_ESCRITA
# 955354           Q1            Q3
# 955379           Q4            Q4
# 955390           Q4            Q3
# 955395           Q4            Q4
# 955398           Q3            Q3

# %%
X_train_ingles, X_test_ingles, y_train_ingles, y_test_ingles = train_test_split(df_t_ingles[covariates],
                                                    df_t_ingles['MOD_INGLES_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_ingles shape: ', X_train_ingles.shape)
print('X_test_ingles shape: ', X_test_ingles.shape)
print('y_train_ingles shape: ', y_train_ingles.shape)
print('y_test_ingles shape: ', y_test_ingles.shape)
# Out:
# X_train_ingles shape:  (36083, 8)
# X_test_ingles shape:  (12028, 8)
# y_train_ingles shape:  (36083,)
# y_test_ingles shape:  (12028,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_ingles= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_ingles.fit(X_train_ingles, y_train_ingles)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_ingles=RandomforestRegModel_ingles.predict(X_test_ingles)

# %%
#MOD_INGLES_PUNT
comparar_ingles=pd.DataFrame(y_pred_ingles, y_test_ingles)
comparar_ingles.head(20)
# Out:
#                           0
# MOD_INGLES_PUNT
# 123.0            138.985409
# 156.0            157.553252
# 108.0            147.635884
# 165.0            159.250874
# 166.5            151.655436
# 172.5            146.966508
# 97.5             135.062528
# 127.5            149.834971
# 139.5            138.477899
# 163.5            149.834971
# 129.0            138.880950
# 154.5            148.376414
# 192.0            147.720717
# 115.5            130.169976
# 126.0            130.347188
# 201.0            149.357889
# 187.5            152.879809
# 111.0            144.747922
# 118.5            156.156941
# 115.5            138.985409

# %%
res_ingles = y_pred_ingles-y_test_ingles # residuals
#print(res)
fig=sm.qqplot(res_ingles,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model INGLES', MAE(y_pred_ingles,y_test_ingles))
print('RMSE of the model INGLES', RMSE(y_pred_ingles,y_test_ingles))
print('MAPE of the model INGLES', MAPE(y_pred_ingles,y_test_ingles))
print('Accuracy of the model INGLES', 100-MAPE(y_pred_ingles,y_test_ingles))
# Out:
# MAE of the model INGLES 23.05214816224179
# RMSE of the model INGLES 28.961329888523554
# MAPE of the model INGLES 16.102742316615576
# Accuracy of the model INGLES 83.89725768338442

# %%
# Important variables INGLES

feature_list_ingles= list(df_t_ingles[covariates].columns)
# Get numerical feature importances
importances_ingles = list(RandomforestRegModel_ingles.feature_importances_)
# List of tuples with variable and importance
feature_importances_ingles = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_ingles, importances_ingles)]
# Sort the feature importances by most important first
feature_importances_ingles = sorted(feature_importances_ingles, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_INGLES_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_ingles];
# Out:
# MOD_INGLES_PUNT
#
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.34
# Variable: INST_ORIGEN          Importance: 0.26
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.17
# Variable: ESTU_METODO_PRGM     Importance: 0.09
# Variable: INST_CARACTER_ACADEMICO Importance: 0.06
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.04
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.03
# Variable: ESTU_GENERO          Importance: 0.01

# %% [markdown]
# **MOD_COMUNI_ESCRITA_PUNT**

# %%
df_t_escrita=df_sabertyt.copy()
for var in ['ESTU_GENERO','INST_ORIGEN','FAMI_TIENEAUTOMOVIL','FAMI_TIENELAVADORA','FAMI_TIENECOMPUTADOR','FAMI_TIENEINTERNET','FAMI_ESTRATOVIVIENDA','FAMI_EDUCACIONMADRE',\
            'FAMI_EDUCACIONPADRE','ESTU_METODO_PRGM','INST_CARACTER_ACADEMICO','ESTU_HORASSEMANATRABAJA','ESTU_ACTIVIDADREFUERZOGENERIC','ESTU_ACTIVIDADREFUERZOAREAS',\
            'ESTU_SIMULACROTIPOICFES','ESTU_PAGOMATRICULAPROPIO','ESTU_PAGOMATRICULAPADRES','ESTU_PAGOMATRICULACREDITO','ESTU_PAGOMATRICULABECA','ESTU_VALORMATRICULAUNIVERSIDAD',\
            'ESTU_PRGM_DEPARTAMENTO','ESTU_NUCLEO_PREGRADO']:
    df_t_escrita[var]=df_t_escrita[var].cat.codes

# %%
with pd.option_context('display.max_columns',500):
    display(df_t_escrita.head())
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 955354                 CC          COLOMBIA            0  1991-06-22 00:00:00
# 955379                 CC          COLOMBIA            0           1992-07-01
# 955390                 CC          COLOMBIA            0           1992-10-08
# 955395                 CC          COLOMBIA            1           1994-05-03
# 955398                 CC          COLOMBIA            0           1987-07-31
#
#         PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_DEPTO_RESIDE  \
# 955354    20161   EK201610110512      ESTUDIANTE             VALLE
# 955379    20161   EK201610028250      ESTUDIANTE            BOGOTA
# 955390    20161   EK201610085857      ESTUDIANTE              META
# 955395    20161   EK201610021372      ESTUDIANTE         ATLANTICO
# 955398    20161   EK201610063234      ESTUDIANTE            BOYACA
#
#         ESTU_COD_RESIDE_DEPTO ESTU_MCPIO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 955354                   76.0              CALI                76001.0
# 955379                   11.0            BOGOTA                11001.0
# 955390                   50.0     VILLAVICENCIO                50001.0
# 955395                    8.0      BARRANQUILLA                 8001.0
# 955398                   15.0             TUNJA                15001.0
#
#                                         ESTU_COLE_TERMINO  \
# 955354  COLEGIO REPUBLICA DOMINICANA (IED) - SEDE PRIN...
# 955379   I.E.D. ESCUELA NORMAL SUPERIOR MARIA AUXILIADORA
# 955390                                COLEGIO CORAZONISTA
# 955395                                           PABLO VI
# 955398                              COLEGIO REAL DE MARES
#
#         ESTU_VALORMATRICULAUNIVERSIDAD  ESTU_PAGOMATRICULABECA  \
# 955354                               4                       0
# 955379                               0                       0
# 955390                               0                       0
# 955395                               4                       0
# 955398                               0                       0
#
#         ESTU_PAGOMATRICULACREDITO  ESTU_PAGOMATRICULAPADRES  \
# 955354                          0                         0
# 955379                          1                         0
# 955390                          1                         0
# 955395                          1                         0
# 955398                          0                         0
#
#         ESTU_PAGOMATRICULAPROPIO  ESTU_SIMULACROTIPOICFES  \
# 955354                         1                        0
# 955379                         1                        0
# 955390                         1                        0
# 955395                         1                        0
# 955398                         1                        0
#
#         ESTU_ACTIVIDADREFUERZOAREAS  ESTU_ACTIVIDADREFUERZOGENERIC  \
# 955354                            0                              0
# 955379                            0                              0
# 955390                            0                              0
# 955395                            0                              0
# 955398                            0                              0
#
#        ESTU_TIPODOCUMENTOSB11  FAMI_EDUCACIONPADRE  FAMI_EDUCACIONMADRE  \
# 955354                     CC                    8                    5
# 955379                     TI                    8                    5
# 955390                     TI                    5                    1
# 955395                     TI                    8                    7
# 955398                     CC                    7                    9
#
#         FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  FAMI_TIENECOMPUTADOR  \
# 955354                     3                   0                     1
# 955379                     2                   1                     1
# 955390                     4                   1                     1
# 955395                     2                   0                     1
# 955398                     3                   1                     1
#
#         FAMI_TIENELAVADORA  FAMI_TIENEAUTOMOVIL  ESTU_HORASSEMANATRABAJA  \
# 955354                   1                    0                        1
# 955379                   1                    0                        1
# 955390                   1                    1                        1
# 955395                   1                    0                        1
# 955398                   1                    1                        1
#
#         INST_COD_INSTITUCION  \
# 955354                  4109
# 955379                  4813
# 955390                  3712
# 955395                  3117
# 955398                  1106
#
#                                   INST_NOMBRE_INSTITUCION  \
# 955354  INSTITUTO TECNICO NACIONAL DE COMERCIOSIMON RO...
# 955379  CORPORACION UNIFICADA NACIONAL DE EDUCACION SU...
# 955390  FUNDACION CENTRO DE INVESTIGACION DOCENCIA Y C...
# 955395             INSTITUCION UNIVERSITARIA ITSA-SOLEDAD
# 955398  UNIVERSIDAD PEDAGOGICA Y TECNOLOGICA DE COLOMB...
#
#                                       ESTU_PRGM_ACADEMICO  \
# 955354           TECNICA PROFESIONAL EN SALUD OCUPACIONAL
# 955379   TECNICA PROFESIONAL EN MANTENIMIENTO ELECTRONICO
# 955390                           TECNOLOGIA EN INDUSTRIAL
# 955395  TECNOLOGIA EN AUTOMATIZACIÓN ELECTRÓNICA INDUS...
# 955398  TÉCNICA PROFESIONAL EN PROCESOS COMERCIALES Y ...
#
#         ESTU_PRGM_CODMUNICIPIO ESTU_PRGM_MUNICIPIO  ESTU_PRGM_DEPARTAMENTO  \
# 955354                   76001                CALI                      29
# 955379                   11001              BOGOTA                       3
# 955390                   50001       VILLAVICENCIO                      19
# 955395                    8758             SOLEDAD                       2
# 955398                   15001               TUNJA                       5
#
#        ESTU_NIVEL_PRGM_ACADEMICO  ESTU_METODO_PRGM  ESTU_NUCLEO_PREGRADO  \
# 955354       TÉCNICO PROFESIONAL                 2                    46
# 955379       TÉCNICO PROFESIONAL                 2                    31
# 955390                TECNOLOGÍA                 2                    33
# 955395                TECNOLOGÍA                 2                    31
# 955398       TÉCNICO PROFESIONAL                 1                    47
#
#         ESTU_INST_CODMUNICIPIO ESTU_INST_MUNICIPIO ESTU_INST_DEPARTAMENTO  \
# 955354                 76001.0                CALI                  VALLE
# 955379                 11001.0              BOGOTA                 BOGOTA
# 955390                 11001.0              BOGOTA                 BOGOTA
# 955395                  8758.0             SOLEDAD              ATLANTICO
# 955398                 15001.0               TUNJA                 BOYACA
#
#         INST_CARACTER_ACADEMICO  INST_ORIGEN  ESTU_COD_MCPIO_PRESENTACION  \
# 955354                        3            4                        76001
# 955379                        3            0                        11001
# 955390                        1            1                        50001
# 955395                        2            4                         8001
# 955398                        4            4                        15001
#
#        ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 955354                    CALI                   VALLE
# 955379                  BOGOTÁ                  BOGOTA
# 955390           VILLAVICENCIO                    META
# 955395            BARRANQUILLA               ATLANTICO
# 955398                   TUNJA                  BOYACA
#
#         ESTU_COD_DEPTO_PRESENTACION  MOD_RAZONA_CUANTITAT_PUNT  \
# 955354                           76                      136.5
# 955379                           11                      192.0
# 955390                           50                      166.5
# 955395                            8                      154.5
# 955398                           15                      153.0
#
#         MOD_RAZONA_CUANTITATIVO_PNAL  MOD_LECTURA_CRITICA_PUNT  \
# 955354                          34.0                     145.5
# 955379                          92.0                     187.5
# 955390                          70.0                     132.0
# 955395                          55.0                     205.5
# 955398                          54.0                     193.5
#
#         MOD_LECTURA_CRITICA_PNAL  MOD_COMPETEN_CIUDADA_PUNT  \
# 955354                      45.0                      148.5
# 955379                      89.0                      199.5
# 955390                      28.0                      142.5
# 955395                      97.0                      207.0
# 955398                      92.0                      180.0
#
#         MOD_COMPETEN_CIUDADA_PNAL  MOD_INGLES_PUNT MOD_INGLES_DESEM  \
# 955354                       47.0            120.0              -A1
# 955379                       96.0            181.5               A2
# 955390                       39.0            169.5               A2
# 955395                       98.0            174.0               A2
# 955398                       84.0            159.0               A2
#
#         MOD_INGLES_PNAL  MOD_COMUNI_ESCRITA_PUNT  MOD_COMUNI_ESCRITA_DESEM  \
# 955354             17.0                    156.0                         3
# 955379             85.0                    180.0                         3
# 955390             76.0                    165.0                         3
# 955395             80.0                    205.5                         4
# 955398             66.0                    159.0                         3
#
#         MOD_COMUNI_ESCRITA_PNAL ESTU_ESTADOINVESTIGACION PERIODO-X    PRUEBA  \
# 955354                     53.0                 PUBLICAR     20161  SaberTyT
# 955379                     84.0                 PUBLICAR     20161  SaberTyT
# 955390                     67.0                 PUBLICAR     20161  SaberTyT
# 955395                     99.0                 PUBLICAR     20161  SaberTyT
# 955398                     59.0                 PUBLICAR     20161  SaberTyT
#
#        TIPO_PRUEBA group_CUANTITATIVO group_LECTURA group_COMPETENCIA  \
# 955354      Normal                 Q3            Q3                Q3
# 955379      Normal                 Q4            Q4                Q4
# 955390      Normal                 Q4            Q2                Q3
# 955395      Normal                 Q3            Q4                Q4
# 955398      Normal                 Q3            Q4                Q4
#
#        group_INGLES group_ESCRITA
# 955354           Q1            Q3
# 955379           Q4            Q4
# 955390           Q4            Q3
# 955395           Q4            Q4
# 955398           Q3            Q3

# %%
X_train_escrita, X_test_escrita, y_train_escrita, y_test_escrita = train_test_split(df_t_escrita[covariates],
                                                    df_t_escrita['MOD_COMUNI_ESCRITA_PUNT'], test_size=0.25,
                                                    random_state=1234)

# %%
print('X_train_escrita shape: ', X_train_escrita.shape)
print('X_test_escrita shape: ', X_test_escrita.shape)
print('y_train_escrita shape: ', y_train_escrita.shape)
print('y_test_escrita shape: ', y_test_escrita.shape)
# Out:
# X_train_escrita shape:  (36083, 8)
# X_test_escrita shape:  (12028, 8)
# y_train_escrita shape:  (36083,)
# y_test_escrita shape:  (12028,)

# %%
# Create the Regression model with Random Forest
RandomforestRegModel_escrita= RandomForestRegressor(bootstrap=True, criterion='mse',max_depth=6,max_features='auto')
# Train the model
RandomforestRegModel_escrita.fit(X_train_escrita, y_train_escrita)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred_escrita=RandomforestRegModel_escrita.predict(X_test_escrita)

# %%
y_pred_escrita
# Out:
# array([148.32492868, 153.39562178, 155.93867652, ..., 155.41064645,
#        149.40398419, 150.87511827])

# %%
#MOD_COMUNI_ESCRITA_PUNT
comparar_escrita=pd.DataFrame(y_pred_escrita, y_test_escrita)
comparar_escrita.head(20)
# Out:
#                                   0
# MOD_COMUNI_ESCRITA_PUNT
# 178.5                    148.324929
# 171.0                    153.395622
# 156.0                    155.938677
# 216.0                    158.467868
# 154.5                    148.434252
# 223.5                    152.815011
# 157.5                    146.868155
# 145.5                    146.239034
# 159.0                    142.398826
# 210.0                    150.997782
# 156.0                    152.004820
# 156.0                    153.288764
# 145.5                    154.895983
# 211.5                    151.956015
# 141.0                    142.219134
# 166.5                    148.847954
# 153.0                    157.580670
# 196.5                    152.996594
# 93.0                     147.957543
# 114.0                    148.324929

# %%
res_escrita = y_pred_escrita-y_test_escrita # residuals
#print(res)
fig=sm.qqplot(res_escrita,fit=True, line='45')

# %%
# Calculate MAE, RMSE, MAPE
print('MAE of the model escrita', MAE(y_pred_escrita,y_test_escrita))
print('RMSE of the model escrita', RMSE(y_pred_escrita,y_test_escrita))
print('MAPE of the model escrita', MAPE(y_pred_escrita,y_test_escrita))
print('Accuracy of the model escrita', 100-MAPE(y_pred_escrita,y_test_escrita))
# Out:
# MAE of the model escrita 22.524535838868506
# RMSE of the model escrita 29.787584790023633
# MAPE of the model escrita 15.921829008313296
# Accuracy of the model escrita 84.0781709916867

# %%
# Important variables MOD_COMUNI_ESCRITA_PUNT

feature_list_escrita= list(df_t_escrita[covariates].columns)
# Get numerical feature importances
importances_escrita = list(RandomforestRegModel_escrita.feature_importances_)
# List of tuples with variable and importance
feature_importances_escrita = [(feature, round(importance, 2)) for feature, importance in zip(feature_list_escrita, importances_escrita)]
# Sort the feature importances by most important first
feature_importances_escrita = sorted(feature_importances_escrita, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
print('MOD_COMUNI_ESCRITA_PUNT\n')
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_escrita];
# Out:
# MOD_COMUNI_ESCRITA_PUNT
#
# Variable: ESTU_NUCLEO_PREGRADO Importance: 0.26
# Variable: ESTU_GENERO          Importance: 0.2
# Variable: ESTU_PRGM_DEPARTAMENTO Importance: 0.17
# Variable: FAMI_ESTRATOVIVIENDA Importance: 0.15
# Variable: ESTU_VALORMATRICULAUNIVERSIDAD Importance: 0.07
# Variable: INST_CARACTER_ACADEMICO Importance: 0.06
# Variable: ESTU_METODO_PRGM     Importance: 0.05
# Variable: INST_ORIGEN          Importance: 0.04

# %%
datafinal[datafinal['PRUEBA']=='SaberPro']['ESTU_VALORMATRICULAUNIVERSIDAD'].value_counts()
# Out:
# Entre 2.5 millones y menos de 4 millones    19280
# Entre 1 millón y menos de 2.5 millones      16133
# Entre 4 millones y menos de 5.5 millones    10982
# Entre 500 mil y menos de 1 millón            9877
# Más de 7 millones                            8980
# Menos de 500 mil                             8340
# Entre 5.5 millones y menos de 7 millones     4728
# No pagó matrícula                             318
# Name: ESTU_VALORMATRICULAUNIVERSIDAD, dtype: int64

# %%
datafinal[datafinal['PRUEBA']=='SaberTyT']['ESTU_VALORMATRICULAUNIVERSIDAD'].value_counts()
# Out:
# No pagó matrícula                           18191
# Entre 1 millón y menos de 2.5 millones      14553
# Entre 500 mil y menos de 1 millón           10636
# Menos de 500 mil                             2856
# Entre 2.5 millones y menos de 4 millones     1934
# Entre 4 millones y menos de 5.5 millones      182
# Entre 5.5 millones y menos de 7 millones      101
# Más de 7 millones                              48
# Name: ESTU_VALORMATRICULAUNIVERSIDAD, dtype: int64

# %%
feature_importances_razona=feature_importances

# %%
feature_importances_razona
# Out:
# [('INST_ORIGEN', 0.42),
#  ('ESTU_NUCLEO_PREGRADO', 0.21),
#  ('ESTU_GENERO', 0.12),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.08),
#  ('FAMI_ESTRATOVIVIENDA', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.05),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.04),
#  ('ESTU_METODO_PRGM', 0.0)]

# %%
top_razona=feature_importances_razona[0:8]
top_razona
# Out:
# [('INST_ORIGEN', 0.42),
#  ('ESTU_NUCLEO_PREGRADO', 0.21),
#  ('ESTU_GENERO', 0.12),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.08),
#  ('FAMI_ESTRATOVIVIENDA', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.05),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.04),
#  ('ESTU_METODO_PRGM', 0.0)]

# %%
top_razona=pd.DataFrame(top_razona)

# %%
top_razona
# Out:
#                                 0     1
# 0                     INST_ORIGEN  0.42
# 1            ESTU_NUCLEO_PREGRADO  0.21
# 2                     ESTU_GENERO  0.12
# 3          ESTU_PRGM_DEPARTAMENTO  0.08
# 4            FAMI_ESTRATOVIVIENDA  0.07
# 5         INST_CARACTER_ACADEMICO  0.05
# 6  ESTU_VALORMATRICULAUNIVERSIDAD  0.04
# 7                ESTU_METODO_PRGM  0.00

# %%
feature_importances_lectura
# Out:
# [('INST_ORIGEN', 0.36),
#  ('FAMI_ESTRATOVIVIENDA', 0.2),
#  ('ESTU_NUCLEO_PREGRADO', 0.16),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.11),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.08),
#  ('INST_CARACTER_ACADEMICO', 0.07),
#  ('ESTU_GENERO', 0.01),
#  ('ESTU_METODO_PRGM', 0.01)]

# %%
top_lectura=feature_importances_lectura[0:8]

# %%
top_lectura=pd.DataFrame(top_lectura)
top_lectura
# Out:
#                                 0     1
# 0                     INST_ORIGEN  0.36
# 1            FAMI_ESTRATOVIVIENDA  0.20
# 2            ESTU_NUCLEO_PREGRADO  0.16
# 3          ESTU_PRGM_DEPARTAMENTO  0.11
# 4  ESTU_VALORMATRICULAUNIVERSIDAD  0.08
# 5         INST_CARACTER_ACADEMICO  0.07
# 6                     ESTU_GENERO  0.01
# 7                ESTU_METODO_PRGM  0.01

# %%
feature_importances_competencia
# Out:
# [('INST_ORIGEN', 0.36),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.22),
#  ('FAMI_ESTRATOVIVIENDA', 0.18),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.08),
#  ('ESTU_NUCLEO_PREGRADO', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.05),
#  ('ESTU_GENERO', 0.03),
#  ('ESTU_METODO_PRGM', 0.01)]

# %%
top_competencia=feature_importances_competencia[0:8]
top_competencia
# Out:
# [('INST_ORIGEN', 0.36),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.22),
#  ('FAMI_ESTRATOVIVIENDA', 0.18),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.08),
#  ('ESTU_NUCLEO_PREGRADO', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.05),
#  ('ESTU_GENERO', 0.03),
#  ('ESTU_METODO_PRGM', 0.01)]

# %%
top_competencia=pd.DataFrame(top_competencia)
top_competencia
# Out:
#                                 0     1
# 0                     INST_ORIGEN  0.36
# 1          ESTU_PRGM_DEPARTAMENTO  0.22
# 2            FAMI_ESTRATOVIVIENDA  0.18
# 3  ESTU_VALORMATRICULAUNIVERSIDAD  0.08
# 4            ESTU_NUCLEO_PREGRADO  0.07
# 5         INST_CARACTER_ACADEMICO  0.05
# 6                     ESTU_GENERO  0.03
# 7                ESTU_METODO_PRGM  0.01

# %%
feature_importances_ingles
# Out:
# [('FAMI_ESTRATOVIVIENDA', 0.34),
#  ('INST_ORIGEN', 0.26),
#  ('ESTU_NUCLEO_PREGRADO', 0.17),
#  ('ESTU_METODO_PRGM', 0.09),
#  ('INST_CARACTER_ACADEMICO', 0.06),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.04),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.03),
#  ('ESTU_GENERO', 0.01)]

# %%
top_ingles=feature_importances_ingles[0:8]
top_ingles
# Out:
# [('FAMI_ESTRATOVIVIENDA', 0.34),
#  ('INST_ORIGEN', 0.26),
#  ('ESTU_NUCLEO_PREGRADO', 0.17),
#  ('ESTU_METODO_PRGM', 0.09),
#  ('INST_CARACTER_ACADEMICO', 0.06),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.04),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.03),
#  ('ESTU_GENERO', 0.01)]

# %%
top_ingles=pd.DataFrame(top_ingles)
top_ingles
# Out:
#                                 0     1
# 0            FAMI_ESTRATOVIVIENDA  0.34
# 1                     INST_ORIGEN  0.26
# 2            ESTU_NUCLEO_PREGRADO  0.17
# 3                ESTU_METODO_PRGM  0.09
# 4         INST_CARACTER_ACADEMICO  0.06
# 5          ESTU_PRGM_DEPARTAMENTO  0.04
# 6  ESTU_VALORMATRICULAUNIVERSIDAD  0.03
# 7                     ESTU_GENERO  0.01

# %%
feature_importances_escrita
# Out:
# [('ESTU_NUCLEO_PREGRADO', 0.26),
#  ('ESTU_GENERO', 0.2),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.17),
#  ('FAMI_ESTRATOVIVIENDA', 0.15),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.06),
#  ('ESTU_METODO_PRGM', 0.05),
#  ('INST_ORIGEN', 0.04)]

# %%
top_escrita=feature_importances_escrita[0:8]
top_escrita
# Out:
# [('ESTU_NUCLEO_PREGRADO', 0.26),
#  ('ESTU_GENERO', 0.2),
#  ('ESTU_PRGM_DEPARTAMENTO', 0.17),
#  ('FAMI_ESTRATOVIVIENDA', 0.15),
#  ('ESTU_VALORMATRICULAUNIVERSIDAD', 0.07),
#  ('INST_CARACTER_ACADEMICO', 0.06),
#  ('ESTU_METODO_PRGM', 0.05),
#  ('INST_ORIGEN', 0.04)]

# %%
top_escrita=pd.DataFrame(top_escrita)
top_escrita
# Out:
#                                 0     1
# 0            ESTU_NUCLEO_PREGRADO  0.26
# 1                     ESTU_GENERO  0.20
# 2          ESTU_PRGM_DEPARTAMENTO  0.17
# 3            FAMI_ESTRATOVIVIENDA  0.15
# 4  ESTU_VALORMATRICULAUNIVERSIDAD  0.07
# 5         INST_CARACTER_ACADEMICO  0.06
# 6                ESTU_METODO_PRGM  0.05
# 7                     INST_ORIGEN  0.04

# %%
#pd.concat([t1, t2, t3, t4, t5], ignore_index=True)
top_tyt=pd.concat([top_razona,top_lectura,top_competencia,top_ingles,top_escrita],ignore_index=True)
top_tyt
# Out:
#                                  0     1
# 0                      INST_ORIGEN  0.42
# 1             ESTU_NUCLEO_PREGRADO  0.21
# 2                      ESTU_GENERO  0.12
# 3           ESTU_PRGM_DEPARTAMENTO  0.08
# 4             FAMI_ESTRATOVIVIENDA  0.07
# 5          INST_CARACTER_ACADEMICO  0.05
# 6   ESTU_VALORMATRICULAUNIVERSIDAD  0.04
# 7                 ESTU_METODO_PRGM  0.00
# 8                      INST_ORIGEN  0.36
# 9             FAMI_ESTRATOVIVIENDA  0.20
# 10            ESTU_NUCLEO_PREGRADO  0.16
# 11          ESTU_PRGM_DEPARTAMENTO  0.11
# 12  ESTU_VALORMATRICULAUNIVERSIDAD  0.08
# 13         INST_CARACTER_ACADEMICO  0.07
# 14                     ESTU_GENERO  0.01
# 15                ESTU_METODO_PRGM  0.01
# 16                     INST_ORIGEN  0.36
# 17          ESTU_PRGM_DEPARTAMENTO  0.22
# 18            FAMI_ESTRATOVIVIENDA  0.18
# 19  ESTU_VALORMATRICULAUNIVERSIDAD  0.08
# 20            ESTU_NUCLEO_PREGRADO  0.07
# 21         INST_CARACTER_ACADEMICO  0.05
# 22                     ESTU_GENERO  0.03
# 23                ESTU_METODO_PRGM  0.01
# 24            FAMI_ESTRATOVIVIENDA  0.34
# 25                     INST_ORIGEN  0.26
# 26            ESTU_NUCLEO_PREGRADO  0.17
# 27                ESTU_METODO_PRGM  0.09
# 28         INST_CARACTER_ACADEMICO  0.06
# 29          ESTU_PRGM_DEPARTAMENTO  0.04
# 30  ESTU_VALORMATRICULAUNIVERSIDAD  0.03
# 31                     ESTU_GENERO  0.01
# 32            ESTU_NUCLEO_PREGRADO  0.26
# 33                     ESTU_GENERO  0.20
# 34          ESTU_PRGM_DEPARTAMENTO  0.17
# 35            FAMI_ESTRATOVIVIENDA  0.15
# 36  ESTU_VALORMATRICULAUNIVERSIDAD  0.07
# 37         INST_CARACTER_ACADEMICO  0.06
# 38                ESTU_METODO_PRGM  0.05
# 39                     INST_ORIGEN  0.04

# %%
#df.rename(columns={'A': 'a', 'C': 'c'}))
top_tyt.rename(columns={0: 'Variable', 1: 'Importance'}, inplace=True)
top_tyt
# Out:
#                           Variable  Importance
# 0                      INST_ORIGEN        0.42
# 1             ESTU_NUCLEO_PREGRADO        0.21
# 2                      ESTU_GENERO        0.12
# 3           ESTU_PRGM_DEPARTAMENTO        0.08
# 4             FAMI_ESTRATOVIVIENDA        0.07
# 5          INST_CARACTER_ACADEMICO        0.05
# 6   ESTU_VALORMATRICULAUNIVERSIDAD        0.04
# 7                 ESTU_METODO_PRGM        0.00
# 8                      INST_ORIGEN        0.36
# 9             FAMI_ESTRATOVIVIENDA        0.20
# 10            ESTU_NUCLEO_PREGRADO        0.16
# 11          ESTU_PRGM_DEPARTAMENTO        0.11
# 12  ESTU_VALORMATRICULAUNIVERSIDAD        0.08
# 13         INST_CARACTER_ACADEMICO        0.07
# 14                     ESTU_GENERO        0.01
# 15                ESTU_METODO_PRGM        0.01
# 16                     INST_ORIGEN        0.36
# 17          ESTU_PRGM_DEPARTAMENTO        0.22
# 18            FAMI_ESTRATOVIVIENDA        0.18
# 19  ESTU_VALORMATRICULAUNIVERSIDAD        0.08
# 20            ESTU_NUCLEO_PREGRADO        0.07
# 21         INST_CARACTER_ACADEMICO        0.05
# 22                     ESTU_GENERO        0.03
# 23                ESTU_METODO_PRGM        0.01
# 24            FAMI_ESTRATOVIVIENDA        0.34
# 25                     INST_ORIGEN        0.26
# 26            ESTU_NUCLEO_PREGRADO        0.17
# 27                ESTU_METODO_PRGM        0.09
# 28         INST_CARACTER_ACADEMICO        0.06
# 29          ESTU_PRGM_DEPARTAMENTO        0.04
# 30  ESTU_VALORMATRICULAUNIVERSIDAD        0.03
# 31                     ESTU_GENERO        0.01
# 32            ESTU_NUCLEO_PREGRADO        0.26
# 33                     ESTU_GENERO        0.20
# 34          ESTU_PRGM_DEPARTAMENTO        0.17
# 35            FAMI_ESTRATOVIVIENDA        0.15
# 36  ESTU_VALORMATRICULAUNIVERSIDAD        0.07
# 37         INST_CARACTER_ACADEMICO        0.06
# 38                ESTU_METODO_PRGM        0.05
# 39                     INST_ORIGEN        0.04

# %%
top_tyt['Variable'].value_counts()
# Out:
# ESTU_GENERO                       5
# FAMI_ESTRATOVIVIENDA              5
# INST_CARACTER_ACADEMICO           5
# ESTU_METODO_PRGM                  5
# ESTU_PRGM_DEPARTAMENTO            5
# ESTU_VALORMATRICULAUNIVERSIDAD    5
# ESTU_NUCLEO_PREGRADO              5
# INST_ORIGEN                       5
# Name: Variable, dtype: int64

# %%
#CF_TOTAL.groupby(CF_TOTAL['CF']).agg({'COLLISION_ID':'count'})
top_tyt.groupby(top_tyt['Variable']).agg({'Importance':'mean'}).sort_values(['Importance'], ascending=False)
# Out:
#                                 Importance
# Variable
# INST_ORIGEN                          0.288
# FAMI_ESTRATOVIVIENDA                 0.188
# ESTU_NUCLEO_PREGRADO                 0.174
# ESTU_PRGM_DEPARTAMENTO               0.124
# ESTU_GENERO                          0.074
# ESTU_VALORMATRICULAUNIVERSIDAD       0.060
# INST_CARACTER_ACADEMICO              0.058
# ESTU_METODO_PRGM                     0.032

# %%
print("Razonamiento Cuantitavio")
print("Pred Max: ", y_pred.max(), "Test Max", y_test.max())
print("Pred Min: ", y_pred.min(), "Test Min", y_test.min())
print('\n')

print("LECTURA_CRITICA")
print("Pred Max: ", y_pred_lect.max(), "Test Max", y_test_lect.max())
print("Pred Min: ", y_pred_lect.min(), "Test Min", y_test_lect.min())
print('\n')

print("COMPETENCIA CIUDADANA")
print("Pred Max: ", y_pred_compet.max(), "Test Max", y_test_compet.max())
print("Pred Min: ", y_pred_compet.min(), "Test Min", y_test_compet.min())
print('\n')

print("INGLES")
print("Pred Max: ", y_pred_ingles.max(), "Test Max", y_test_ingles.max())
print("Pred Min: ", y_pred_ingles.min(), "Test Min", y_test_ingles.min())
print('\n')

print("COMUNICACION ESCRITA")
print("Pred Max: ", y_pred_escrita.max(), "Test Max", y_test_escrita.max())
print("Pred Min: ", y_pred_escrita.min(), "Test Min", y_test_escrita.min())
print('\n')
# Out:
# Razonamiento Cuantitavio
# Pred Max:  195.61911092987427 Test Max 300.0
# Pred Min:  90.26959239937106 Test Min 57.0
#
#
# LECTURA_CRITICA
# Pred Max:  190.82547795140104 Test Max 300.0
# Pred Min:  117.76558413476292 Test Min 39.0
#
#
# COMPETENCIA CIUDADANA
# Pred Max:  184.69866439733653 Test Max 300.0
# Pred Min:  119.23867720167604 Test Min 57.0
#
#
# INGLES
# Pred Max:  183.9520300085626 Test Max 300.0
# Pred Min:  124.26177023224325 Test Min 72.0
#
#
# COMUNICACION ESCRITA
# Pred Max:  167.80803468446183 Test Max 300.0
# Pred Min:  131.7567252370832 Test Min 46.5

# %%
#Razonamiento
plt.figure(figsize=(8,6))

x = y_pred
y= y_test
sns.distplot(x, label='pred')
sns.distplot(y, label='test')

plt.title('Predict vs Test - Razonamiento', fontsize=16)
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn-deep')

x = y_pred
y = y_test
bins = np.linspace(0, 300, 70)

plt.hist([x, y], bins, label=['Pred', 'Tes'])
plt.legend(loc='upper right')
plt.title('Predict vs Test - Razonamiento', fontsize=16)
plt.show()

# %%
#lectura
plt.figure(figsize=(8,6))

x = y_pred_lect
y= y_test_lect
sns.distplot(x, label='pred')
sns.distplot(y, label='test')

plt.title('Predict vs Test - Lectura', fontsize=16)
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn-deep')

x = y_pred_lect
y = y_test_lect
bins = np.linspace(0, 300, 70)

plt.hist([x, y], bins, label=['Pred', 'Tes'])
plt.legend(loc='upper right')
plt.title('Predict vs Test - LECTURA', fontsize=16)
plt.show()

# %%
#Competencia
plt.figure(figsize=(8,6))

x = y_pred_compet
y= y_test_compet
sns.distplot(x, label='pred')
sns.distplot(y, label='test')

plt.title('Predict vs Test - Compet', fontsize=16)
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn-deep')

x = y_pred_compet
y = y_test_compet
bins = np.linspace(0, 300, 70)

plt.hist([x, y], bins, label=['Pred', 'Tes'])
plt.legend(loc='upper right')
plt.title('Predict vs Test - COMPETENCIA CIUDADANA', fontsize=16)
plt.show()

# %%
#Ingles
plt.figure(figsize=(8,6))

x = y_pred_ingles
y= y_test_ingles
sns.distplot(x, label='pred')
sns.distplot(y, label='test')

plt.title('Predict vs Test - Ingles', fontsize=16)
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn-deep')

x = y_pred_ingles
y = y_test_ingles
bins = np.linspace(0, 300, 70)

plt.hist([x, y], bins, label=['Pred', 'Tes'])
plt.legend(loc='upper right')
plt.title('Predict vs Test - INGLES', fontsize=16)
plt.show()

# %%
#Escrita
plt.figure(figsize=(8,6))

x = y_pred_escrita
y= y_test_escrita
sns.distplot(x, label='pred')
sns.distplot(y, label='test')

plt.title('Predict vs Test - Escrita', fontsize=16)
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.style.use('seaborn-deep')

x = y_pred_escrita
y = y_test_escrita
bins = np.linspace(0, 300, 70)

plt.hist([x, y], bins, label=['Pred', 'Tes'])
plt.legend(loc='upper right')
plt.title('Predict vs Test - ESCRITA', fontsize=16)
plt.show()
